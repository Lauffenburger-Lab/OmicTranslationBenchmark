# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import mannwhitneyu, normaltest
from statannotations.Annotator import Annotator
import statannot

# %% [markdown]
# # Compare DeepCellState variations

# %%
import seaborn as sns
sns.set()

# %%
res_notvae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_notvae_results1000ep512bs.csv',index_col=0)
res_notvae_2encs['model'] = 'similarity-trained AE'
res_vae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_vae_results1000ep512bs.csv',index_col=0)
res_vae_2encs['model'] = 'similarity-trained VAE'
res_prevae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_pretrained_vae_results1000ep512bs.csv',index_col=0)
res_prevae_2encs['model'] = 'pre-similarity-trained VAE'
baseline = pd.read_csv('../results/baseline_evaluation_allgenes.csv',index_col=0)
baseline = baseline.drop_duplicates()

# %%
res_cpa = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_withCPA_1000ep512bs_a375_ht29.csv',index_col=0)
res_cpa['model'] = 'CPA-based AE'

# %%
res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_ht29_a375_withclass.csv',index_col=0)
res_mi_class['model'] = 'AE with classifier'

# %%
res_direct = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_direct_translation_not_vae_results1000ep512bs.csv',index_col=0)
res_direct['model'] = 'direct translation AE'

# %%
results = pd.concat([res_notvae_2encs,
                     res_vae_2encs,
                     res_prevae_2encs,
                     res_mi_class,
                     res_cpa,
                     res_direct],axis=0)

results
# Out:
#    model_pearsonHT29  model_pearsonA375  model_spearHT29  model_spearA375  \
# 0           0.666739           0.564090         0.562238         0.488221
# 1           0.591782           0.572697         0.478091         0.431274
# 2           0.703306           0.637546         0.599642         0.542747
# 3           0.595689           0.585109         0.465942         0.473938
# 4           0.621247           0.639732         0.519357         0.538977
# 5           0.554374           0.533395         0.456431         0.418876
# 6           0.505563           0.469591         0.401197         0.384238
# 7           0.630244           0.550840         0.542571         0.440696
# 8           0.501270           0.399251         0.382562         0.324429
# 9           0.554151           0.511755         0.449934         0.414483
# 0           0.672007           0.602081         0.565656         0.526510
# 1           0.565864           0.589989         0.474451         0.465861
# 2           0.691483           0.644011         0.579349         0.552728
# 3           0.592448           0.523835         0.453410         0.431392
# 4           0.658097           0.651461         0.534632         0.552374
# 5           0.542527           0.543744         0.466458         0.422879
# 6           0.484080           0.459723         0.420633         0.377699
# 7           0.605198           0.574763         0.497182         0.455777
# 8           0.420948           0.420358         0.313993         0.333600
# 9           0.516164           0.497016         0.405352         0.400865
# 0           0.649254           0.567270         0.552457         0.495932
# 1           0.568055           0.563963         0.460192         0.441114
# 2           0.691392           0.635433         0.589269         0.554386
# 3           0.580027           0.579179         0.452766         0.463812
# 4           0.636649           0.640256         0.521346         0.550964
# 5           0.517538           0.527614         0.425620         0.453913
# 6           0.506246           0.445963         0.399823         0.357171
# 7           0.666274           0.586457         0.572034         0.469947
# 8           0.487201           0.433324         0.384154         0.353557
# 9           0.541991           0.471840         0.443098         0.391396
# 0           0.674442           0.570235         0.569433         0.488278
# 1           0.599027           0.583896         0.490749         0.452875
# 2           0.705431           0.643685         0.591212         0.554409
# 3           0.596755           0.586761         0.469937         0.469025
# 4           0.646739           0.640250         0.534608         0.540724
# 5           0.570010           0.541169         0.489358         0.429460
# 6           0.529065           0.476808         0.427845         0.392704
# 7           0.648193           0.576124         0.561575         0.456567
# 8           0.517324           0.409533         0.399560         0.332204
# 9           0.574006           0.546425         0.465308         0.444518
# 0           0.673932           0.549015         0.562946         0.449530
# 1           0.589004           0.549911         0.479765         0.424332
# 2           0.676635           0.639625         0.570473         0.540096
# 3           0.550606           0.558759         0.439052         0.443280
# 4           0.621177           0.630697         0.519464         0.531267
# 5           0.592926           0.539691         0.508504         0.434678
# 6           0.501435           0.437838         0.394468         0.360564
# 7           0.631147           0.564606         0.526179         0.428213
# 8           0.489493           0.370766         0.379147         0.286545
# 9           0.549553           0.510040         0.444448         0.428244
# 0           0.597393           0.482235         0.493795         0.404231
# 1           0.569001           0.567816         0.447734         0.447532
# 2           0.659897           0.620128         0.553527         0.520385
# 3           0.582334           0.571491         0.453351         0.462511
# 4           0.612338           0.627239         0.496473         0.532367
# 5           0.552025           0.524972         0.469300         0.417509
# 6           0.500190           0.442974         0.404544         0.358124
# 7           0.587414           0.517645         0.508234         0.396625
# 8           0.502165           0.381463         0.389112         0.296481
# 9           0.531792           0.491069         0.436466         0.412022
#
#    model_accHT29  model_accA375  recon_pear_ht29  recon_pear_a375  \
# 0       0.699960       0.672665         0.830313         0.826383
# 1       0.665911       0.652558         0.824589         0.818986
# 2       0.715648       0.692009         0.812255         0.827975
# 3       0.664803       0.670647         0.826020         0.813655
# 4       0.684905       0.692943         0.846574         0.828014
# 5       0.658123       0.645286         0.853151         0.831958
# 6       0.635842       0.629828         0.833748         0.800847
# 7       0.693754       0.653587         0.849627         0.818409
# 8       0.628646       0.604494         0.838561         0.822378
# 9       0.656046       0.647380         0.816862         0.803080
# 0       0.701155       0.686533         0.822774         0.779324
# 1       0.665155       0.666721         0.809804         0.753822
# 2       0.703966       0.692574         0.752126         0.764791
# 3       0.657500       0.654186         0.722135         0.721446
# 4       0.688516       0.700558         0.809746         0.723825
# 5       0.662802       0.646991         0.843694         0.822660
# 6       0.645992       0.628805         0.774423         0.742963
# 7       0.678587       0.661870         0.784845         0.705975
# 8       0.604980       0.610396         0.701056         0.710100
# 9       0.640546       0.640680         0.722740         0.701822
# 0       0.694539       0.675736         0.818976         0.750212
# 1       0.659964       0.657339         0.808245         0.776176
# 2       0.712012       0.698044         0.739298         0.807916
# 3       0.658192       0.667262         0.769390         0.721916
# 4       0.687929       0.699336         0.833149         0.800234
# 5       0.646909       0.662413         0.760569         0.735852
# 6       0.638030       0.616230         0.819579         0.784154
# 7       0.709506       0.666166         0.800889         0.738630
# 8       0.632996       0.615631         0.758285         0.734822
# 9       0.656492       0.637265         0.694587         0.758261
# 0       0.703659       0.671954         0.827002         0.820544
# 1       0.671413       0.664183         0.826619         0.820395
# 2       0.713033       0.696681         0.812226         0.826925
# 3       0.665675       0.668766         0.821476         0.804674
# 4       0.692576       0.693203         0.839975         0.825189
# 5       0.672199       0.650312         0.834089         0.828042
# 6       0.648721       0.632456         0.828883         0.815544
# 7       0.703091       0.659627         0.853530         0.812377
# 8       0.634600       0.607860         0.830389         0.818583
# 9       0.662983       0.657942         0.821980         0.808581
# 0       0.701321       0.656841         0.835393         0.818401
# 1       0.668531       0.650932         0.821832         0.827302
# 2       0.702578       0.690789         0.819998         0.832906
# 3       0.653401       0.658281         0.831658         0.807958
# 4       0.685294       0.692043         0.849340         0.828193
# 5       0.680805       0.652499         0.852308         0.829899
# 6       0.636266       0.622189         0.830061         0.806941
# 7       0.689054       0.648810         0.853617         0.817448
# 8       0.628200       0.592782         0.811054         0.821871
# 9       0.652375       0.652080         0.818322         0.803945
# 0       0.670224       0.640016         0.742100         0.740357
# 1       0.653805       0.661848         0.772833         0.767519
# 2       0.694435       0.683150         0.751067         0.763027
# 3       0.660532       0.667851         0.748587         0.747398
# 4       0.675516       0.692455         0.767007         0.763084
# 5       0.666094       0.644725         0.781454         0.756074
# 6       0.640390       0.620268         0.756632         0.739038
# 7       0.679920       0.637178         0.783028         0.732762
# 8       0.631137       0.597430         0.766207         0.745064
# 9       0.649333       0.646721         0.730897         0.711924
#
#    recon_spear_ht29  recon_spear_a375  ...  recon_acc_a375  cross_corr_ht29  \
# 0          0.775642          0.756613  ...        0.790215         0.561255
# 1          0.761464          0.734010  ...        0.778140         0.525529
# 2          0.762062          0.761507  ...        0.791721         0.536881
# 3          0.771951          0.742145  ...        0.783081         0.461170
# 4          0.804735          0.752695  ...        0.791035         0.571863
# 5          0.811846          0.776322  ...        0.801362         0.500165
# 6          0.793034          0.731223  ...        0.778329         0.461660
# 7          0.814801          0.772086  ...        0.799294         0.518081
# 8          0.800195          0.775301  ...        0.799670         0.494669
# 9          0.760642          0.758384  ...        0.792070         0.525332
# 0          0.762210          0.673304  ...        0.753181         0.576706
# 1          0.743418          0.623143  ...        0.730856         0.540844
# 2          0.657321          0.655778  ...        0.744689         0.571963
# 3          0.599709          0.594886  ...        0.720152         0.490115
# 4          0.748106          0.600002  ...        0.725187         0.615015
# 5          0.801087          0.767717  ...        0.798685         0.518851
# 6          0.707325          0.655868  ...        0.746485         0.554532
# 7          0.717525          0.610275  ...        0.730337         0.520934
# 8          0.626364          0.615463  ...        0.731377         0.491566
# 9          0.635768          0.612520  ...        0.730152         0.575333
# 0          0.752773          0.629410  ...        0.734440         0.563547
# 1          0.734534          0.660270  ...        0.744600         0.515558
# 2          0.644106          0.727825  ...        0.775459         0.535715
# 3          0.676557          0.598689  ...        0.721113         0.465720
# 4          0.786898          0.709390  ...        0.771655         0.594461
# 5          0.679259          0.648346  ...        0.745942         0.551058
# 6          0.774036          0.718419  ...        0.773156         0.454975
# 7          0.739501          0.654527  ...        0.745156         0.563986
# 8          0.693487          0.651684  ...        0.745271         0.504223
# 9          0.604660          0.694344  ...        0.761662         0.482437
# 0          0.773864          0.747979  ...        0.786223              NaN
# 1          0.761357          0.738538  ...        0.781049              NaN
# 2          0.765004          0.762456  ...        0.791202              NaN
# 3          0.761728          0.737869  ...        0.781250              NaN
# 4          0.801233          0.748599  ...        0.789252              NaN
# 5          0.799860          0.777122  ...        0.803027              NaN
# 6          0.787878          0.762341  ...        0.793517              NaN
# 7          0.814444          0.764148  ...        0.795408              NaN
# 8          0.791325          0.773949  ...        0.799783              NaN
# 9          0.773293          0.764439  ...        0.795105              NaN
# 0          0.783634          0.754474  ...        0.789528              NaN
# 1          0.772010          0.753359  ...        0.787998              NaN
# 2          0.770136          0.766292  ...        0.793680              NaN
# 3          0.772910          0.729672  ...        0.776977              NaN
# 4          0.809962          0.761095  ...        0.795430              NaN
# 5          0.808809          0.780059  ...        0.804115              NaN
# 6          0.788840          0.758583  ...        0.788537              NaN
# 7          0.821611          0.770311  ...        0.798742              NaN
# 8          0.766373          0.775849  ...        0.800164              NaN
# 9          0.771057          0.758481  ...        0.792892              NaN
# 0          0.651817          0.614725  ...        0.727556         0.482594
# 1          0.675556          0.647556  ...        0.741821         0.475165
# 2          0.655678          0.656133  ...        0.743000         0.487329
# 3          0.641490          0.629767  ...        0.734629         0.431596
# 4          0.694789          0.641652  ...        0.742146         0.514760
# 5          0.703016          0.667393  ...        0.753402         0.455600
# 6          0.685567          0.646906  ...        0.740194         0.424462
# 7          0.715655          0.648849  ...        0.745276         0.456299
# 8          0.708504          0.664973  ...        0.750991         0.440930
# 9          0.656130          0.636284  ...        0.737643         0.448687
#
#    cross_corr_a375  Direct_pearson  Direct_spearman  DirectAcc_ht29  \
# 0         0.539134        0.491287         0.415190        0.642983
# 1         0.551173        0.449773         0.373708        0.631105
# 2         0.556446        0.467521         0.380200        0.626279
# 3         0.527485        0.420189         0.338177        0.617376
# 4         0.636663        0.534992         0.417309        0.646877
# 5         0.544733        0.414236         0.365071        0.626368
# 6         0.456088        0.305874         0.271386        0.590569
# 7         0.540003        0.453185         0.369136        0.629967
# 8         0.475472        0.301552         0.254713        0.581735
# 9         0.503635        0.381603         0.307406        0.604008
# 0         0.571916        0.491287         0.415190        0.642983
# 1         0.561562        0.449773         0.373708        0.631105
# 2         0.601047        0.467521         0.380200        0.626279
# 3         0.556084        0.420189         0.338177        0.617376
# 4         0.636629        0.534992         0.417309        0.646877
# 5         0.548061        0.414236         0.365071        0.626368
# 6         0.557212        0.305874         0.271386        0.590569
# 7         0.614659        0.453185         0.369136        0.629967
# 8         0.499856        0.301552         0.254713        0.581735
# 9         0.534863        0.381603         0.307406        0.604008
# 0         0.508147        0.491287         0.415190        0.642983
# 1         0.543888        0.449773         0.373708        0.631105
# 2         0.562228        0.467521         0.380200        0.626279
# 3         0.511190        0.420189         0.338177        0.617376
# 4         0.635052        0.534992         0.417309        0.646877
# 5         0.577094        0.414236         0.365071        0.626368
# 6         0.435028        0.305874         0.271386        0.590569
# 7         0.627593        0.453185         0.369136        0.629967
# 8         0.504411        0.301552         0.254713        0.581735
# 9         0.506906        0.381603         0.307406        0.604008
# 0              NaN        0.491287         0.415190        0.642983
# 1              NaN        0.449773         0.373708        0.631105
# 2              NaN        0.467521         0.380200        0.626279
# 3              NaN        0.420189         0.338177        0.617376
# 4              NaN        0.534992         0.417309        0.646877
# 5              NaN        0.414235         0.365071        0.626368
# 6              NaN        0.305874         0.271386        0.590569
# 7              NaN        0.453185         0.369136        0.629967
# 8              NaN        0.301552         0.254713        0.581735
# 9              NaN        0.381603         0.307406        0.604008
# 0              NaN        0.491287         0.415190        0.642983
# 1              NaN        0.449773         0.373708        0.631105
# 2              NaN        0.467521         0.380200        0.626279
# 3              NaN        0.420189         0.338177        0.617376
# 4              NaN        0.534992         0.417309        0.646877
# 5              NaN        0.414235         0.365071        0.626368
# 6              NaN        0.305874         0.271386        0.590569
# 7              NaN        0.453185         0.369136        0.629967
# 8              NaN        0.301552         0.254713        0.581735
# 9              NaN        0.381603         0.307406        0.604008
# 0         0.424604        0.491287         0.415190        0.642983
# 1         0.522335        0.449773         0.373708        0.631105
# 2         0.517149        0.467521         0.380200        0.626279
# 3         0.482092        0.420189         0.338177        0.617376
# 4         0.600715        0.534992         0.417309        0.646877
# 5         0.511786        0.414236         0.365071        0.626368
# 6         0.401321        0.305874         0.271386        0.590569
# 7         0.495715        0.453185         0.369136        0.629967
# 8         0.436406        0.301552         0.254713        0.581735
# 9         0.423841        0.381603         0.307406        0.604008
#
#    DirectAcc_a375                       model F1_score  ClassAccuracy
# 0        0.642983       similarity-trained AE      NaN            NaN
# 1        0.631105       similarity-trained AE      NaN            NaN
# 2        0.626279       similarity-trained AE      NaN            NaN
# 3        0.617376       similarity-trained AE      NaN            NaN
# 4        0.646877       similarity-trained AE      NaN            NaN
# 5        0.626368       similarity-trained AE      NaN            NaN
# 6        0.590569       similarity-trained AE      NaN            NaN
# 7        0.629967       similarity-trained AE      NaN            NaN
# 8        0.581735       similarity-trained AE      NaN            NaN
# 9        0.604008       similarity-trained AE      NaN            NaN
# 0        0.642983      similarity-trained VAE      NaN            NaN
# 1        0.631105      similarity-trained VAE      NaN            NaN
# 2        0.626279      similarity-trained VAE      NaN            NaN
# 3        0.617376      similarity-trained VAE      NaN            NaN
# 4        0.646877      similarity-trained VAE      NaN            NaN
# 5        0.626368      similarity-trained VAE      NaN            NaN
# 6        0.590569      similarity-trained VAE      NaN            NaN
# 7        0.629967      similarity-trained VAE      NaN            NaN
# 8        0.581735      similarity-trained VAE      NaN            NaN
# 9        0.604008      similarity-trained VAE      NaN            NaN
# 0        0.642983  pre-similarity-trained VAE      NaN            NaN
# 1        0.631105  pre-similarity-trained VAE      NaN            NaN
# 2        0.626279  pre-similarity-trained VAE      NaN            NaN
# 3        0.617376  pre-similarity-trained VAE      NaN            NaN
# 4        0.646877  pre-similarity-trained VAE      NaN            NaN
# 5        0.626368  pre-similarity-trained VAE      NaN            NaN
# 6        0.590569  pre-similarity-trained VAE      NaN            NaN
# 7        0.629967  pre-similarity-trained VAE      NaN            NaN
# 8        0.581735  pre-similarity-trained VAE      NaN            NaN
# 9        0.604008  pre-similarity-trained VAE      NaN            NaN
# 0        0.642983          AE with classifier      NaN            NaN
# 1        0.631105          AE with classifier      NaN            NaN
# 2        0.626279          AE with classifier      NaN            NaN
# 3        0.617376          AE with classifier      NaN            NaN
# 4        0.646877          AE with classifier      NaN            NaN
# 5        0.626368          AE with classifier      NaN            NaN
# 6        0.590569          AE with classifier      NaN            NaN
# 7        0.629967          AE with classifier      NaN            NaN
# 8        0.581735          AE with classifier      NaN            NaN
# 9        0.604008          AE with classifier      NaN            NaN
# 0        0.642983                CPA-based AE      1.0            1.0
# 1        0.631105                CPA-based AE      1.0            1.0
# 2        0.626279                CPA-based AE      1.0            1.0
# 3        0.617376                CPA-based AE      1.0            1.0
# 4        0.646877                CPA-based AE      1.0            1.0
# 5        0.626368                CPA-based AE      1.0            1.0
# 6        0.590569                CPA-based AE      1.0            1.0
# 7        0.629967                CPA-based AE      1.0            1.0
# 8        0.581735                CPA-based AE      1.0            1.0
# 9        0.604008                CPA-based AE      1.0            1.0
# 0        0.642983       direct translation AE      NaN            NaN
# 1        0.631105       direct translation AE      NaN            NaN
# 2        0.626279       direct translation AE      NaN            NaN
# 3        0.617376       direct translation AE      NaN            NaN
# 4        0.646877       direct translation AE      NaN            NaN
# 5        0.626368       direct translation AE      NaN            NaN
# 6        0.590569       direct translation AE      NaN            NaN
# 7        0.629967       direct translation AE      NaN            NaN
# 8        0.581735       direct translation AE      NaN            NaN
# 9        0.604008       direct translation AE      NaN            NaN
#
# [60 rows x 21 columns]

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','sign accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','sign accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline],axis=0)
res_to_a375
# Out:
#      pearson  spearman  sign accuracy                  model
# 0   0.564090  0.488221       0.672665  similarity-trained AE
# 1   0.572697  0.431274       0.652558  similarity-trained AE
# 2   0.637546  0.542747       0.692009  similarity-trained AE
# 3   0.585109  0.473938       0.670647  similarity-trained AE
# 4   0.639732  0.538977       0.692943  similarity-trained AE
# ..       ...       ...            ...                    ...
# 5   0.414236  0.365071       0.626368     direct translation
# 6   0.305874  0.271386       0.590569     direct translation
# 7   0.453185  0.369136       0.629967     direct translation
# 8   0.301552  0.254713       0.581735     direct translation
# 9   0.381603  0.307406       0.604008     direct translation
#
# [70 rows x 4 columns]

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#                      model         metric     value
# 0    similarity-trained AE        pearson  0.564090
# 1    similarity-trained AE        pearson  0.572697
# 2    similarity-trained AE        pearson  0.637546
# 3    similarity-trained AE        pearson  0.585109
# 4    similarity-trained AE        pearson  0.639732
# ..                     ...            ...       ...
# 205     direct translation  sign accuracy  0.626368
# 206     direct translation  sign accuracy  0.590569
# 207     direct translation  sign accuracy  0.629967
# 208     direct translation  sign accuracy  0.581735
# 209     direct translation  sign accuracy  0.604008
#
# [210 rows x 3 columns]

# %%
res_to_a375.model.unique()
# Out:
# array(['similarity-trained AE', 'similarity-trained VAE',
#        'pre-similarity-trained VAE', 'AE with classifier', 'CPA-based AE',
#        'direct translation AE', 'direct translation'], dtype=object)

# %%
plt.rcParams["figure.figsize"] = (8, 6)

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(8,7), dpi= 300)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_to_a375,
            order=['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.xlim(0.25,0.7)
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='models')
# Out:
# [Text(0.5, 1.0, ''),
#  Text(0.5, 0, 'Performance metric value'),
#  Text(0, 0.5, 'models')]

# %%
from scipy import stats

# %%
models = ['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-14-872359e74bb4>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-14-872359e74bb4>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-15-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-15-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='sign accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-16-a9ff6e3ced82>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='sign accuracy'].value.values
# <ipython-input-16-a9ff6e3ced82>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='sign accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']]
a375_translate.to_csv('../results/my_results_10kgenes/a375_all_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
a375_translate
# Out:
#                                    metric  direct translation  \
# direct translation                pearson                 1.0
# similarity-trained AE             pearson                 0.0
# similarity-trained VAE            pearson                 0.0
# pre-similarity-trained VAE        pearson                 0.0
# AE with classifier                pearson                 0.0
# CPA-based AE                      pearson                 0.0
# direct translation AE             pearson                 0.0
# direct translation               spearman                 1.0
# similarity-trained AE            spearman                 0.0
# similarity-trained VAE           spearman                 0.0
# pre-similarity-trained VAE       spearman                 0.0
# AE with classifier               spearman                 0.0
# CPA-based AE                     spearman                 0.0
# direct translation AE            spearman                 0.0
# direct translation          sign accuracy                 1.0
# similarity-trained AE       sign accuracy                 0.0
# similarity-trained VAE      sign accuracy                 0.0
# pre-similarity-trained VAE  sign accuracy                 0.0
# AE with classifier          sign accuracy                 0.0
# CPA-based AE                sign accuracy                 0.0
# direct translation AE       sign accuracy                 0.0
#
#                             similarity-trained AE  similarity-trained VAE  \
# direct translation                       0.003611                0.002827
# similarity-trained AE                    1.000000                0.791337
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
# direct translation                       0.003611                0.004586
# similarity-trained AE                    1.000000                0.850107
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
# direct translation                       0.004586                0.005795
# similarity-trained AE                    1.000000                0.909722
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
#
#                             pre-similarity-trained VAE  AE with classifier  \
# direct translation                            0.005795            0.002202
# similarity-trained AE                         0.969850            0.520523
# similarity-trained VAE                        0.791337            1.000000
# pre-similarity-trained VAE                    1.000000            0.623176
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# direct translation                            0.007285            0.002202
# similarity-trained AE                         0.677585            0.570750
# similarity-trained VAE                        0.909722            0.791337
# pre-similarity-trained VAE                    1.000000            1.000000
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# direct translation                            0.011330            0.002202
# similarity-trained AE                         0.677585            0.570750
# similarity-trained VAE                        0.850107            0.791337
# pre-similarity-trained VAE                    1.000000            0.909722
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
#
#                             CPA-based AE  direct translation AE
# direct translation              0.007285               0.021134
# similarity-trained AE           0.623176               0.427355
# similarity-trained VAE          0.677585               0.384673
# pre-similarity-trained VAE      0.570750               0.520523
# AE with classifier              0.344704               0.241322
# CPA-based AE                    1.000000               0.733730
# direct translation AE           0.000000               1.000000
# direct translation              0.007285               0.025748
# similarity-trained AE           0.850107               0.384673
# similarity-trained VAE          0.677585               0.384673
# pre-similarity-trained VAE      0.384673               0.427355
# AE with classifier              0.212294               0.273036
# CPA-based AE                    1.000000               0.570750
# direct translation AE           0.000000               1.000000
# direct translation              0.007285               0.025748
# similarity-trained AE           0.791337               0.427355
# similarity-trained VAE          0.623176               0.384673
# pre-similarity-trained VAE      0.344704               0.472676
# AE with classifier              0.273036               0.307489
# CPA-based AE                    1.000000               0.677585
# direct translation AE           0.000000               1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_a375 = results.loc[:,['recon_pear_a375','recon_spear_a375','recon_acc_a375','model']]
res_recon_a375.columns = ['pearson','spearman','sign accuracy','model']
res_recon_a375
# Out:
#     pearson  spearman  sign accuracy                       model
# 0  0.826383  0.756613       0.790215       similarity-trained AE
# 1  0.818986  0.734010       0.778140       similarity-trained AE
# 2  0.827975  0.761507       0.791721       similarity-trained AE
# 3  0.813655  0.742145       0.783081       similarity-trained AE
# 4  0.828014  0.752695       0.791035       similarity-trained AE
# 5  0.831958  0.776322       0.801362       similarity-trained AE
# 6  0.800847  0.731223       0.778329       similarity-trained AE
# 7  0.818409  0.772086       0.799294       similarity-trained AE
# 8  0.822378  0.775301       0.799670       similarity-trained AE
# 9  0.803080  0.758384       0.792070       similarity-trained AE
# 0  0.779324  0.673304       0.753181      similarity-trained VAE
# 1  0.753822  0.623143       0.730856      similarity-trained VAE
# 2  0.764791  0.655778       0.744689      similarity-trained VAE
# 3  0.721446  0.594886       0.720152      similarity-trained VAE
# 4  0.723825  0.600002       0.725187      similarity-trained VAE
# 5  0.822660  0.767717       0.798685      similarity-trained VAE
# 6  0.742963  0.655868       0.746485      similarity-trained VAE
# 7  0.705975  0.610275       0.730337      similarity-trained VAE
# 8  0.710100  0.615463       0.731377      similarity-trained VAE
# 9  0.701822  0.612520       0.730152      similarity-trained VAE
# 0  0.750212  0.629410       0.734440  pre-similarity-trained VAE
# 1  0.776176  0.660270       0.744600  pre-similarity-trained VAE
# 2  0.807916  0.727825       0.775459  pre-similarity-trained VAE
# 3  0.721916  0.598689       0.721113  pre-similarity-trained VAE
# 4  0.800234  0.709390       0.771655  pre-similarity-trained VAE
# 5  0.735852  0.648346       0.745942  pre-similarity-trained VAE
# 6  0.784154  0.718419       0.773156  pre-similarity-trained VAE
# 7  0.738630  0.654527       0.745156  pre-similarity-trained VAE
# 8  0.734822  0.651684       0.745271  pre-similarity-trained VAE
# 9  0.758261  0.694344       0.761662  pre-similarity-trained VAE
# 0  0.820544  0.747979       0.786223          AE with classifier
# 1  0.820395  0.738538       0.781049          AE with classifier
# 2  0.826925  0.762456       0.791202          AE with classifier
# 3  0.804674  0.737869       0.781250          AE with classifier
# 4  0.825189  0.748599       0.789252          AE with classifier
# 5  0.828042  0.777122       0.803027          AE with classifier
# 6  0.815544  0.762341       0.793517          AE with classifier
# 7  0.812377  0.764148       0.795408          AE with classifier
# 8  0.818583  0.773949       0.799783          AE with classifier
# 9  0.808581  0.764439       0.795105          AE with classifier
# 0  0.818401  0.754474       0.789528                CPA-based AE
# 1  0.827302  0.753359       0.787998                CPA-based AE
# 2  0.832906  0.766292       0.793680                CPA-based AE
# 3  0.807958  0.729672       0.776977                CPA-based AE
# 4  0.828193  0.761095       0.795430                CPA-based AE
# 5  0.829899  0.780059       0.804115                CPA-based AE
# 6  0.806941  0.758583       0.788537                CPA-based AE
# 7  0.817448  0.770311       0.798742                CPA-based AE
# 8  0.821871  0.775849       0.800164                CPA-based AE
# 9  0.803945  0.758481       0.792892                CPA-based AE
# 0  0.740357  0.614725       0.727556       direct translation AE
# 1  0.767519  0.647556       0.741821       direct translation AE
# 2  0.763027  0.656133       0.743000       direct translation AE
# 3  0.747398  0.629767       0.734629       direct translation AE
# 4  0.763084  0.641652       0.742146       direct translation AE
# 5  0.756074  0.667393       0.753402       direct translation AE
# 6  0.739038  0.646906       0.740194       direct translation AE
# 7  0.732762  0.648849       0.745276       direct translation AE
# 8  0.745064  0.664973       0.750991       direct translation AE
# 9  0.711924  0.636284       0.737643       direct translation AE

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#                      model         metric     value
# 0    similarity-trained AE        pearson  0.826383
# 1    similarity-trained AE        pearson  0.818986
# 2    similarity-trained AE        pearson  0.827975
# 3    similarity-trained AE        pearson  0.813655
# 4    similarity-trained AE        pearson  0.828014
# ..                     ...            ...       ...
# 175  direct translation AE  sign accuracy  0.753402
# 176  direct translation AE  sign accuracy  0.740194
# 177  direct translation AE  sign accuracy  0.745276
# 178  direct translation AE  sign accuracy  0.750991
# 179  direct translation AE  sign accuracy  0.737643
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_recon_a375,
            order=['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
# Out:
# [Text(0.5, 1.0, ''),
#  Text(0.5, 0, 'Performance metric value'),
#  Text(0, 0.5, 'models')]

# %%
models = ['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='pearson'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-21-495f48121114>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='pearson'].value.values
# <ipython-input-21-495f48121114>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-22-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-22-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='sign accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-23-26171e6f1a72>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='sign accuracy'].value.values
# <ipython-input-23-26171e6f1a72>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='sign accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']]
a375_reconstruction.to_csv('../results/my_results_10kgenes/a375_all_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                                    metric  similarity-trained AE  \
# similarity-trained AE             pearson                    1.0
# similarity-trained VAE            pearson                    0.0
# pre-similarity-trained VAE        pearson                    0.0
# AE with classifier                pearson                    0.0
# CPA-based AE                      pearson                    0.0
# direct translation AE             pearson                    0.0
# similarity-trained AE            spearman                    1.0
# similarity-trained VAE           spearman                    0.0
# pre-similarity-trained VAE       spearman                    0.0
# AE with classifier               spearman                    0.0
# CPA-based AE                     spearman                    0.0
# direct translation AE            spearman                    0.0
# similarity-trained AE       sign accuracy                    1.0
# similarity-trained VAE      sign accuracy                    0.0
# pre-similarity-trained VAE  sign accuracy                    0.0
# AE with classifier          sign accuracy                    0.0
# CPA-based AE                sign accuracy                    0.0
# direct translation AE       sign accuracy                    0.0
#
#                             similarity-trained VAE  \
# similarity-trained AE                     0.001008
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
# similarity-trained AE                     0.001315
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
# similarity-trained AE                     0.001315
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
#
#                             pre-similarity-trained VAE  AE with classifier  \
# similarity-trained AE                         0.000330            0.733730
# similarity-trained VAE                        0.212294            0.001315
# pre-similarity-trained VAE                    1.000000            0.000246
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# similarity-trained AE                         0.000183            0.677585
# similarity-trained VAE                        0.161972            0.001706
# pre-similarity-trained VAE                    1.000000            0.000183
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# similarity-trained AE                         0.000183            0.733730
# similarity-trained VAE                        0.140465            0.001706
# pre-similarity-trained VAE                    1.000000            0.000183
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
#
#                             CPA-based AE  direct translation AE
# similarity-trained AE           0.909722               0.000183
# similarity-trained VAE          0.001008               0.520523
# pre-similarity-trained VAE      0.000330               0.472676
# AE with classifier              0.677585               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000
# similarity-trained AE           0.520523               0.000183
# similarity-trained VAE          0.001315               0.307489
# pre-similarity-trained VAE      0.000183               0.161972
# AE with classifier              0.733730               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000
# similarity-trained AE           0.677585               0.000183
# similarity-trained VAE          0.001315               0.384673
# pre-similarity-trained VAE      0.000183               0.140465
# AE with classifier              0.677585               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','sign accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','sign accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline],axis=0)
res_to_ht29
# Out:
#      pearson  spearman  sign accuracy                  model
# 0   0.666739  0.562238       0.699960  similarity-trained AE
# 1   0.591782  0.478091       0.665911  similarity-trained AE
# 2   0.703306  0.599642       0.715648  similarity-trained AE
# 3   0.595689  0.465942       0.664803  similarity-trained AE
# 4   0.621247  0.519357       0.684905  similarity-trained AE
# ..       ...       ...            ...                    ...
# 5   0.414236  0.365071       0.626368     direct translation
# 6   0.305874  0.271386       0.590569     direct translation
# 7   0.453185  0.369136       0.629967     direct translation
# 8   0.301552  0.254713       0.581735     direct translation
# 9   0.381603  0.307406       0.604008     direct translation
#
# [70 rows x 4 columns]

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#                      model         metric     value
# 0    similarity-trained AE        pearson  0.666739
# 1    similarity-trained AE        pearson  0.591782
# 2    similarity-trained AE        pearson  0.703306
# 3    similarity-trained AE        pearson  0.595689
# 4    similarity-trained AE        pearson  0.621247
# ..                     ...            ...       ...
# 205     direct translation  sign accuracy  0.626368
# 206     direct translation  sign accuracy  0.590569
# 207     direct translation  sign accuracy  0.629967
# 208     direct translation  sign accuracy  0.581735
# 209     direct translation  sign accuracy  0.604008
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_to_ht29,
            order=['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='model')
plt.xlim(0.25,0.7)
# Out:
# (0.25, 0.7)

# %%
models = ['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-28-f32db2e41f2b>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-28-f32db2e41f2b>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-29-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-29-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='sign accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-30-cfb7e48ca1ad>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='sign accuracy'].value.values
# <ipython-input-30-cfb7e48ca1ad>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='sign accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']]
ht29_translate.to_csv('../results/my_results_10kgenes/ht29_all_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
ht29_translate
# Out:
#                                    metric  direct translation  \
# direct translation                pearson                 1.0
# similarity-trained AE             pearson                 0.0
# similarity-trained VAE            pearson                 0.0
# pre-similarity-trained VAE        pearson                 0.0
# AE with classifier                pearson                 0.0
# CPA-based AE                      pearson                 0.0
# direct translation AE             pearson                 0.0
# direct translation               spearman                 1.0
# similarity-trained AE            spearman                 0.0
# similarity-trained VAE           spearman                 0.0
# pre-similarity-trained VAE       spearman                 0.0
# AE with classifier               spearman                 0.0
# CPA-based AE                     spearman                 0.0
# direct translation AE            spearman                 0.0
# direct translation          sign accuracy                 1.0
# similarity-trained AE       sign accuracy                 0.0
# similarity-trained VAE      sign accuracy                 0.0
# pre-similarity-trained VAE  sign accuracy                 0.0
# AE with classifier          sign accuracy                 0.0
# CPA-based AE                sign accuracy                 0.0
# direct translation AE       sign accuracy                 0.0
#
#                             similarity-trained AE  similarity-trained VAE  \
# direct translation                       0.000330                0.001706
# similarity-trained AE                    1.000000                0.733730
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
# direct translation                       0.000583                0.002202
# similarity-trained AE                    1.000000                0.909722
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
# direct translation                       0.001008                0.002827
# similarity-trained AE                    1.000000                0.850107
# similarity-trained VAE                   0.000000                1.000000
# pre-similarity-trained VAE               0.000000                0.000000
# AE with classifier                       0.000000                0.000000
# CPA-based AE                             0.000000                0.000000
# direct translation AE                    0.000000                0.000000
#
#                             pre-similarity-trained VAE  AE with classifier  \
# direct translation                            0.000583            0.000330
# similarity-trained AE                         0.850107            0.520523
# similarity-trained VAE                        0.969850            0.427355
# pre-similarity-trained VAE                    1.000000            0.472676
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# direct translation                            0.000583            0.000330
# similarity-trained AE                         0.791337            0.623176
# similarity-trained VAE                        0.969850            0.520523
# pre-similarity-trained VAE                    1.000000            0.427355
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# direct translation                            0.000583            0.000330
# similarity-trained AE                         0.969850            0.570750
# similarity-trained VAE                        0.969850            0.344704
# pre-similarity-trained VAE                    1.000000            0.427355
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
#
#                             CPA-based AE  direct translation AE
# direct translation              0.000440               0.000440
# similarity-trained AE           0.791337               0.344704
# similarity-trained VAE          0.733730               0.850107
# pre-similarity-trained VAE      0.909722               0.791337
# AE with classifier              0.520523               0.212294
# CPA-based AE                    1.000000               0.520523
# direct translation AE           0.000000               1.000000
# direct translation              0.000769               0.000583
# similarity-trained AE           0.969850               0.520523
# similarity-trained VAE          0.909722               0.623176
# pre-similarity-trained VAE      0.969850               0.850107
# AE with classifier              0.623176               0.273036
# CPA-based AE                    1.000000               0.472676
# direct translation AE           0.000000               1.000000
# direct translation              0.001008               0.000583
# similarity-trained AE           1.000000               0.623176
# similarity-trained VAE          0.791337               0.733730
# pre-similarity-trained VAE      0.909722               0.733730
# AE with classifier              0.520523               0.241322
# CPA-based AE                    1.000000               0.472676
# direct translation AE           0.000000               1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','sign accuracy','model']
res_recon_ht29
# Out:
#     pearson  spearman  sign accuracy                       model
# 0  0.830313  0.775642       0.796885       similarity-trained AE
# 1  0.824589  0.761464       0.792661       similarity-trained AE
# 2  0.812255  0.762062       0.792232       similarity-trained AE
# 3  0.826020  0.771951       0.797735       similarity-trained AE
# 4  0.846574  0.804735       0.817642       similarity-trained AE
# 5  0.853151  0.811846       0.821536       similarity-trained AE
# 6  0.833748  0.793034       0.811242       similarity-trained AE
# 7  0.849627  0.814801       0.824357       similarity-trained AE
# 8  0.838561  0.800195       0.815394       similarity-trained AE
# 9  0.816862  0.760642       0.792421       similarity-trained AE
# 0  0.822774  0.762210       0.791508      similarity-trained VAE
# 1  0.809804  0.743418       0.785214      similarity-trained VAE
# 2  0.752126  0.657321       0.745642      similarity-trained VAE
# 3  0.722135  0.599709       0.724270      similarity-trained VAE
# 4  0.809746  0.748106       0.791022      similarity-trained VAE
# 5  0.843694  0.801087       0.817127      similarity-trained VAE
# 6  0.774423  0.707325       0.771637      similarity-trained VAE
# 7  0.784845  0.717525       0.779576      similarity-trained VAE
# 8  0.701056  0.626364       0.737812      similarity-trained VAE
# 9  0.722740  0.635768       0.739901      similarity-trained VAE
# 0  0.818976  0.752773       0.787572  pre-similarity-trained VAE
# 1  0.808245  0.734534       0.779723  pre-similarity-trained VAE
# 2  0.739298  0.644106       0.739686  pre-similarity-trained VAE
# 3  0.769390  0.676557       0.755426  pre-similarity-trained VAE
# 4  0.833149  0.786898       0.807971  pre-similarity-trained VAE
# 5  0.760569  0.679259       0.760621  pre-similarity-trained VAE
# 6  0.819579  0.774036       0.801770  pre-similarity-trained VAE
# 7  0.800889  0.739501       0.788419  pre-similarity-trained VAE
# 8  0.758285  0.693487       0.766529  pre-similarity-trained VAE
# 9  0.694587  0.604660       0.726555  pre-similarity-trained VAE
# 0  0.827002  0.773864       0.798444          AE with classifier
# 1  0.826619  0.761357       0.793032          AE with classifier
# 2  0.812226  0.765004       0.794210          AE with classifier
# 3  0.821476  0.761728       0.793955          AE with classifier
# 4  0.839975  0.801233       0.815781          AE with classifier
# 5  0.834089  0.799860       0.815556          AE with classifier
# 6  0.828883  0.787878       0.808918          AE with classifier
# 7  0.853530  0.814444       0.824053          AE with classifier
# 8  0.830389  0.791325       0.810530          AE with classifier
# 9  0.821980  0.773293       0.800246          AE with classifier
# 0  0.835393  0.783634       0.801952                CPA-based AE
# 1  0.821832  0.772010       0.796822                CPA-based AE
# 2  0.819998  0.770136       0.797072                CPA-based AE
# 3  0.831658  0.772910       0.799429                CPA-based AE
# 4  0.849340  0.809962       0.821331                CPA-based AE
# 5  0.852308  0.808809       0.820787                CPA-based AE
# 6  0.830061  0.788840       0.809169                CPA-based AE
# 7  0.853617  0.821611       0.827868                CPA-based AE
# 8  0.811054  0.766373       0.795509                CPA-based AE
# 9  0.818322  0.771057       0.797344                CPA-based AE
# 0  0.742100  0.651817       0.740773       direct translation AE
# 1  0.772833  0.675556       0.753520       direct translation AE
# 2  0.751067  0.655678       0.745960       direct translation AE
# 3  0.748587  0.641490       0.738277       direct translation AE
# 4  0.767007  0.694789       0.766442       direct translation AE
# 5  0.781454  0.703016       0.770715       direct translation AE
# 6  0.756632  0.685567       0.761529       direct translation AE
# 7  0.783028  0.715655       0.776806       direct translation AE
# 8  0.766207  0.708504       0.772060       direct translation AE
# 9  0.730897  0.656130       0.743420       direct translation AE

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#                      model         metric     value
# 0    similarity-trained AE        pearson  0.830313
# 1    similarity-trained AE        pearson  0.824589
# 2    similarity-trained AE        pearson  0.812255
# 3    similarity-trained AE        pearson  0.826020
# 4    similarity-trained AE        pearson  0.846574
# ..                     ...            ...       ...
# 175  direct translation AE  sign accuracy  0.770715
# 176  direct translation AE  sign accuracy  0.761529
# 177  direct translation AE  sign accuracy  0.776806
# 178  direct translation AE  sign accuracy  0.772060
# 179  direct translation AE  sign accuracy  0.743420
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_recon_ht29,
            order=['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='model')
#plt.ylim(0,1.0)
# Out:
# [Text(0.5, 1.0, ''),
#  Text(0.5, 0, 'Performance metric value'),
#  Text(0, 0.5, 'model')]

# %%
models = ['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-35-b8505db3e1c6>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-35-b8505db3e1c6>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-36-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-36-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='sign accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-37-9d6d1f9e8d53>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='sign accuracy'].value.values
# <ipython-input-37-9d6d1f9e8d53>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='sign accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE']]
ht29_reconstruction.to_csv('../results/my_results_10kgenes/ht29_all_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                                    metric  similarity-trained AE  \
# similarity-trained AE             pearson                    1.0
# similarity-trained VAE            pearson                    0.0
# pre-similarity-trained VAE        pearson                    0.0
# AE with classifier                pearson                    0.0
# CPA-based AE                      pearson                    0.0
# direct translation AE             pearson                    0.0
# similarity-trained AE            spearman                    1.0
# similarity-trained VAE           spearman                    0.0
# pre-similarity-trained VAE       spearman                    0.0
# AE with classifier               spearman                    0.0
# CPA-based AE                     spearman                    0.0
# direct translation AE            spearman                    0.0
# similarity-trained AE       sign accuracy                    1.0
# similarity-trained VAE      sign accuracy                    0.0
# pre-similarity-trained VAE  sign accuracy                    0.0
# AE with classifier          sign accuracy                    0.0
# CPA-based AE                sign accuracy                    0.0
# direct translation AE       sign accuracy                    0.0
#
#                             similarity-trained VAE  \
# similarity-trained AE                     0.002202
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
# similarity-trained AE                     0.002827
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
# similarity-trained AE                     0.001315
# similarity-trained VAE                    1.000000
# pre-similarity-trained VAE                0.000000
# AE with classifier                        0.000000
# CPA-based AE                              0.000000
# direct translation AE                     0.000000
#
#                             pre-similarity-trained VAE  AE with classifier  \
# similarity-trained AE                         0.002202            0.677585
# similarity-trained VAE                        0.909722            0.004586
# pre-similarity-trained VAE                    1.000000            0.002202
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# similarity-trained AE                         0.002202            0.791337
# similarity-trained VAE                        0.791337            0.002827
# pre-similarity-trained VAE                    1.000000            0.002827
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
# similarity-trained AE                         0.002827            0.909722
# similarity-trained VAE                        0.850107            0.002202
# pre-similarity-trained VAE                    1.000000            0.002827
# AE with classifier                            0.000000            1.000000
# CPA-based AE                                  0.000000            0.000000
# direct translation AE                         0.000000            0.000000
#
#                             CPA-based AE  direct translation AE
# similarity-trained AE           0.909722               0.000183
# similarity-trained VAE          0.003611               0.384673
# pre-similarity-trained VAE      0.002827               0.185877
# AE with classifier              0.850107               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000
# similarity-trained AE           0.850107               0.000183
# similarity-trained VAE          0.001315               0.384673
# pre-similarity-trained VAE      0.003611               0.212294
# AE with classifier              0.791337               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000
# similarity-trained AE           0.733730               0.000183
# similarity-trained VAE          0.001315               0.384673
# pre-similarity-trained VAE      0.003611               0.185877
# AE with classifier              0.733730               0.000183
# CPA-based AE                    1.000000               0.000183
# direct translation AE           0.000000               1.000000

# %% [markdown]
# # Combine the barplots from the two cell-lines into one figure with 2 panels

# %%
plt.rcParams["figure.figsize"] = (6, 3)

# %%
sns.set_theme(style="whitegrid",font_scale=1.5)

# Create subplots with 1 row and 2 columns
fig, axes = plt.subplots(1, 2)

ax = sns.barplot(ax=axes[0],x="value", y="model", data=res_to_a375,
            order=['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
axes[0].legend_.remove()

ax = sns.barplot(ax=axes[1],x="value", y="model", data=res_to_ht29,
            order=['direct translation',
                   'similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
axes[1].legend_.remove()

# Fix axes titles and ticks
axes[0].set_xlim([0.3, 0.75])  # Set x-limit for the first subplot
axes[0].set_xticks([0.3,0.4,0.5,0.6,0.7])  # Set x-ticks for the first subplot
axes[1].set_xlim([0.3, 0.75])  # Set x-limit for the second subplot
axes[1].set_xticks([0.3,0.4,0.5,0.6,0.7])  # Set x-ticks for the second subplot
axes[0].set_xlabel("")
axes[1].set_xlabel("")
axes[1].set_ylabel("")
axes[1].set_yticks([])

legend_labels = ['sign accuracy','pearson','spearman']
# Get the handles and labels from any of the subplots
handles, labels = axes[0].get_legend_handles_labels()
ax.legend(handles=handles, 
          labels=legend_labels, 
          title='', 
          loc='lower center', 
          bbox_to_anchor=(0, -0.5), 
          ncol=len(legend_labels), 
          frameon=False,
          fontsize='small')

# set titles
axes[0].title.set_text('A375')
axes[1].title.set_text('HT29')
fig.suptitle('Translation to',y=1.1)

# # Add a common x-axis label
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
plt.xticks([])
plt.xlabel("Performance metric value", labelpad=30)

# Remove borders of subplots
for ax in axes:
    ax.spines['right'].set_visible(False)
    #ax.spines['left'].set_visible(False)

plt.tight_layout()
# Adjust subplot spacing
# plt.subplots_adjust(wspace=1)

plt.savefig('../article_supplementary_info/supplementary_fig1a_translation.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
# Out:
# <ipython-input-40-40f454f2559b>:62: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6, 3)

# %%
sns.set_theme(style="whitegrid",font_scale=1.5)
# plt.figure(figsize=(9,12), dpi= 80)

# Create subplots with 1 row and 2 columns
fig, axes = plt.subplots(1, 2,sharex=False)

ax = sns.barplot(ax=axes[0],x="value", y="model", data=res_recon_a375,
            order=['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
axes[0].legend_.remove()

ax = sns.barplot(ax=axes[1],x="value", y="model", data=res_recon_ht29,
            order=['similarity-trained AE','similarity-trained VAE',
                   'pre-similarity-trained VAE','AE with classifier',
                   'CPA-based AE','direct translation AE'],
            hue="metric",ci=95,capsize=0.2,orient='h')
axes[1].legend_.remove()

# Fix axes titles and ticks
# For subplot 1
axes[0].set_xlim([0.5, 1.05])  # Set x-limit for the first subplot
axes[0].set_xticks([0.5,0.6,0.7,0.8,0.9,1])  # Set x-ticks for the first subplot
axes[0].set_xticklabels([0.5,0.6,0.7,0.8,0.9,1])
axes[0].set_xlabel("")
axes[0].set_ylabel("")

# For the second subplot
axes[1].set_xlim([0.5, 1.05])  # Set x-limit for the second subplot
axes[1].set_xticks([0.5,0.6,0.7,0.8,0.9,1])  # Set x-ticks for the second subplot
axes[1].set_xticklabels([0.5,0.6,0.7,0.8,0.9,1])
axes[1].set_xlabel("")
axes[1].set_ylabel("")
axes[1].set_yticks([])

legend_labels = ['sign accuracy','pearson','spearman']
# Get the handles and labels from any of the subplots
handles, labels = axes[0].get_legend_handles_labels()
ax.legend(handles=handles, 
          labels=legend_labels, 
          title='', 
          loc='lower center', 
          bbox_to_anchor=(0, -0.5), 
          ncol=len(legend_labels), 
          frameon=False,
          fontsize='small')

# set titles
axes[0].title.set_text('A375')
axes[1].title.set_text('HT29')
fig.suptitle('Reconstruction',y=1.1)

# # Add a common x-axis label
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
plt.xticks([])
plt.xlabel("Performance metric value", labelpad=30)

# Remove borders of subplots
for ax in axes:
    ax.spines['right'].set_visible(False)
    #ax.spines['left'].set_visible(False)

plt.tight_layout()
# Adjust subplot spacing
# plt.subplots_adjust(wspace=1)

plt.savefig('../article_supplementary_info/supplementary_fig1a_reconstruction.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
