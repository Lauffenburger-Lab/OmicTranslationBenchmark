# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import mannwhitneyu, normaltest
from statannotations.Annotator import Annotator
import statannot

# %% [markdown]
# # Compare DeepCellState variations

# %%
import seaborn as sns
sns.set()

# %%
res_dcs_noise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_withnoise.csv',index_col=0)
res_dcs_noise['model'] = 'DCS'
res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_no_noise.csv',index_col=0)
res_dcs_nonoise['model'] = 'DCS modified v1'
res_notvae_2encs = pd.read_csv('../results/my_results/landmarks_10foldvalidation_notvae_results1000ep512bs.csv',index_col=0)
res_notvae_2encs['model'] = 'similarity-trained Autoencoders'
res_dcs_direct = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_direct_and_l2similarity.csv',index_col=0)
res_dcs_direct['model'] = 'DCS modified v2'
baseline = pd.read_csv('../results/baseline_evaluation_landmarks.csv',index_col=0)
baseline = baseline.drop_duplicates()

# add mi
res_mi = pd.read_csv('../results/MI_results/landmarks_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
res_mi['model'] = 'InfoMax-based Autoencoders'

# %%
# add TransCompRmixedANNS
res_annTransCompR = pd.read_csv('../results/ANNmixedTransCompR_results/landmarks_10foldvalidation_ANNmixedTransCompR_500ep512bs_a375_ht29.csv',index_col=0)
res_annTransCompR['model'] = 'TransCompR-combined and InfoMax-based Autoencoders'

# %%
# # add mi
# res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_pc3_ha1e.csv',index_col=0)
# res_mi['model'] = 'Translation Model'

# res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_2000ep512bs_pc3_ha1e_withclass.csv',index_col=0)
# res_mi_class['model'] = 'Translation Model with classifier'

# %%
# res_dcs_noise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_withnoise.csv',index_col=0)
# res_dcs_noise['model'] = 'DCS'
# res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_no_noise.csv',index_col=0)
# res_dcs_nonoise['model'] = 'DCS modified v1'
# res_notvae_2encs = pd.read_csv('../results/my_results/landmarks_10foldvalidation_vae_results1000ep512bs.csv',index_col=0)
# res_notvae_2encs['model'] = 'Two Autoencoders'
# res_dcs_direct = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_direct_and_l2similarity.csv',index_col=0)
# res_dcs_direct['model'] = 'DCS modified v2'
# baseline = pd.read_csv('../results/baseline_evaluation_landmarks.csv',index_col=0)
# baseline = baseline.drop_duplicates()

# # # add mi
# # res_mi = pd.read_csv('../results/MI_results/landmarks_10foldvalidation_pretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
# 9        0.628630        0.628630
# 0        0.662602        0.662602
# 1        0.649719        0.649719
# 2        0.644760        0.644760
# 3        0.635813        0.635813
# 4        0.652991        0.652991
# 5        0.654422        0.654422
# 6        0.618277        0.618277
# 7        0.652275        0.652275
# 8        0.609995        0.609995
# 9        0.628630        0.628630
# 0        0.662730        0.662730
# 1        0.649847        0.649847
# 2        0.644836        0.644836
# 3        0.635890        0.635890
# 4        0.653144        0.653144
# 5        0.654525        0.654525
# 6        0.618405        0.618405
# 7        0.652428        0.652428
# 8        0.610148        0.610148
# 9        0.628809        0.628809
# 0        0.662602        0.662602
# 1        0.649719        0.649719
# 2        0.644760        0.644760
# 3        0.635813        0.635813
# 4        0.652991        0.652991
# 5        0.654422        0.654422
# 6        0.618277        0.618277
# 7        0.652275        0.652275
# 8        0.609995        0.609995
# 9        0.628630        0.628630
# 0        0.662730        0.662730
# 1        0.649847        0.649847
# 2        0.644836        0.644836
# 3        0.635890        0.635890
# 4        0.653144        0.653144
# 5        0.654525        0.654525
# 6        0.618405        0.618405
# 7        0.652428        0.652428
# 8        0.610148        0.610148
# 9        0.628809        0.628809
# 0        0.662730        0.662730
# 1        0.649847        0.649847
# 2        0.644836        0.644836
# 3        0.635890        0.635890
# 4        0.653144        0.653144
# 5        0.654525        0.654525
# 6        0.618405        0.618405
# 7        0.652428        0.652428
# 8        0.610148        0.610148
# 9        0.628809        0.628809
#
#                                                model
# 0                                                DCS
# 1                                                DCS
# 2                                                DCS
# 3                                                DCS
# 4                                                DCS
# 5                                                DCS
# 6                                                DCS
# 7                                                DCS
# 8                                                DCS
# 9                                                DCS
# 0                                    DCS modified v1
# 1                                    DCS modified v1
# 2                                    DCS modified v1
# 3                                    DCS modified v1
# 4                                    DCS modified v1
# 5                                    DCS modified v1
# 6                                    DCS modified v1
# 7                                    DCS modified v1
# 8                                    DCS modified v1
# 9                                    DCS modified v1
# 0                    similarity-trained Autoencoders
# 1                    similarity-trained Autoencoders
# 2                    similarity-trained Autoencoders
# 3                    similarity-trained Autoencoders
# 4                    similarity-trained Autoencoders
# 5                    similarity-trained Autoencoders
# 6                    similarity-trained Autoencoders
# 7                    similarity-trained Autoencoders
# 8                    similarity-trained Autoencoders
# 9                    similarity-trained Autoencoders
# 0                                    DCS modified v2
# 1                                    DCS modified v2
# 2                                    DCS modified v2
# 3                                    DCS modified v2
# 4                                    DCS modified v2
# 5                                    DCS modified v2
# 6                                    DCS modified v2
# 7                                    DCS modified v2
# 8                                    DCS modified v2
# 9                                    DCS modified v2
# 0                         InfoMax-based Autoencoders
# 1                         InfoMax-based Autoencoders
# 2                         InfoMax-based Autoencoders
# 3                         InfoMax-based Autoencoders
# 4                         InfoMax-based Autoencoders
# 5                         InfoMax-based Autoencoders
# 6                         InfoMax-based Autoencoders
# 7                         InfoMax-based Autoencoders
# 8                         InfoMax-based Autoencoders
# 9                         InfoMax-based Autoencoders
# 0  TransCompR-combined and InfoMax-based Autoenco...
# 1  TransCompR-combined and InfoMax-based Autoenco...
# 2  TransCompR-combined and InfoMax-based Autoenco...
# 3  TransCompR-combined and InfoMax-based Autoenco...
# 4  TransCompR-combined and InfoMax-based Autoenco...
# 5  TransCompR-combined and InfoMax-based Autoenco...
# 6  TransCompR-combined and InfoMax-based Autoenco...
# 7  TransCompR-combined and InfoMax-based Autoenco...
# 8  TransCompR-combined and InfoMax-based Autoenco...
# 9  TransCompR-combined and InfoMax-based Autoenco...

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline],axis=0)
res_to_a375
# Out:
#      pearson  spearman  accuracy               model
# 0   0.571852  0.515097  0.684765                 DCS
# 1   0.530438  0.466992  0.665210                 DCS
# 2   0.561118  0.488067  0.665746                 DCS
# 3   0.492172  0.435180  0.651815                 DCS
# 4   0.588295  0.482839  0.667408                 DCS
# ..       ...       ...       ...                 ...
# 5   0.456026  0.433163  0.654525  direct translation
# 6   0.391251  0.353916  0.618405  direct translation
# 7   0.455651  0.433182  0.652428  direct translation
# 8   0.373686  0.337688  0.610148  direct translation
# 9   0.413972  0.372399  0.628809  direct translation
#
# [70 rows x 4 columns]

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#                   model    metric     value
# 0                   DCS   pearson  0.571852
# 1                   DCS   pearson  0.530438
# 2                   DCS   pearson  0.561118
# 3                   DCS   pearson  0.492172
# 4                   DCS   pearson  0.588295
# ..                  ...       ...       ...
# 205  direct translation  accuracy  0.654525
# 206  direct translation  accuracy  0.618405
# 207  direct translation  accuracy  0.652428
# 208  direct translation  accuracy  0.610148
# 209  direct translation  accuracy  0.628809
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.25)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_to_a375,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','InfoMax-based Autoencoders',
                   'TransCompR-combined and InfoMax-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
# statannot.add_stat_annotation(ax=ax, 
#                               data=res_to_a375,
#                               y="value",
#                               x="model",
#                               order=['direct translation','DCS',
#                                      'DCS modified v1','DCS modified v2',
#                                      'similarity-trained Autoencoders','GAN-based Autoencoders',
#                                      'TransCompR-combined and GAN-based Autoencoders'],
#                               hue_order = ['accuracy','pearson','spearman'],
#                               hue="metric",
#                               box_pairs=[
#                                   (("DCS", "pearson"), ("similarity-trained Autoencoders","pearson"))],
#                               test="Mann-Whitney",
#                               loc = 'inside',
#                               verbose=0
#                              )
plt.savefig('../figures/MI_results/landmarks_autoencoders_compare_a375.png', bbox_inches='tight',dpi=600)

# %%
from scipy import stats

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders',
          'direct translation','InfoMax-based Autoencoders',
          'TransCompR-combined and InfoMax-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-12-b63209060681>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-12-b63209060681>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-13-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-13-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-14-748d6dd7cfa5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
# <ipython-input-14-748d6dd7cfa5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']]
a375_translate.to_csv('../results/MI_results/landmarks_a375_autoencoders_comparison_translation_pvalues_table.csv')
a375_translate
# Out:
#                                                       metric  DCS  \
# DCS                                                  pearson  1.0
# DCS modified v1                                      pearson  0.0
# DCS modified v2                                      pearson  0.0
# similarity-trained Autoencoders                      pearson  0.0
# direct translation                                   pearson  0.0
# InfoMax-based Autoencoders                           pearson  0.0
# TransCompR-combined and InfoMax-based Autoencoders   pearson  0.0
# DCS                                                 spearman  1.0
# DCS modified v1                                     spearman  0.0
# DCS modified v2                                     spearman  0.0
# similarity-trained Autoencoders                     spearman  0.0
# direct translation                                  spearman  0.0
# InfoMax-based Autoencoders                          spearman  0.0
# TransCompR-combined and InfoMax-based Autoencoders  spearman  0.0
# DCS                                                 accuracy  1.0
# DCS modified v1                                     accuracy  0.0
# DCS modified v2                                     accuracy  0.0
# similarity-trained Autoencoders                     accuracy  0.0
# direct translation                                  accuracy  0.0
# InfoMax-based Autoencoders                          accuracy  0.0
# TransCompR-combined and InfoMax-based Autoencoders  accuracy  0.0
#
#                                                     DCS modified v1  \
# DCS                                                        0.003611
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.003611
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.005795
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     DCS modified v2  \
# DCS                                                        0.000330
# DCS modified v1                                            0.212294
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000246
# DCS modified v1                                            0.185877
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000246
# DCS modified v1                                            0.088973
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     similarity-trained Autoencoders  \
# DCS                                                                        0.000183
# DCS modified v1                                                            0.121225
# DCS modified v2                                                            0.733730
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000246
# DCS modified v1                                                            0.185877
# DCS modified v2                                                            0.909722
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000246
# DCS modified v1                                                            0.075662
# DCS modified v2                                                            0.909722
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
#
#                                                     direct translation  \
# DCS                                                           0.088973
# DCS modified v1                                               0.000440
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
# DCS                                                           0.037635
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
# DCS                                                           0.064022
# DCS modified v1                                               0.000330
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
#
#                                                     InfoMax-based Autoencoders  \
# DCS                                                                   0.000246
# DCS modified v1                                                       0.121225
# DCS modified v2                                                       0.791337
# similarity-trained Autoencoders                                       0.850107
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000246
# DCS modified v1                                                       0.273036
# DCS modified v2                                                       1.000000
# similarity-trained Autoencoders                                       0.733730
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000330
# DCS modified v1                                                       0.121225
# DCS modified v2                                                       1.000000
# similarity-trained Autoencoders                                       0.850107
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
#
#                                                     TransCompR-combined and InfoMax-based Autoencoders
# DCS                                                                                          0.000246
# DCS modified v1                                                                              0.104110
# DCS modified v2                                                                              0.570750
# similarity-trained Autoencoders                                                              0.969850
# direct translation                                                                           0.000183
# InfoMax-based Autoencoders                                                                   0.791337
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000246
# DCS modified v1                                                                              0.104110
# DCS modified v2                                                                              0.791337
# similarity-trained Autoencoders                                                              0.733730
# direct translation                                                                           0.000183
# InfoMax-based Autoencoders                                                                   0.677585
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000246
# DCS modified v1                                                                              0.064022
# DCS modified v2                                                                              0.733730
# similarity-trained Autoencoders                                                              0.791337
# direct translation                                                                           0.000183
# 7                                    DCS modified v1
# 8                                    DCS modified v1
# 9                                    DCS modified v1
# 0                    similarity-trained Autoencoders
# 1                    similarity-trained Autoencoders
# 2                    similarity-trained Autoencoders
# 3                    similarity-trained Autoencoders
# 4                    similarity-trained Autoencoders
# 5                    similarity-trained Autoencoders
# 6                    similarity-trained Autoencoders
# 7                    similarity-trained Autoencoders
# 8                    similarity-trained Autoencoders
# 9                    similarity-trained Autoencoders
# 0                                    DCS modified v2
# 1                                    DCS modified v2
# 2                                    DCS modified v2
# 3                                    DCS modified v2
# 4                                    DCS modified v2
# 5                                    DCS modified v2
# 6                                    DCS modified v2
# 7                                    DCS modified v2
# 8                                    DCS modified v2
# 9                                    DCS modified v2
# 0                         InfoMax-based Autoencoders
# 1                         InfoMax-based Autoencoders
# 2                         InfoMax-based Autoencoders
# 3                         InfoMax-based Autoencoders
# 4                         InfoMax-based Autoencoders
# 5                         InfoMax-based Autoencoders
# 6                         InfoMax-based Autoencoders
# 7                         InfoMax-based Autoencoders
# 8                         InfoMax-based Autoencoders
# 9                         InfoMax-based Autoencoders
# 0  TransCompR-combined and InfoMax-based Autoenco...
# 1  TransCompR-combined and InfoMax-based Autoenco...
# 2  TransCompR-combined and InfoMax-based Autoenco...
# 3  TransCompR-combined and InfoMax-based Autoenco...
# 4  TransCompR-combined and InfoMax-based Autoenco...
# 5  TransCompR-combined and InfoMax-based Autoenco...
# 6  TransCompR-combined and InfoMax-based Autoenco...
# 7  TransCompR-combined and InfoMax-based Autoenco...
# 8  TransCompR-combined and InfoMax-based Autoenco...
# 9  TransCompR-combined and InfoMax-based Autoenco...

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#                                                  model    metric     value
# 0                                                  DCS   pearson  0.995403
# 1                                                  DCS   pearson  0.995315
# 2                                                  DCS   pearson  0.995380
# 3                                                  DCS   pearson  0.995497
# 4                                                  DCS   pearson  0.995651
# ..                                                 ...       ...       ...
# 175  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.791505
# 176  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.787696
# 177  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.790883
# 178  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.789017
# 179  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.778792
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_recon_a375,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','InfoMax-based Autoencoders',
                   'TransCompR-combined and InfoMax-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/landmarks_10fold_validation_reconstruction_autoencoders_comparison_a375.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-19-24f92d05a7d3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-19-24f92d05a7d3>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-20-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-20-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-21-7bf8ce6c3d50>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
# <ipython-input-21-7bf8ce6c3d50>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']]
a375_reconstruction.to_csv('../results/MI_results/landmarks_a375_autoencoders_comparison_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                                                       metric  DCS  \
# DCS                                                  pearson  1.0
# DCS modified v1                                      pearson  0.0
# DCS modified v2                                      pearson  0.0
# similarity-trained Autoencoders                      pearson  0.0
# InfoMax-based Autoencoders                           pearson  0.0
# TransCompR-combined and InfoMax-based Autoencoders   pearson  0.0
# DCS                                                 spearman  1.0
# DCS modified v1                                     spearman  0.0
# DCS modified v2                                     spearman  0.0
# similarity-trained Autoencoders                     spearman  0.0
# InfoMax-based Autoencoders                          spearman  0.0
# TransCompR-combined and InfoMax-based Autoencoders  spearman  0.0
# DCS                                                 accuracy  1.0
# DCS modified v1                                     accuracy  0.0
# DCS modified v2                                     accuracy  0.0
# similarity-trained Autoencoders                     accuracy  0.0
# InfoMax-based Autoencoders                          accuracy  0.0
# TransCompR-combined and InfoMax-based Autoencoders  accuracy  0.0
#
#                                                     DCS modified v1  \
# DCS                                                        0.003611
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000182
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     DCS modified v2  \
# DCS                                                        0.000330
# DCS modified v1                                            0.212294
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            0.000183
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000182
# DCS modified v1                                            0.000183
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     similarity-trained Autoencoders  \
# DCS                                                                        0.000183
# DCS modified v1                                                            0.121225
# DCS modified v2                                                            0.733730
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000183
# DCS modified v1                                                            0.017257
# DCS modified v2                                                            0.000183
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000182
# DCS modified v1                                                            0.017257
# DCS modified v2                                                            0.000183
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
#
#                                                     InfoMax-based Autoencoders  \
# DCS                                                                   0.000246
# DCS modified v1                                                       0.121225
# DCS modified v2                                                       0.791337
# similarity-trained Autoencoders                                       0.850107
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000183
# DCS modified v1                                                       0.021134
# DCS modified v2                                                       0.000183
# similarity-trained Autoencoders                                       1.000000
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000182
# DCS modified v1                                                       0.037635
# DCS modified v2                                                       0.000183
# similarity-trained Autoencoders                                       0.909722
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
#
#                                                     TransCompR-combined and InfoMax-based Autoencoders
# DCS                                                                                          0.000246
# DCS modified v1                                                                              0.104110
# DCS modified v2                                                                              0.570750
# similarity-trained Autoencoders                                                              0.969850
# InfoMax-based Autoencoders                                                                   0.791337
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000183
# DCS modified v1                                                                              0.021134
# DCS modified v2                                                                              0.000183
# similarity-trained Autoencoders                                                              0.344704
# InfoMax-based Autoencoders                                                                   0.427355
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000182
# DCS modified v1                                                                              0.064022
# DCS modified v2                                                                              0.000183
# similarity-trained Autoencoders                                                              0.384673
# InfoMax-based Autoencoders                                                                   0.427355
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline],axis=0)
res_to_ht29
# Out:
#      pearson  spearman  accuracy               model
# 0   0.578932  0.518443  0.682975                 DCS
# 1   0.533776  0.465651  0.665491                 DCS
# 2   0.567735  0.490919  0.666232                 DCS
# 3   0.499116  0.437531  0.653809                 DCS
# 4   0.597630  0.492726  0.673185                 DCS
# ..       ...       ...       ...                 ...
# 5   0.456026  0.433163  0.654525  direct translation
# 6   0.391251  0.353916  0.618405  direct translation
# 7   0.455651  0.433182  0.652428  direct translation
# 8   0.373686  0.337688  0.610148  direct translation
# 9   0.413972  0.372399  0.628809  direct translation
#
# [70 rows x 4 columns]

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#                   model    metric     value
# 0                   DCS   pearson  0.578932
# 1                   DCS   pearson  0.533776
# 2                   DCS   pearson  0.567735
# 3                   DCS   pearson  0.499116
# 4                   DCS   pearson  0.597630
# ..                  ...       ...       ...
# 205  direct translation  accuracy  0.654525
# 206  direct translation  accuracy  0.618405
# 207  direct translation  accuracy  0.652428
# 208  direct translation  accuracy  0.610148
# 209  direct translation  accuracy  0.628809
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_to_ht29,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','InfoMax-based Autoencoders',
                   'TransCompR-combined and InfoMax-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/landmarks_10fold_validation_autoencoders_comparison_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-26-5fcdfe964499>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-26-5fcdfe964499>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-27-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-27-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-28-c5c1bf237c12>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
# <ipython-input-28-c5c1bf237c12>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']]
ht29_translate.to_csv('../results/MI_results/landmarks_ht29_autoencoders_comparison_translation_pvalues_table.csv')
ht29_translate
# Out:
#                                                       metric  DCS  \
# DCS                                                  pearson  1.0
# DCS modified v1                                      pearson  0.0
# DCS modified v2                                      pearson  0.0
# similarity-trained Autoencoders                      pearson  0.0
# direct translation                                   pearson  0.0
# InfoMax-based Autoencoders                           pearson  0.0
# TransCompR-combined and InfoMax-based Autoencoders   pearson  0.0
# DCS                                                 spearman  1.0
# DCS modified v1                                     spearman  0.0
# DCS modified v2                                     spearman  0.0
# similarity-trained Autoencoders                     spearman  0.0
# direct translation                                  spearman  0.0
# InfoMax-based Autoencoders                          spearman  0.0
# TransCompR-combined and InfoMax-based Autoencoders  spearman  0.0
# DCS                                                 accuracy  1.0
# DCS modified v1                                     accuracy  0.0
# DCS modified v2                                     accuracy  0.0
# similarity-trained Autoencoders                     accuracy  0.0
# direct translation                                  accuracy  0.0
# InfoMax-based Autoencoders                          accuracy  0.0
# TransCompR-combined and InfoMax-based Autoencoders  accuracy  0.0
#
#                                                     DCS modified v1  \
# DCS                                                        0.002202
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.001008
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.003611
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     DCS modified v2  \
# DCS                                                        0.000183
# DCS modified v1                                            0.045155
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            0.185877
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000246
# DCS modified v1                                            0.140465
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# direct translation                                         0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     similarity-trained Autoencoders  \
# DCS                                                                        0.000183
# DCS modified v1                                                            0.025748
# DCS modified v2                                                            0.623176
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000183
# DCS modified v1                                                            0.212294
# DCS modified v2                                                            0.850107
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000183
# DCS modified v1                                                            0.140465
# DCS modified v2                                                            1.000000
# similarity-trained Autoencoders                                            1.000000
# direct translation                                                         0.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
#
#                                                     direct translation  \
# DCS                                                           0.075662
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
# DCS                                                           0.031209
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
# DCS                                                           0.045155
# DCS modified v1                                               0.000246
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.000183
# direct translation                                            1.000000
# InfoMax-based Autoencoders                                    0.000000
# TransCompR-combined and InfoMax-based Autoencoders            0.000000
#
#                                                     InfoMax-based Autoencoders  \
# DCS                                                                   0.000183
# DCS modified v1                                                       0.021134
# DCS modified v2                                                       0.677585
# similarity-trained Autoencoders                                       0.909722
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000183
# DCS modified v1                                                       0.212294
# DCS modified v2                                                       0.969850
# similarity-trained Autoencoders                                       0.909722
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000246
# DCS modified v1                                                       0.185877
# DCS modified v2                                                       0.909722
# similarity-trained Autoencoders                                       0.969850
# direct translation                                                    0.000183
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
#
#                                                     TransCompR-combined and InfoMax-based Autoencoders
# DCS                                                                                          0.000183
# DCS modified v1                                                                              0.031209
# DCS modified v2                                                                              0.733730
# similarity-trained Autoencoders                                                              1.000000
# direct translation                                                                           0.000183
# InfoMax-based Autoencoders                                                                   0.850107
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000246
# DCS modified v1                                                                              0.185877
# DCS modified v2                                                                              1.000000
# similarity-trained Autoencoders                                                              0.791337
# direct translation                                                                           0.000183
# InfoMax-based Autoencoders                                                                   0.733730
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000583
# DCS modified v1                                                                              0.140465
# DCS modified v2                                                                              0.850107
# similarity-trained Autoencoders                                                              0.733730
# direct translation                                                                           0.000183
# InfoMax-based Autoencoders                                                                   0.791337
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','accuracy','model']
res_recon_ht29
# Out:
#     pearson  spearman  accuracy  \
# 0  0.995590  0.994586  0.968163
# 1  0.995553  0.994415  0.966193
# 2  0.995337  0.994434  0.966927
# 3  0.995539  0.994217  0.966732
# 4  0.995768  0.994716  0.970645
# 5  0.995763  0.994690  0.969613
# 6  0.995875  0.994665  0.968777
# 7  0.995881  0.994811  0.970357
# 8  0.995477  0.994341  0.967754
# 9  0.995335  0.994204  0.966862
# 0  0.842648  0.791356  0.804192
# 1  0.836692  0.772504  0.795241
# 2  0.824746  0.762092  0.789896
# 3  0.829919  0.764813  0.793512
# 4  0.848621  0.797513  0.814770
# 5  0.847044  0.794397  0.810727
# 6  0.841623  0.789309  0.809797
# 7  0.852933  0.805181  0.819046
# 8  0.829362  0.783593  0.804666
# 9  0.829450  0.771960  0.795771
# 0  0.835342  0.779589  0.798978
# 1  0.824906  0.758185  0.789682
# 2  0.806941  0.746039  0.779820
# 3  0.820321  0.755486  0.788399
# 4  0.837311  0.782229  0.805336
# 5  0.837943  0.784522  0.808347
# 6  0.836852  0.784206  0.808031
# 7  0.842142  0.785961  0.811954
# 8  0.819279  0.770689  0.798206
# 9  0.815645  0.758789  0.790463
# 0  0.777120  0.703462  0.759630
# 1  0.774754  0.689518  0.752361
# 2  0.753705  0.680977  0.752491
# 3  0.757096  0.662595  0.744088
# 4  0.785107  0.713340  0.769818
# 5  0.773984  0.703518  0.768275
# 6  0.782978  0.706388  0.767959
# 7  0.788455  0.726835  0.779336
# 8  0.752849  0.696428  0.762512
# 9  0.763017  0.687984  0.754527
# 0  0.834316  0.779212  0.798373
# 1  0.823490  0.761229  0.790807
# 2  0.802314  0.740124  0.778509
# 3  0.817232  0.751979  0.788158
# 4  0.836160  0.782262  0.806981
# 5  0.837946  0.784436  0.807883
# 6  0.836553  0.780629  0.805205
# 7  0.844214  0.794396  0.816629
# 8  0.816366  0.768773  0.795120
# 9  0.812918  0.757548  0.788381
# 0  0.830352  0.779403  0.796951
# 1  0.815242  0.757887  0.787219
# 2  0.803268  0.755668  0.783649
# 3  0.816007  0.753521  0.787275
# 4  0.839819  0.790289  0.811694
# 5  0.834846  0.787215  0.809221
# 6  0.832940  0.783311  0.805540
# 7  0.841136  0.801203  0.817903
# 8  0.813914  0.772925  0.800112
# 9  0.810576  0.757113  0.787684
#
#                                                model
# 0                                                DCS
# 1                                                DCS
# 2                                                DCS
# 3                                                DCS
# 4                                                DCS
# 5                                                DCS
# 6                                                DCS
# 7                                                DCS
# 8                                                DCS
# 9                                                DCS
# 0                                    DCS modified v1
# 1                                    DCS modified v1
# 2                                    DCS modified v1
# 3                                    DCS modified v1
# 4                                    DCS modified v1
# 5                                    DCS modified v1
# 6                                    DCS modified v1
# 7                                    DCS modified v1
# 8                                    DCS modified v1
# 9                                    DCS modified v1
# 0                    similarity-trained Autoencoders
# 1                    similarity-trained Autoencoders
# 2                    similarity-trained Autoencoders
# 3                    similarity-trained Autoencoders
# 4                    similarity-trained Autoencoders
# 5                    similarity-trained Autoencoders
# 6                    similarity-trained Autoencoders
# 7                    similarity-trained Autoencoders
# 8                    similarity-trained Autoencoders
# 9                    similarity-trained Autoencoders
# 0                                    DCS modified v2
# 1                                    DCS modified v2
# 2                                    DCS modified v2
# 3                                    DCS modified v2
# 4                                    DCS modified v2
# 5                                    DCS modified v2
# 6                                    DCS modified v2
# 7                                    DCS modified v2
# 8                                    DCS modified v2
# 9                                    DCS modified v2
# 0                         InfoMax-based Autoencoders
# 1                         InfoMax-based Autoencoders
# 2                         InfoMax-based Autoencoders
# 3                         InfoMax-based Autoencoders
# 4                         InfoMax-based Autoencoders
# 5                         InfoMax-based Autoencoders
# 6                         InfoMax-based Autoencoders
# 7                         InfoMax-based Autoencoders
# 8                         InfoMax-based Autoencoders
# 9                         InfoMax-based Autoencoders
# 0  TransCompR-combined and InfoMax-based Autoenco...
# 1  TransCompR-combined and InfoMax-based Autoenco...
# 2  TransCompR-combined and InfoMax-based Autoenco...
# 3  TransCompR-combined and InfoMax-based Autoenco...
# 4  TransCompR-combined and InfoMax-based Autoenco...
# 5  TransCompR-combined and InfoMax-based Autoenco...
# 6  TransCompR-combined and InfoMax-based Autoenco...
# 7  TransCompR-combined and InfoMax-based Autoenco...
# 8  TransCompR-combined and InfoMax-based Autoenco...
# 9  TransCompR-combined and InfoMax-based Autoenco...

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#                                                  model    metric     value
# 0                                                  DCS   pearson  0.995590
# 1                                                  DCS   pearson  0.995553
# 2                                                  DCS   pearson  0.995337
# 3                                                  DCS   pearson  0.995539
# 4                                                  DCS   pearson  0.995768
# ..                                                 ...       ...       ...
# 175  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.809221
# 176  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.805540
# 177  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.817903
# 178  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.800112
# 179  TransCompR-combined and InfoMax-based Autoenco...  accuracy  0.787684
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_recon_ht29,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','InfoMax-based Autoencoders',
                   'TransCompR-combined and InfoMax-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/landmarks_10fold_validation_reconstruction_autoencoders_comparison_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-33-c30164c18060>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-33-c30164c18060>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-34-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-34-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-35-12b8fd9ef33b>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
# <ipython-input-35-12b8fd9ef33b>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','InfoMax-based Autoencoders','TransCompR-combined and InfoMax-based Autoencoders']]
ht29_reconstruction.to_csv('../results/MI_results/landmarks_ht29_autoencoders_comparison_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                                                       metric  DCS  \
# DCS                                                  pearson  1.0
# DCS modified v1                                      pearson  0.0
# DCS modified v2                                      pearson  0.0
# similarity-trained Autoencoders                      pearson  0.0
# InfoMax-based Autoencoders                           pearson  0.0
# TransCompR-combined and InfoMax-based Autoencoders   pearson  0.0
# DCS                                                 spearman  1.0
# DCS modified v1                                     spearman  0.0
# DCS modified v2                                     spearman  0.0
# similarity-trained Autoencoders                     spearman  0.0
# InfoMax-based Autoencoders                          spearman  0.0
# TransCompR-combined and InfoMax-based Autoencoders  spearman  0.0
# DCS                                                 accuracy  1.0
# DCS modified v1                                     accuracy  0.0
# DCS modified v2                                     accuracy  0.0
# similarity-trained Autoencoders                     accuracy  0.0
# InfoMax-based Autoencoders                          accuracy  0.0
# TransCompR-combined and InfoMax-based Autoencoders  accuracy  0.0
#
#                                                     DCS modified v1  \
# DCS                                                        0.000183
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            1.000000
# DCS modified v2                                            0.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     DCS modified v2  \
# DCS                                                        0.000183
# DCS modified v1                                            0.000183
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            0.000183
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
# DCS                                                        0.000183
# DCS modified v1                                            0.000183
# DCS modified v2                                            1.000000
# similarity-trained Autoencoders                            0.000000
# InfoMax-based Autoencoders                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders         0.000000
#
#                                                     similarity-trained Autoencoders  \
# DCS                                                                        0.000183
# DCS modified v1                                                            0.075662
# DCS modified v2                                                            0.000183
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000183
# DCS modified v1                                                            0.064022
# DCS modified v2                                                            0.000183
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
# DCS                                                                        0.000183
# DCS modified v1                                                            0.273036
# DCS modified v2                                                            0.000183
# similarity-trained Autoencoders                                            1.000000
# InfoMax-based Autoencoders                                                 0.000000
# TransCompR-combined and InfoMax-based Autoencoders                         0.000000
#
#                                                     InfoMax-based Autoencoders  \
# DCS                                                                   0.000183
# DCS modified v1                                                       0.053903
# DCS modified v2                                                       0.000183
# similarity-trained Autoencoders                                       0.733730
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000183
# DCS modified v1                                                       0.075662
# DCS modified v2                                                       0.000183
# similarity-trained Autoencoders                                       0.850107
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
# DCS                                                                   0.000183
# DCS modified v1                                                       0.241322
# DCS modified v2                                                       0.000246
# similarity-trained Autoencoders                                       0.733730
# InfoMax-based Autoencoders                                            1.000000
# TransCompR-combined and InfoMax-based Autoencoders                    0.000000
#
#                                                     TransCompR-combined and InfoMax-based Autoencoders
# DCS                                                                                          0.000183
# DCS modified v1                                                                              0.037635
# DCS modified v2                                                                              0.000183
# similarity-trained Autoencoders                                                              0.384673
# InfoMax-based Autoencoders                                                                   0.570750
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000183
# DCS modified v1                                                                              0.185877
# DCS modified v2                                                                              0.000183
# similarity-trained Autoencoders                                                              0.791337
# InfoMax-based Autoencoders                                                                   0.677585
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
# DCS                                                                                          0.000183
# DCS modified v1                                                                              0.344704
# DCS modified v2                                                                              0.000183
# similarity-trained Autoencoders                                                              0.969850
# InfoMax-based Autoencoders                                                                   1.000000
# TransCompR-combined and InfoMax-based Autoencoders                                           1.000000
