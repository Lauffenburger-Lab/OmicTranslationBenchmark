# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Compare CPA, Non CPA with classifier and TransCompR

# %%
import seaborn as sns
sns.set()

# %%
res_cpa = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_withCPA_1000ep512bs_a375_ht29.csv',index_col=0)
res_cpa['model'] = 'CPA'
res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
res_mi['model'] = 'similarity-trained Autoencoders'
res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_ht29_a375_withclass.csv',index_col=0)
res_mi_class['model'] = 'Autoencoders with classifier'
res_transCompR = pd.read_csv('../results/TransCompR_results/allgenes_10foldvalidation_transcompr_decoders_1000ep512bs_a375_ht29.csv',index_col=0)
res_transCompR['model'] = 'TransCompR'
baseline = pd.read_csv('../results/baseline_evaluation_allgenes.csv',index_col=0)
baseline = baseline.drop_duplicates()

# %%
results = pd.concat([res_cpa,res_mi,res_mi_class,res_transCompR],axis=0)
results
# Out:
#    F1_score  ClassAccuracy  model_pearsonHT29  model_pearsonA375  \
# 0       1.0            1.0           0.673932           0.549015
# 1       1.0            1.0           0.589004           0.549911
# 2       1.0            1.0           0.676635           0.639625
# 3       1.0            1.0           0.550606           0.558759
# 4       1.0            1.0           0.621177           0.630697
# 5       1.0            1.0           0.592926           0.539691
# 6       1.0            1.0           0.501435           0.437838
# 7       1.0            1.0           0.631147           0.564606
# 8       1.0            1.0           0.489493           0.370766
# 9       1.0            1.0           0.549553           0.510040
# 0       NaN            NaN           0.667348           0.574139
# 1       NaN            NaN           0.577154           0.590913
# 2       NaN            NaN           0.706598           0.637148
# 3       NaN            NaN           0.593213           0.588596
# 4       NaN            NaN           0.654452           0.635853
# 5       NaN            NaN           0.575751           0.552753
# 6       NaN            NaN           0.528944           0.440748
# 7       NaN            NaN           0.632949           0.566633
# 8       NaN            NaN           0.505198           0.405110
# 9       NaN            NaN           0.573678           0.519431
# 0       NaN            NaN           0.674442           0.570235
# 1       NaN            NaN           0.599027           0.583896
# 2       NaN            NaN           0.705431           0.643685
# 3       NaN            NaN           0.596755           0.586761
# 4       NaN            NaN           0.646739           0.640250
# 5       NaN            NaN           0.570010           0.541169
# 6       NaN            NaN           0.529065           0.476808
# 7       NaN            NaN           0.648193           0.576124
# 8       NaN            NaN           0.517324           0.409533
# 9       NaN            NaN           0.574006           0.546425
# 0       NaN            NaN           0.646988           0.559911
# 1       NaN            NaN           0.580043           0.597295
# 2       NaN            NaN           0.678701           0.633806
# 3       NaN            NaN           0.589427           0.578064
# 4       NaN            NaN           0.661613           0.646906
# 5       NaN            NaN           0.572714           0.552361
# 6       NaN            NaN           0.517275           0.448766
# 7       NaN            NaN           0.613800           0.578690
# 8       NaN            NaN           0.504796           0.400220
# 9       NaN            NaN           0.547518           0.513790
#
#    model_spearHT29  model_spearA375  model_accHT29  model_accA375  \
# 0         0.562946         0.449530       0.701321       0.656841
# 1         0.479765         0.424332       0.668531       0.650932
# 2         0.570473         0.540096       0.702578       0.690789
# 3         0.439052         0.443280       0.653401       0.658281
# 4         0.519464         0.531267       0.685294       0.692043
# 5         0.508504         0.434678       0.680805       0.652499
# 6         0.394468         0.360564       0.636266       0.622189
# 7         0.526179         0.428213       0.689054       0.648810
# 8         0.379147         0.286545       0.628200       0.592782
# 9         0.444448         0.428244       0.652375       0.652080
# 0         0.577731         0.494421       0.704729       0.673265
# 1         0.459355         0.453064       0.658361       0.661112
# 2         0.601433         0.540541       0.716949       0.686692
# 3         0.456560         0.473792       0.660867       0.671086
# 4         0.557725         0.535623       0.701383       0.690730
# 5         0.485382         0.432631       0.672650       0.651852
# 6         0.433714         0.379072       0.651624       0.629179
# 7         0.544343         0.452295       0.694205       0.656526
# 8         0.386525         0.325354       0.628820       0.606410
# 9         0.461137         0.425053       0.657622       0.651626
# 0         0.569433         0.488278       0.703659       0.671954
# 1         0.490749         0.452875       0.671413       0.664183
# 2         0.591212         0.554409       0.713033       0.696681
# 3         0.469937         0.469025       0.665675       0.668766
# 4         0.534608         0.540724       0.692576       0.693203
# 5         0.489358         0.429460       0.672199       0.650312
# 6         0.427845         0.392704       0.648721       0.632456
# 7         0.561575         0.456567       0.703091       0.659627
# 8         0.399560         0.332204       0.634600       0.607860
# 9         0.465308         0.444518       0.662983       0.657942
# 0         0.553253         0.492247       0.694567       0.673555
# 1         0.476264         0.484086       0.665774       0.674427
# 2         0.563377         0.534583       0.697407       0.690482
# 3         0.467958         0.467822       0.663682       0.668952
# 4         0.540899         0.537596       0.691919       0.693295
# 5         0.482618         0.459567       0.669031       0.662602
# 6         0.429654         0.385287       0.647088       0.630542
# 7         0.528382         0.453449       0.688293       0.660842
# 8         0.399192         0.322164       0.634823       0.604707
# 9         0.447626         0.419357       0.655919       0.648059
#
#    recon_pear_ht29  recon_pear_a375  ...  recon_spear_a375  recon_acc_ht29  \
# 0         0.835393         0.818401  ...          0.754474        0.801952
# 1         0.821832         0.827302  ...          0.753359        0.796822
# 2         0.819998         0.832906  ...          0.766292        0.797072
# 3         0.831658         0.807958  ...          0.729672        0.799429
# 4         0.849340         0.828193  ...          0.761095        0.821331
# 5         0.852308         0.829899  ...          0.780059        0.820787
# 6         0.830061         0.806941  ...          0.758583        0.809169
# 7         0.853617         0.817448  ...          0.770311        0.827868
# 8         0.811054         0.821871  ...          0.775849        0.795509
# 9         0.818322         0.803945  ...          0.758481        0.797344
# 0         0.835169         0.820469  ...          0.746691        0.801800
# 1         0.828786         0.814631  ...          0.744231        0.795398
# 2         0.807937         0.828589  ...          0.760706        0.789337
# 3         0.822836         0.808884  ...          0.732363        0.796170
# 4         0.845713         0.828356  ...          0.755079        0.819980
# 5         0.847676         0.832160  ...          0.780179        0.819358
# 6         0.827314         0.799361  ...          0.744852        0.809588
# 7         0.851542         0.816330  ...          0.770359        0.825445
# 8         0.835067         0.814963  ...          0.761875        0.814475
# 9         0.819369         0.803444  ...          0.756039        0.797549
# 0         0.827002         0.820544  ...          0.747979        0.798444
# 1         0.826619         0.820395  ...          0.738538        0.793032
# 2         0.812226         0.826925  ...          0.762456        0.794210
# 3         0.821476         0.804674  ...          0.737869        0.793955
# 4         0.839975         0.825189  ...          0.748599        0.815781
# 5         0.834089         0.828042  ...          0.777122        0.815556
# 6         0.828883         0.815544  ...          0.762341        0.808918
# 7         0.853530         0.812377  ...          0.764148        0.824053
# 8         0.830389         0.818583  ...          0.773949        0.810530
# 9         0.821980         0.808581  ...          0.764439        0.800246
# 0         0.855301         0.846577  ...          0.794943        0.815974
# 1         0.845496         0.855556  ...          0.794674        0.807935
# 2         0.832049         0.862449  ...          0.815280        0.803988
# 3         0.838981         0.840884  ...          0.795623        0.803606
# 4         0.869403         0.860909  ...          0.808959        0.833310
# 5         0.869644         0.870845  ...          0.833748        0.835783
# 6         0.861795         0.854774  ...          0.820409        0.830092
# 7         0.877211         0.846940  ...          0.813830        0.843838
# 8         0.853622         0.851408  ...          0.814839        0.826753
# 9         0.846276         0.844722  ...          0.813814        0.817515
#
#    recon_acc_a375  Direct_pearson  Direct_spearman  DirectAcc_ht29  \
# 0        0.789528        0.491287         0.415190        0.642983
# 1        0.787998        0.449773         0.373708        0.631105
# 2        0.793680        0.467521         0.380200        0.626279
# 3        0.776977        0.420189         0.338177        0.617376
# 4        0.795430        0.534992         0.417309        0.646877
# 5        0.804115        0.414235         0.365071        0.626368
# 6        0.788537        0.305874         0.271386        0.590569
# 7        0.798742        0.453185         0.369136        0.629967
# 8        0.800164        0.301552         0.254713        0.581735
# 9        0.792892        0.381603         0.307406        0.604008
# 0        0.785728        0.491287         0.415190        0.642983
# 1        0.783632        0.449773         0.373708        0.631105
# 2        0.790942        0.467521         0.380200        0.626279
# 3        0.778678        0.420189         0.338177        0.617376
# 4        0.791811        0.534992         0.417309        0.646877
# 5        0.804544        0.414236         0.365071        0.626368
# 6        0.784965        0.305874         0.271386        0.590569
# 7        0.798246        0.453185         0.369136        0.629967
# 8        0.792260        0.301552         0.254713        0.581735
# 9        0.791271        0.381603         0.307406        0.604008
# 0        0.786223        0.491287         0.415190        0.642983
# 1        0.781049        0.449773         0.373708        0.631105
# 2        0.791202        0.467521         0.380200        0.626279
# 3        0.781250        0.420189         0.338177        0.617376
# 4        0.789252        0.534992         0.417309        0.646877
# 5        0.803027        0.414235         0.365071        0.626368
# 6        0.793517        0.305874         0.271386        0.590569
# 7        0.795408        0.453185         0.369136        0.629967
# 8        0.799783        0.301552         0.254713        0.581735
# 9        0.795105        0.381603         0.307406        0.604008
# 0        0.806279             NaN              NaN             NaN
# 1        0.805782             NaN              NaN             NaN
# 2        0.816364             NaN              NaN             NaN
# 3        0.806346             NaN              NaN             NaN
# 4        0.816057             NaN              NaN             NaN
# 5        0.830252             NaN              NaN             NaN
# 6        0.821250             NaN              NaN             NaN
# 7        0.817877             NaN              NaN             NaN
# 8        0.818141             NaN              NaN             NaN
# 9        0.817554             NaN              NaN             NaN
#
#    DirectAcc_a375                            model cross_corr_ht29  \
# 0        0.642983                              CPA             NaN
# 1        0.631105                              CPA             NaN
# 2        0.626279                              CPA             NaN
# 3        0.617376                              CPA             NaN
# 4        0.646877                              CPA             NaN
# 5        0.626368                              CPA             NaN
# 6        0.590569                              CPA             NaN
# 7        0.629967                              CPA             NaN
# 8        0.581735                              CPA             NaN
# 9        0.604008                              CPA             NaN
# 0        0.642983  Similarity trained Autoencoders        0.583207
# 1        0.631105  Similarity trained Autoencoders        0.527387
# 2        0.626279  Similarity trained Autoencoders        0.535538
# 3        0.617376  Similarity trained Autoencoders        0.464524
# 4        0.646877  Similarity trained Autoencoders        0.608245
# 5        0.626368  Similarity trained Autoencoders        0.527997
# 6        0.590569  Similarity trained Autoencoders        0.494581
# 7        0.629967  Similarity trained Autoencoders        0.529275
# 8        0.581735  Similarity trained Autoencoders        0.485504
# 9        0.604008  Similarity trained Autoencoders        0.543145
# 0        0.642983     Autoencoders with classifier             NaN
# 1        0.631105     Autoencoders with classifier             NaN
# 2        0.626279     Autoencoders with classifier             NaN
# 3        0.617376     Autoencoders with classifier             NaN
# 4        0.646877     Autoencoders with classifier             NaN
# 5        0.626368     Autoencoders with classifier             NaN
# 6        0.590569     Autoencoders with classifier             NaN
# 7        0.629967     Autoencoders with classifier             NaN
# 8        0.581735     Autoencoders with classifier             NaN
# 9        0.604008     Autoencoders with classifier             NaN
# 0             NaN                       TransCompR             NaN
# 1             NaN                       TransCompR             NaN
# 2             NaN                       TransCompR             NaN
# 3             NaN                       TransCompR             NaN
# 4             NaN                       TransCompR             NaN
# 5             NaN                       TransCompR             NaN
# 6             NaN                       TransCompR             NaN
# 7             NaN                       TransCompR             NaN
# 8             NaN                       TransCompR             NaN
# 9             NaN                       TransCompR             NaN
#
#    cross_corr_a375
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 0         0.553094
# 1         0.559233
# 2         0.563246
# 3         0.536350
# 4         0.640172
# 5         0.568708
# 6         0.465254
# 7         0.565050
# 8         0.494689
# 9         0.505058
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
#
# [40 rows x 21 columns]

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline],axis=0)
res_to_a375
# Out:
#     pearson  spearman  accuracy                            model
# 0  0.549015  0.449530  0.656841                              CPA
# 1  0.549911  0.424332  0.650932                              CPA
# 2  0.639625  0.540096  0.690789                              CPA
# 3  0.558759  0.443280  0.658281                              CPA
# 4  0.630697  0.531267  0.692043                              CPA
# 5  0.539691  0.434678  0.652499                              CPA
# 6  0.437838  0.360564  0.622189                              CPA
# 7  0.564606  0.428213  0.648810                              CPA
# 8  0.370766  0.286545  0.592782                              CPA
# 9  0.510040  0.428244  0.652080                              CPA
# 0  0.574139  0.494421  0.673265  Similarity trained Autoencoders
# 1  0.590913  0.453064  0.661112  Similarity trained Autoencoders
# 2  0.637148  0.540541  0.686692  Similarity trained Autoencoders
# 3  0.588596  0.473792  0.671086  Similarity trained Autoencoders
# 4  0.635853  0.535623  0.690730  Similarity trained Autoencoders
# 5  0.552753  0.432631  0.651852  Similarity trained Autoencoders
# 6  0.440748  0.379072  0.629179  Similarity trained Autoencoders
# 7  0.566633  0.452295  0.656526  Similarity trained Autoencoders
# 8  0.405110  0.325354  0.606410  Similarity trained Autoencoders
# 9  0.519431  0.425053  0.651626  Similarity trained Autoencoders
# 0  0.570235  0.488278  0.671954     Autoencoders with classifier
# 1  0.583896  0.452875  0.664183     Autoencoders with classifier
# 2  0.643685  0.554409  0.696681     Autoencoders with classifier
# 3  0.586761  0.469025  0.668766     Autoencoders with classifier
# 4  0.640250  0.540724  0.693203     Autoencoders with classifier
# 5  0.541169  0.429460  0.650312     Autoencoders with classifier
# 6  0.476808  0.392704  0.632456     Autoencoders with classifier
# 7  0.576124  0.456567  0.659627     Autoencoders with classifier
# 8  0.409533  0.332204  0.607860     Autoencoders with classifier
# 9  0.546425  0.444518  0.657942     Autoencoders with classifier
# 0  0.559911  0.492247  0.673555                       TransCompR
# 1  0.597295  0.484086  0.674427                       TransCompR
# 2  0.633806  0.534583  0.690482                       TransCompR
# 3  0.578064  0.467822  0.668952                       TransCompR
# 4  0.646906  0.537596  0.693295                       TransCompR
# 5  0.552361  0.459567  0.662602                       TransCompR
# 6  0.448766  0.385287  0.630542                       TransCompR
# 7  0.578690  0.453449  0.660842                       TransCompR
# 8  0.400220  0.322164  0.604707                       TransCompR
# 9  0.513790  0.419357  0.648059                       TransCompR
# 0  0.491287  0.415190  0.642983               direct translation
# 1  0.449773  0.373708  0.631105               direct translation
# 2  0.467521  0.380200  0.626279               direct translation
# 3  0.420189  0.338177  0.617376               direct translation
# 4  0.534992  0.417309  0.646877               direct translation
# 5  0.414236  0.365071  0.626368               direct translation
# 6  0.305874  0.271386  0.590569               direct translation
# 7  0.453185  0.369136  0.629967               direct translation
# 8  0.301552  0.254713  0.581735               direct translation
# 9  0.381603  0.307406  0.604008               direct translation

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#                   model    metric     value
# 0                   CPA   pearson  0.549015
# 1                   CPA   pearson  0.549911
# 2                   CPA   pearson  0.639625
# 3                   CPA   pearson  0.558759
# 4                   CPA   pearson  0.630697
# ..                  ...       ...       ...
# 145  direct translation  accuracy  0.626368
# 146  direct translation  accuracy  0.590569
# 147  direct translation  accuracy  0.629967
# 148  direct translation  accuracy  0.581735
# 149  direct translation  accuracy  0.604008
#
# [150 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.25)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="value", y="model", data=res_to_a375,
            order=['direct translation','Similarity trained Autoencoders',
                   'Autoencoders with classifier','CPA',
                   'TransCompR'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_compare_with_TransCompR_a375.png', bbox_inches='tight',dpi=600)

# %%
from scipy import stats

# %%
models = ['Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR','direct translation']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-27-19bd705513e7>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-27-19bd705513e7>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-28-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-28-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-29-748d6dd7cfa5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
# <ipython-input-29-748d6dd7cfa5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR','direct translation']]
a375_translate.to_csv('../results/MI_results/allgenes_a375_compare_with_TransCompR_translation_pvalues_table.csv')
a375_translate
# Out:
#                                    metric  Similarity trained Autoencoders  \
# Similarity trained Autoencoders   pearson                              1.0
# Autoencoders with classifier      pearson                              0.0
# CPA                               pearson                              0.0
# TransCompR                        pearson                              0.0
# direct translation                pearson                              0.0
# Similarity trained Autoencoders  spearman                              1.0
# Autoencoders with classifier     spearman                              0.0
# CPA                              spearman                              0.0
# TransCompR                       spearman                              0.0
# direct translation               spearman                              0.0
# Similarity trained Autoencoders  accuracy                              1.0
# Autoencoders with classifier     accuracy                              0.0
# CPA                              accuracy                              0.0
# TransCompR                       accuracy                              0.0
# direct translation               accuracy                              0.0
#
#                                  Autoencoders with classifier       CPA  \
# Similarity trained Autoencoders                      0.909722  0.384673
# Autoencoders with classifier                         1.000000  0.344704
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
# Similarity trained Autoencoders                      0.791337  0.384673
# Autoencoders with classifier                         1.000000  0.212294
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
# Similarity trained Autoencoders                      0.791337  0.623176
# Autoencoders with classifier                         1.000000  0.273036
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
#
#                                  TransCompR  direct translation
# Similarity trained Autoencoders    0.969850            0.005795
# Autoencoders with classifier       0.969850            0.002202
# CPA                                0.384673            0.007285
# TransCompR                         1.000000            0.005795
# direct translation                 0.000000            1.000000
# Similarity trained Autoencoders    0.850107            0.002827
# Autoencoders with classifier       0.969850            0.002202
# CPA                                0.344704            0.007285
# TransCompR                         1.000000            0.002202
# direct translation                 0.000000            1.000000
# Similarity trained Autoencoders    0.677585            0.003611
# Autoencoders with classifier       0.850107            0.002202
# CPA                                0.344704            0.007285
# TransCompR                         1.000000            0.002827
# direct translation                 0.000000            1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_a375 = results.loc[:,['recon_pear_a375','recon_spear_a375','recon_acc_a375','model']]
res_recon_a375.columns = ['pearson','spearman','accuracy','model']
res_recon_a375
# Out:
#     pearson  spearman  accuracy                            model
# 0  0.818401  0.754474  0.789528                              CPA
# 1  0.827302  0.753359  0.787998                              CPA
# 2  0.832906  0.766292  0.793680                              CPA
# 3  0.807958  0.729672  0.776977                              CPA
# 4  0.828193  0.761095  0.795430                              CPA
# 5  0.829899  0.780059  0.804115                              CPA
# 6  0.806941  0.758583  0.788537                              CPA
# 7  0.817448  0.770311  0.798742                              CPA
# 8  0.821871  0.775849  0.800164                              CPA
# 9  0.803945  0.758481  0.792892                              CPA
# 0  0.820469  0.746691  0.785728  Similarity trained Autoencoders
# 1  0.814631  0.744231  0.783632  Similarity trained Autoencoders
# 2  0.828589  0.760706  0.790942  Similarity trained Autoencoders
# 3  0.808884  0.732363  0.778678  Similarity trained Autoencoders
# 4  0.828356  0.755079  0.791811  Similarity trained Autoencoders
# 5  0.832160  0.780179  0.804544  Similarity trained Autoencoders
# 6  0.799361  0.744852  0.784965  Similarity trained Autoencoders
# 7  0.816330  0.770359  0.798246  Similarity trained Autoencoders
# 8  0.814963  0.761875  0.792260  Similarity trained Autoencoders
# 9  0.803444  0.756039  0.791271  Similarity trained Autoencoders
# 0  0.820544  0.747979  0.786223     Autoencoders with classifier
# 1  0.820395  0.738538  0.781049     Autoencoders with classifier
# 2  0.826925  0.762456  0.791202     Autoencoders with classifier
# 3  0.804674  0.737869  0.781250     Autoencoders with classifier
# 4  0.825189  0.748599  0.789252     Autoencoders with classifier
# 5  0.828042  0.777122  0.803027     Autoencoders with classifier
# 6  0.815544  0.762341  0.793517     Autoencoders with classifier
# 7  0.812377  0.764148  0.795408     Autoencoders with classifier
# 8  0.818583  0.773949  0.799783     Autoencoders with classifier
# 9  0.808581  0.764439  0.795105     Autoencoders with classifier
# 0  0.846577  0.794943  0.806279                       TransCompR
# 1  0.855556  0.794674  0.805782                       TransCompR
# 2  0.862449  0.815280  0.816364                       TransCompR
# 3  0.840884  0.795623  0.806346                       TransCompR
# 4  0.860909  0.808959  0.816057                       TransCompR
# 5  0.870845  0.833748  0.830252                       TransCompR
# 6  0.854774  0.820409  0.821250                       TransCompR
# 7  0.846940  0.813830  0.817877                       TransCompR
# 8  0.851408  0.814839  0.818141                       TransCompR
# 9  0.844722  0.813814  0.817554                       TransCompR

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#           model    metric     value
# 0           CPA   pearson  0.818401
# 1           CPA   pearson  0.827302
# 2           CPA   pearson  0.832906
# 3           CPA   pearson  0.807958
# 4           CPA   pearson  0.828193
# ..          ...       ...       ...
# 115  TransCompR  accuracy  0.830252
# 116  TransCompR  accuracy  0.821250
# 117  TransCompR  accuracy  0.817877
# 118  TransCompR  accuracy  0.818141
# 119  TransCompR  accuracy  0.817554
#
# [120 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="value", y="model", data=res_recon_a375,
            order=['Similarity trained Autoencoders',
                   'Autoencoders with classifier','CPA',
                   'TransCompR'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_reconstruction_compare_with_TransCompR_a375.png', bbox_inches='tight',dpi=600)

# %%
models = ['Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-36-695b4ac350db>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-36-695b4ac350db>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-37-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-37-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-38-7bf8ce6c3d50>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
# <ipython-input-38-7bf8ce6c3d50>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR']]
a375_reconstruction.to_csv('../results/MI_results/allgenes_a375_compare_with_TransCompR_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                                    metric  Similarity trained Autoencoders  \
# Similarity trained Autoencoders   pearson                              1.0
# Autoencoders with classifier      pearson                              0.0
# CPA                               pearson                              0.0
# TransCompR                        pearson                              0.0
# Similarity trained Autoencoders  spearman                              1.0
# Autoencoders with classifier     spearman                              0.0
# CPA                              spearman                              0.0
# TransCompR                       spearman                              0.0
# Similarity trained Autoencoders  accuracy                              1.0
# Autoencoders with classifier     accuracy                              0.0
# CPA                              accuracy                              0.0
# TransCompR                       accuracy                              0.0
#
#                                  Autoencoders with classifier       CPA  \
# Similarity trained Autoencoders                      0.909722  0.384673
# Autoencoders with classifier                         1.000000  0.344704
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# Similarity trained Autoencoders                      0.472676  0.427355
# Autoencoders with classifier                         1.000000  0.733730
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# Similarity trained Autoencoders                      0.623176  0.344704
# Autoencoders with classifier                         1.000000  0.677585
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
#
#                                  TransCompR
# Similarity trained Autoencoders    0.969850
# Autoencoders with classifier       0.969850
# CPA                                0.384673
# TransCompR                         1.000000
# Similarity trained Autoencoders    0.000183
# Autoencoders with classifier       0.000183
# CPA                                0.000183
# TransCompR                         1.000000
# Similarity trained Autoencoders    0.000183
# Autoencoders with classifier       0.000183
# CPA                                0.000183
# TransCompR                         1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline],axis=0)
res_to_ht29
# Out:
#     pearson  spearman  accuracy                            model
# 0  0.673932  0.562946  0.701321                              CPA
# 1  0.589004  0.479765  0.668531                              CPA
# 2  0.676635  0.570473  0.702578                              CPA
# 3  0.550606  0.439052  0.653401                              CPA
# 4  0.621177  0.519464  0.685294                              CPA
# 5  0.592926  0.508504  0.680805                              CPA
# 6  0.501435  0.394468  0.636266                              CPA
# 7  0.631147  0.526179  0.689054                              CPA
# 8  0.489493  0.379147  0.628200                              CPA
# 9  0.549553  0.444448  0.652375                              CPA
# 0  0.667348  0.577731  0.704729  Similarity trained Autoencoders
# 1  0.577154  0.459355  0.658361  Similarity trained Autoencoders
# 2  0.706598  0.601433  0.716949  Similarity trained Autoencoders
# 3  0.593213  0.456560  0.660867  Similarity trained Autoencoders
# 4  0.654452  0.557725  0.701383  Similarity trained Autoencoders
# 5  0.575751  0.485382  0.672650  Similarity trained Autoencoders
# 6  0.528944  0.433714  0.651624  Similarity trained Autoencoders
# 7  0.632949  0.544343  0.694205  Similarity trained Autoencoders
# 8  0.505198  0.386525  0.628820  Similarity trained Autoencoders
# 9  0.573678  0.461137  0.657622  Similarity trained Autoencoders
# 0  0.674442  0.569433  0.703659     Autoencoders with classifier
# 1  0.599027  0.490749  0.671413     Autoencoders with classifier
# 2  0.705431  0.591212  0.713033     Autoencoders with classifier
# 3  0.596755  0.469937  0.665675     Autoencoders with classifier
# 4  0.646739  0.534608  0.692576     Autoencoders with classifier
# 5  0.570010  0.489358  0.672199     Autoencoders with classifier
# 6  0.529065  0.427845  0.648721     Autoencoders with classifier
# 7  0.648193  0.561575  0.703091     Autoencoders with classifier
# 8  0.517324  0.399560  0.634600     Autoencoders with classifier
# 9  0.574006  0.465308  0.662983     Autoencoders with classifier
# 0  0.646988  0.553253  0.694567                       TransCompR
# 1  0.580043  0.476264  0.665774                       TransCompR
# 2  0.678701  0.563377  0.697407                       TransCompR
# 3  0.589427  0.467958  0.663682                       TransCompR
# 4  0.661613  0.540899  0.691919                       TransCompR
# 5  0.572714  0.482618  0.669031                       TransCompR
# 6  0.517275  0.429654  0.647088                       TransCompR
# 7  0.613800  0.528382  0.688293                       TransCompR
# 8  0.504796  0.399192  0.634823                       TransCompR
# 9  0.547518  0.447626  0.655919                       TransCompR
# 0  0.491287  0.415190  0.642983               direct translation
# 1  0.449773  0.373708  0.631105               direct translation
# 2  0.467521  0.380200  0.626279               direct translation
# 3  0.420189  0.338177  0.617376               direct translation
# 4  0.534992  0.417309  0.646877               direct translation
# 5  0.414236  0.365071  0.626368               direct translation
# 6  0.305874  0.271386  0.590569               direct translation
# 7  0.453185  0.369136  0.629967               direct translation
# 8  0.301552  0.254713  0.581735               direct translation
# 9  0.381603  0.307406  0.604008               direct translation

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#                   model    metric     value
# 0                   CPA   pearson  0.673932
# 1                   CPA   pearson  0.589004
# 2                   CPA   pearson  0.676635
# 3                   CPA   pearson  0.550606
# 4                   CPA   pearson  0.621177
# ..                  ...       ...       ...
# 145  direct translation  accuracy  0.626368
# 146  direct translation  accuracy  0.590569
# 147  direct translation  accuracy  0.629967
# 148  direct translation  accuracy  0.581735
# 149  direct translation  accuracy  0.604008
#
# [150 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="value", y="model", data=res_to_ht29,
            order=['direct translation','Similarity trained Autoencoders',
                   'Autoencoders with classifier','CPA',
                   'TransCompR'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_compare_with_TransCompR_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR','direct translation']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-43-6e864ca9fdf8>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-43-6e864ca9fdf8>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-44-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-44-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-45-c5c1bf237c12>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
# <ipython-input-45-c5c1bf237c12>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR']]
ht29_translate.to_csv('../results/MI_results/allgenes_ht29_compare_with_TransCompR_translation_pvalues_table.csv')
ht29_translate
# Out:
#                                    metric  Similarity trained Autoencoders  \
# Similarity trained Autoencoders   pearson                              1.0
# Autoencoders with classifier      pearson                              0.0
# CPA                               pearson                              0.0
# TransCompR                        pearson                              0.0
# direct translation                pearson                              0.0
# Similarity trained Autoencoders  spearman                              1.0
# Autoencoders with classifier     spearman                              0.0
# CPA                              spearman                              0.0
# TransCompR                       spearman                              0.0
# direct translation               spearman                              0.0
# Similarity trained Autoencoders  accuracy                              1.0
# Autoencoders with classifier     accuracy                              0.0
# CPA                              accuracy                              0.0
# TransCompR                       accuracy                              0.0
# direct translation               accuracy                              0.0
#
#                                  Autoencoders with classifier       CPA  \
# Similarity trained Autoencoders                      0.909722  0.677585
# Autoencoders with classifier                         1.000000  0.520523
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
# Similarity trained Autoencoders                      0.733730  0.677585
# Autoencoders with classifier                         1.000000  0.623176
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
# Similarity trained Autoencoders                      0.850107  0.623176
# Autoencoders with classifier                         1.000000  0.520523
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# direct translation                                   0.000000  0.000000
#
#                                  TransCompR
# Similarity trained Autoencoders    0.733730
# Autoencoders with classifier       0.623176
# CPA                                0.969850
# TransCompR                         1.000000
# direct translation                 0.000000
# Similarity trained Autoencoders    0.791337
# Autoencoders with classifier       0.623176
# CPA                                0.791337
# TransCompR                         1.000000
# direct translation                 0.000000
# Similarity trained Autoencoders    0.733730
# Autoencoders with classifier       0.520523
# CPA                                0.969850
# TransCompR                         1.000000
# direct translation                 0.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','accuracy','model']
res_recon_ht29
# Out:
#     pearson  spearman  accuracy                            model
# 0  0.835393  0.783634  0.801952                              CPA
# 1  0.821832  0.772010  0.796822                              CPA
# 2  0.819998  0.770136  0.797072                              CPA
# 3  0.831658  0.772910  0.799429                              CPA
# 4  0.849340  0.809962  0.821331                              CPA
# 5  0.852308  0.808809  0.820787                              CPA
# 6  0.830061  0.788840  0.809169                              CPA
# 7  0.853617  0.821611  0.827868                              CPA
# 8  0.811054  0.766373  0.795509                              CPA
# 9  0.818322  0.771057  0.797344                              CPA
# 0  0.835169  0.780231  0.801800  Similarity trained Autoencoders
# 1  0.828786  0.767704  0.795398  Similarity trained Autoencoders
# 2  0.807937  0.755687  0.789337  Similarity trained Autoencoders
# 3  0.822836  0.767055  0.796170  Similarity trained Autoencoders
# 4  0.845713  0.809343  0.819980  Similarity trained Autoencoders
# 5  0.847676  0.806944  0.819358  Similarity trained Autoencoders
# 6  0.827314  0.789109  0.809588  Similarity trained Autoencoders
# 7  0.851542  0.815302  0.825445  Similarity trained Autoencoders
# 8  0.835067  0.799301  0.814475  Similarity trained Autoencoders
# 9  0.819369  0.768452  0.797549  Similarity trained Autoencoders
# 0  0.827002  0.773864  0.798444     Autoencoders with classifier
# 1  0.826619  0.761357  0.793032     Autoencoders with classifier
# 2  0.812226  0.765004  0.794210     Autoencoders with classifier
# 3  0.821476  0.761728  0.793955     Autoencoders with classifier
# 4  0.839975  0.801233  0.815781     Autoencoders with classifier
# 5  0.834089  0.799860  0.815556     Autoencoders with classifier
# 6  0.828883  0.787878  0.808918     Autoencoders with classifier
# 7  0.853530  0.814444  0.824053     Autoencoders with classifier
# 8  0.830389  0.791325  0.810530     Autoencoders with classifier
# 9  0.821980  0.773293  0.800246     Autoencoders with classifier
# 0  0.855301  0.812526  0.815974                       TransCompR
# 1  0.845496  0.798646  0.807935                       TransCompR
# 2  0.832049  0.788924  0.803988                       TransCompR
# 3  0.838981  0.787004  0.803606                       TransCompR
# 4  0.869403  0.840359  0.833310                       TransCompR
# 5  0.869644  0.841884  0.835783                       TransCompR
# 6  0.861795  0.833605  0.830092                       TransCompR
# 7  0.877211  0.854646  0.843838                       TransCompR
# 8  0.853622  0.827085  0.826753                       TransCompR
# 9  0.846276  0.811522  0.817515                       TransCompR

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#           model    metric     value
# 0           CPA   pearson  0.835393
# 1           CPA   pearson  0.821832
# 2           CPA   pearson  0.819998
# 3           CPA   pearson  0.831658
# 4           CPA   pearson  0.849340
# ..          ...       ...       ...
# 115  TransCompR  accuracy  0.835783
# 116  TransCompR  accuracy  0.830092
# 117  TransCompR  accuracy  0.843838
# 118  TransCompR  accuracy  0.826753
# 119  TransCompR  accuracy  0.817515
#
# [120 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="value", y="model", data=res_recon_ht29,
            order=['Similarity trained Autoencoders',
                   'Autoencoders with classifier','CPA',
                   'TransCompR'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_reconstruction_compare_with_TransCompR_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-51-308813f9070d>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-51-308813f9070d>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-52-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-52-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-53-12b8fd9ef33b>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
# <ipython-input-53-12b8fd9ef33b>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','Similarity trained Autoencoders','Autoencoders with classifier','CPA','TransCompR']]
ht29_reconstruction.to_csv('../results/MI_results/allgenes_ht29_compare_with_TransCompR_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                                    metric  Similarity trained Autoencoders  \
# Similarity trained Autoencoders   pearson                              1.0
# Autoencoders with classifier      pearson                              0.0
# CPA                               pearson                              0.0
# TransCompR                        pearson                              0.0
# Similarity trained Autoencoders  spearman                              1.0
# Autoencoders with classifier     spearman                              0.0
# CPA                              spearman                              0.0
# TransCompR                       spearman                              0.0
# Similarity trained Autoencoders  accuracy                              1.0
# Autoencoders with classifier     accuracy                              0.0
# CPA                              accuracy                              0.0
# TransCompR                       accuracy                              0.0
#
#                                  Autoencoders with classifier       CPA  \
# Similarity trained Autoencoders                      0.623176  0.909722
# Autoencoders with classifier                         1.000000  0.850107
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# Similarity trained Autoencoders                      0.733730  0.791337
# Autoencoders with classifier                         1.000000  0.791337
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
# Similarity trained Autoencoders                      0.733730  0.850107
# Autoencoders with classifier                         1.000000  0.733730
# CPA                                                  0.000000  1.000000
# TransCompR                                           0.000000  0.000000
#
#                                  TransCompR
# Similarity trained Autoencoders    0.005795
# Autoencoders with classifier       0.001315
# CPA                                0.005795
# TransCompR                         1.000000
# Similarity trained Autoencoders    0.011330
# Autoencoders with classifier       0.007285
# CPA                                0.004586
# TransCompR                         1.000000
# Similarity trained Autoencoders    0.031209
# Autoencoders with classifier       0.014019
# CPA                                0.021134
# TransCompR                         1.000000
