# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import mannwhitneyu, normaltest
from statannotations.Annotator import Annotator
import statannot

# %% [markdown]
# # Compare DeepCellState variations

# %%
import seaborn as sns
sns.set()

# %%
res_dcs_noise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_with_noise_10k.csv',index_col=0)
res_dcs_noise['model'] = 'DCS'
res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_no_noise_10k.csv',index_col=0)
res_dcs_nonoise['model'] = 'DCS modified v1'
res_notvae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_notvae_results1000ep512bs.csv',index_col=0)
res_notvae_2encs['model'] = 'similarity-trained Autoencoders'
res_dcs_direct = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_direct_andl2similarity_10k.csv',index_col=0)
res_dcs_direct['model'] = 'DCS modified v2'
baseline = pd.read_csv('../results/baseline_evaluation_allgenes.csv',index_col=0)
baseline = baseline.drop_duplicates()

# add mi
res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
res_mi['model'] = 'GAN-based Autoencoders'

# %%
# add TransCompRmixedANNS
res_annTransCompR = pd.read_csv('../results/ANNmixedTransCompR_results_10k/allgenes_10foldvalidation_ANNmixedTransCompR_500ep512bs_a375_ht29.csv',index_col=0)
res_annTransCompR['model'] = 'TransCompR-combined and GAN-based Autoencoders'

# %%
# # add mi
# res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_pc3_ha1e.csv',index_col=0)
# res_mi['model'] = 'Translation Model'

# res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_2000ep512bs_pc3_ha1e_withclass.csv',index_col=0)
# res_mi_class['model'] = 'Translation Model with classifier'

# %%
# res_dcs_noise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_withnoise.csv',index_col=0)
# res_dcs_noise['model'] = 'DCS'
# res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_no_noise.csv',index_col=0)
# res_dcs_nonoise['model'] = 'DCS modified v1'
# res_notvae_2encs = pd.read_csv('../results/my_results/landmarks_10foldvalidation_vae_results1000ep512bs.csv',index_col=0)
# res_notvae_2encs['model'] = 'Two Autoencoders'
# res_dcs_direct = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_direct_and_l2similarity.csv',index_col=0)
# res_dcs_direct['model'] = 'DCS modified v2'
# baseline = pd.read_csv('../results/baseline_evaluation_landmarks.csv',index_col=0)
# baseline = baseline.drop_duplicates()

# # # add mi
# # res_mi = pd.read_csv('../results/MI_results/landmarks_10foldvalidation_pretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
# # res_mi['model'] = 'MI Autoencoders'

# %%
results = pd.concat([res_dcs_noise,res_dcs_nonoise,res_notvae_2encs,res_dcs_direct,res_mi,res_annTransCompR],axis=0)
results
# Out:
#    model_pearsonHT29  model_pearsonA375  model_spearHT29  model_spearA375  \
# 0           0.613718           0.599170         0.526330         0.512294
# 1           0.566115           0.558736         0.464582         0.463245
# 2           0.609149           0.582151         0.492402         0.473071
# 3           0.530387           0.514541         0.418556         0.411831
# 4           0.649465           0.635018         0.522971         0.505391
# 5           0.517710           0.500510         0.456342         0.436321
# 6           0.379070           0.377209         0.345177         0.332456
# 7           0.565623           0.548966         0.465607         0.445844
# 8           0.390222           0.374094         0.324936         0.311553
# 9           0.470474           0.465445         0.379353         0.370936
# 0           0.618526           0.601937         0.533965         0.514301
# 1           0.565272           0.555866         0.463171         0.456192
# 2           0.616632           0.590337         0.495240         0.481992
# 3           0.531053           0.513541         0.421344         0.411026
# 4           0.661082           0.639639         0.532603         0.509573
# 5           0.522730           0.501386         0.454013         0.436072
# 6           0.378412           0.375514         0.341890         0.329808
# 7           0.563070           0.552748         0.461913         0.441782
# 8           0.396872           0.380036         0.328490         0.315809
# 9           0.475924           0.465739         0.379794         0.372564
# 0           0.666739           0.564090         0.562238         0.488221
# 1           0.591782           0.572697         0.478091         0.431274
# 2           0.703306           0.637546         0.599642         0.542747
# 3           0.595689           0.585109         0.465942         0.473938
# 4           0.621247           0.639732         0.519357         0.538977
# 5           0.554374           0.533395         0.456431         0.418876
# 6           0.505563           0.469591         0.401197         0.384238
# 7           0.630244           0.550840         0.542571         0.440696
# 8           0.501270           0.399251         0.382562         0.324429
# 9           0.554151           0.511755         0.449934         0.414483
# 0           0.694047           0.564707         0.600927         0.489972
# 1           0.601810           0.608006         0.483167         0.489876
# 2           0.702464           0.650462         0.591011         0.543741
# 3           0.611520           0.602023         0.487644         0.487823
# 4           0.700402           0.668152         0.579689         0.571824
# 5           0.618214           0.582899         0.508138         0.478771
# 6           0.541515           0.474985         0.458018         0.415385
# 7           0.651315           0.599302         0.568369         0.483529
# 8           0.545906           0.442222         0.435823         0.368281
# 9           0.571278           0.566806         0.464479         0.464336
# 0           0.667348           0.574139         0.577731         0.494421
# 1           0.577154           0.590913         0.459355         0.453064
# 2           0.706598           0.637148         0.601433         0.540541
# 3           0.593213           0.588596         0.456560         0.473792
# 4           0.654452           0.635853         0.557725         0.535623
# 5           0.575751           0.552753         0.485382         0.432631
# 6           0.528944           0.440748         0.433714         0.379072
# 7           0.632949           0.566633         0.544343         0.452295
# 8           0.505198           0.405110         0.386525         0.325354
# 9           0.573678           0.519431         0.461137         0.425053
# 0           0.664255           0.579915         0.570137         0.490883
# 1           0.613458           0.598754         0.498885         0.479042
# 2           0.696031           0.665309         0.583487         0.559070
# 3           0.614798           0.591180         0.489897         0.472043
# 4           0.674006           0.647690         0.553541         0.543611
# 5           0.601537           0.561560         0.512526         0.449254
# 6           0.522216           0.491400         0.421796         0.394415
# 7           0.637887           0.587091         0.555805         0.461821
# 8           0.517180           0.432028         0.408438         0.353169
# 9           0.571238           0.530337         0.462166         0.433570
#
#    model_accHT29  model_accA375  recon_pear_ht29  recon_pear_a375  \
# 0       0.685056       0.680166         0.947445         0.944607
# 1       0.663853       0.665333         0.945406         0.942046
# 2       0.667321       0.661947         0.942116         0.947642
# 3       0.646344       0.644403         0.944477         0.941711
# 4       0.686253       0.680406         0.950940         0.945411
# 5       0.659744       0.653069         0.952127         0.946220
# 6       0.616173       0.611459         0.947209         0.943144
# 7       0.665412       0.657116         0.951822         0.941229
# 8       0.606323       0.601103         0.946720         0.943884
# 9       0.630049       0.627560         0.944046         0.940707
# 0       0.687864       0.679744         0.905294         0.894737
# 1       0.664461       0.661640         0.899689         0.894061
# 2       0.668776       0.665608         0.890714         0.901794
# 3       0.646993       0.643278         0.894254         0.887728
# 4       0.690038       0.682260         0.909243         0.898279
# 5       0.658797       0.652305         0.912985         0.903179
# 6       0.613987       0.610309         0.901663         0.895989
# 7       0.664334       0.656710         0.913307         0.893390
# 8       0.608237       0.602734         0.904954         0.897282
# 9       0.629836       0.627878         0.896798         0.892277
# 0       0.699960       0.672665         0.830313         0.826383
# 1       0.665911       0.652558         0.824589         0.818986
# 2       0.715648       0.692009         0.812255         0.827975
# 3       0.664803       0.670647         0.826020         0.813655
# 4       0.684905       0.692943         0.846574         0.828014
# 5       0.658123       0.645286         0.853151         0.831958
# 6       0.635842       0.629828         0.833748         0.800847
# 7       0.693754       0.653587         0.849627         0.818409
# 8       0.628646       0.604494         0.838561         0.822378
# 9       0.656046       0.647380         0.816862         0.803080
# 0       0.714731       0.672886         0.792076         0.774872
# 1       0.669611       0.675419         0.783562         0.777196
# 2       0.709213       0.691394         0.776529         0.785535
# 3       0.672209       0.675568         0.774928         0.768159
# 4       0.708608       0.708943         0.823872         0.793090
# 5       0.677833       0.669765         0.799070         0.776692
# 6       0.659471       0.641724         0.798056         0.762495
# 7       0.706301       0.668620         0.796374         0.723925
# 8       0.648426       0.622705         0.786902         0.773076
# 9       0.659345       0.665881         0.781035         0.764739
# 0       0.704729       0.673265         0.835169         0.820469
# 1       0.658361       0.661112         0.828786         0.814631
# 2       0.716949       0.686692         0.807937         0.828589
# 3       0.660867       0.671086         0.822836         0.808884
# 4       0.701383       0.690730         0.845713         0.828356
# 5       0.672650       0.651852         0.847676         0.832160
# 6       0.651624       0.629179         0.827314         0.799361
# 7       0.694205       0.656526         0.851542         0.816330
# 8       0.628820       0.606410         0.835067         0.814963
# 9       0.657622       0.651626         0.819369         0.803444
# 0       0.705627       0.671636         0.879440         0.861666
# 1       0.676286       0.671056         0.864738         0.867706
# 2       0.710244       0.699160         0.856943         0.876625
# 3       0.674378       0.670977         0.868115         0.863265
# 4       0.697075       0.695667         0.882092         0.873245
# 5       0.683596       0.657210         0.877534         0.875062
# 6       0.645323       0.634134         0.875646         0.869891
# 7       0.701480       0.662304         0.881350         0.856327
# 8       0.637780       0.616248         0.876735         0.866323
# 9       0.660480       0.653121         0.869873         0.852096
#
#    recon_spear_ht29  recon_spear_a375  recon_acc_ht29  recon_acc_a375  \
# 0          0.937704          0.931870        0.896936        0.891681
# 1          0.934308          0.929751        0.894100        0.889458
# 2          0.933452          0.935973        0.893411        0.894833
# 3          0.933683          0.929063        0.894614        0.889775
# 4          0.942423          0.933031        0.903572        0.894141
# 5          0.942698          0.937022        0.903724        0.896427
# 6          0.939710          0.932478        0.900714        0.891758
# 7          0.944159          0.933005        0.905886        0.893113
# 8          0.939709          0.935252        0.901069        0.895268
# 9          0.935589          0.932645        0.895927        0.893243
# 0          0.882624          0.871022        0.858544        0.852468
# 1          0.877359          0.866142        0.855455        0.848679
# 2          0.871069          0.876313        0.852250        0.854598
# 3          0.871414          0.864473        0.852953        0.848241
# 4          0.892813          0.871958        0.868540        0.854948
# 5          0.893661          0.885072        0.869312        0.862272
# 6          0.885650          0.876050        0.863277        0.855333
# 7          0.898859          0.878501        0.873773        0.858342
# 8          0.889883          0.880321        0.866144        0.859161
# 9          0.877517          0.875791        0.857071        0.856103
# 0          0.775642          0.756613        0.796885        0.790215
# 1          0.761464          0.734010        0.792661        0.778140
# 2          0.762062          0.761507        0.792232        0.791721
# 3          0.771951          0.742145        0.797735        0.783081
# 4          0.804735          0.752695        0.817642        0.791035
# 5          0.811846          0.776322        0.821536        0.801362
# 6          0.793034          0.731223        0.811242        0.778329
# 7          0.814801          0.772086        0.824357        0.799294
# 8          0.800195          0.775301        0.815394        0.799670
# 9          0.760642          0.758384        0.792421        0.792070
# 0          0.723574          0.686237        0.772086        0.755247
# 1          0.711663          0.676526        0.765846        0.750082
# 2          0.707050          0.702377        0.764035        0.761791
# 3          0.699053          0.687787        0.762112        0.756393
# 4          0.773560          0.704071        0.799868        0.765778
# 5          0.748566          0.710172        0.788570        0.767404
# 6          0.746831          0.697467        0.787282        0.761097
# 7          0.752913          0.661135        0.793152        0.744554
# 8          0.741768          0.712661        0.783793        0.768941
# 9          0.723354          0.713006        0.773273        0.769017
# 0          0.780231          0.746691        0.801800        0.785728
# 1          0.767704          0.744231        0.795398        0.783632
# 2          0.755687          0.760706        0.789337        0.790942
# 3          0.767055          0.732363        0.796170        0.778678
# 4          0.809343          0.755079        0.819980        0.791811
# 5          0.806944          0.780179        0.819358        0.804544
# 6          0.789109          0.744852        0.809588        0.784965
# 7          0.815302          0.770359        0.825445        0.798246
# 8          0.799301          0.761875        0.814475        0.792260
# 9          0.768452          0.756039        0.797549        0.791271
# 0          0.847197          0.831706        0.836858        0.827744
# 1          0.831556          0.830984        0.826465        0.827412
# 2          0.826870          0.840893        0.823209        0.831185
# 3          0.840600          0.829932        0.834136        0.827293
# 4          0.861618          0.843019        0.849000        0.837052
# 5          0.861290          0.854330        0.847646        0.841472
# 6          0.855310          0.843207        0.844256        0.835253
# 7          0.864614          0.836144        0.850979        0.832483
# 8          0.857992          0.845611        0.845584        0.836843
# 9          0.846019          0.826328        0.838051        0.823739
#
#    cross_corr_ht29  cross_corr_a375  Direct_pearson  Direct_spearman  \
# 0         0.920867         0.920973        0.491287         0.213417
# 1         0.915497         0.915471        0.449773         0.484918
# 2         0.911275         0.915116        0.467521         0.225109
# 3         0.913457         0.919640        0.420189         0.132573
# 4         0.923569         0.925903        0.534992         0.588160
# 5         0.915390         0.922801        0.414236         0.500197
# 6         0.918249         0.919547        0.305874         0.156733
# 7         0.916835         0.922630        0.453185         0.515452
# 8         0.913029         0.914657        0.301552         0.143882
# 9         0.918858         0.917644        0.381603         0.261180
# 0         0.844822         0.848965        0.491287         0.213417
# 1         0.833210         0.842814        0.449773         0.484918
# 2         0.821369         0.836068        0.467521         0.225109
# 3         0.819174         0.842463        0.420189         0.132573
# 4         0.843547         0.855155        0.534992         0.588160
# 5         0.833371         0.854004        0.414236         0.500197
# 6         0.838858         0.841392        0.305874         0.156733
# 7         0.833406         0.853190        0.453185         0.515452
# 8         0.824562         0.836484        0.301552         0.143882
# 9         0.840801         0.840325        0.381603         0.261180
# 0         0.561255         0.539134        0.491287         0.415190
# 1         0.525529         0.551173        0.449773         0.373708
# 2         0.536881         0.556446        0.467521         0.380200
# 3         0.461170         0.527485        0.420189         0.338177
# 4         0.571863         0.636663        0.534992         0.417309
# 5         0.500165         0.544733        0.414236         0.365071
# 6         0.461660         0.456088        0.305874         0.271386
# 7         0.518081         0.540003        0.453185         0.369136
# 8         0.494669         0.475472        0.301552         0.254713
# 9         0.525332         0.503635        0.381603         0.307406
# 0         0.642537         0.560727        0.491287         0.213417
# 1         0.603092         0.633511        0.449773         0.484918
# 2         0.599310         0.633685        0.467521         0.225109
# 3         0.522509         0.606819        0.420189         0.132573
# 4         0.654624         0.686866        0.534992         0.588160
# 5         0.603380         0.643138        0.414236         0.500197
# 6         0.559584         0.589233        0.305874         0.156733
# 7         0.577107         0.604186        0.453185         0.515452
# 8         0.560933         0.604294        0.301552         0.143882
# 9         0.625018         0.575655        0.381603         0.261180
# 0         0.583207         0.553094        0.491287         0.415190
# 1         0.527387         0.559233        0.449773         0.373708
# 2         0.535538         0.563246        0.467521         0.380200
# 3         0.464524         0.536350        0.420189         0.338177
# 4         0.608245         0.640172        0.534992         0.417309
# 5         0.527997         0.568708        0.414236         0.365071
# 6         0.494581         0.465254        0.305874         0.271386
# 7         0.529275         0.565050        0.453185         0.369136
# 8         0.485504         0.494689        0.301552         0.254713
# 9         0.543145         0.505058        0.381603         0.307406
# 0              NaN              NaN        0.491287         0.415190
# 1              NaN              NaN        0.449773         0.373708
# 2              NaN              NaN        0.467521         0.380200
# 3              NaN              NaN        0.420189         0.338177
# 4              NaN              NaN        0.534992         0.417309
# 5              NaN              NaN        0.414236         0.365071
# 6              NaN              NaN        0.305874         0.271386
# 7              NaN              NaN        0.453185         0.369136
# 8              NaN              NaN        0.301552         0.254713
# 9              NaN              NaN        0.381603         0.307406
#
#    DirectAcc_ht29  DirectAcc_a375  \
# 0        0.642906        0.642906
# 1        0.631011        0.631011
# 2        0.626187        0.626187
# 3        0.617286        0.617286
# 4        0.646800        0.646800
# 5        0.626274        0.626274
# 6        0.590469        0.590469
# 7        0.629866        0.629866
# 8        0.581630        0.581630
# 9        0.603909        0.603909
# 0        0.642906        0.642906
# 1        0.631011        0.631011
# 2        0.626187        0.626187
# 3        0.617286        0.617286
# 4        0.646800        0.646800
# 5        0.626274        0.626274
# 6        0.590469        0.590469
# 7        0.629866        0.629866
# 8        0.581630        0.581630
# 9        0.603909        0.603909
# 0        0.642983        0.642983
# 1        0.631105        0.631105
# 2        0.626279        0.626279
# 3        0.617376        0.617376
# 4        0.646877        0.646877
# 5        0.626368        0.626368
# 6        0.590569        0.590569
# 7        0.629967        0.629967
# 8        0.581735        0.581735
# 9        0.604008        0.604008
# 0        0.642906        0.642906
# 1        0.631011        0.631011
# 2        0.626187        0.626187
# 3        0.617286        0.617286
# 4        0.646800        0.646800
# 5        0.626274        0.626274
# 6        0.590469        0.590469
# 7        0.629866        0.629866
# 8        0.581630        0.581630
# 9        0.603909        0.603909
# 0        0.642983        0.642983
# 1        0.631105        0.631105
# 2        0.626279        0.626279
# 3        0.617376        0.617376
# 4        0.646877        0.646877
# 5        0.626368        0.626368
# 6        0.590569        0.590569
# 7        0.629967        0.629967
# 8        0.581735        0.581735
# 9        0.604008        0.604008
# 0        0.642983        0.642983
# 1        0.631105        0.631105
# 2        0.626279        0.626279
# 3        0.617376        0.617376
# 4        0.646877        0.646877
# 5        0.626368        0.626368
# 6        0.590569        0.590569
# 7        0.629967        0.629967
# 8        0.581735        0.581735
# 9        0.604008        0.604008
#
#                                             model
# 0                                             DCS
# 1                                             DCS
# 2                                             DCS
# 3                                             DCS
# 4                                             DCS
# 5                                             DCS
# 6                                             DCS
# 7                                             DCS
# 8                                             DCS
# 9                                             DCS
# 0                                 DCS modified v1
# 1                                 DCS modified v1
# 2                                 DCS modified v1
# 3                                 DCS modified v1
# 4                                 DCS modified v1
# 5                                 DCS modified v1
# 6                                 DCS modified v1
# 7                                 DCS modified v1
# 8                                 DCS modified v1
# 9                                 DCS modified v1
# 0                 similarity-trained Autoencoders
# 1                 similarity-trained Autoencoders
# 2                 similarity-trained Autoencoders
# 3                 similarity-trained Autoencoders
# 4                 similarity-trained Autoencoders
# 5                 similarity-trained Autoencoders
# 6                 similarity-trained Autoencoders
# 7                 similarity-trained Autoencoders
# 8                 similarity-trained Autoencoders
# 9                 similarity-trained Autoencoders
# 0                                 DCS modified v2
# 1                                 DCS modified v2
# 2                                 DCS modified v2
# 3                                 DCS modified v2
# 4                                 DCS modified v2
# 5                                 DCS modified v2
# 6                                 DCS modified v2
# 7                                 DCS modified v2
# 8                                 DCS modified v2
# 9                                 DCS modified v2
# 0                          GAN-based Autoencoders
# 1                          GAN-based Autoencoders
# 2                          GAN-based Autoencoders
# 3                          GAN-based Autoencoders
# 4                          GAN-based Autoencoders
# 5                          GAN-based Autoencoders
# 6                          GAN-based Autoencoders
# 7                          GAN-based Autoencoders
# 8                          GAN-based Autoencoders
# 9                          GAN-based Autoencoders
# 0  TransCompR-combined and GAN-based Autoencoders
# 1  TransCompR-combined and GAN-based Autoencoders
# 2  TransCompR-combined and GAN-based Autoencoders
# 3  TransCompR-combined and GAN-based Autoencoders
# 4  TransCompR-combined and GAN-based Autoencoders
# 5  TransCompR-combined and GAN-based Autoencoders
# 6  TransCompR-combined and GAN-based Autoencoders
# 7  TransCompR-combined and GAN-based Autoencoders
# 8  TransCompR-combined and GAN-based Autoencoders
# 9  TransCompR-combined and GAN-based Autoencoders

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline],axis=0)
res_to_a375
# Out:
#      pearson  spearman  accuracy               model
# 0   0.599170  0.512294  0.680166                 DCS
# 1   0.558736  0.463245  0.665333                 DCS
# 2   0.582151  0.473071  0.661947                 DCS
# 3   0.514541  0.411831  0.644403                 DCS
# 4   0.635018  0.505391  0.680406                 DCS
# ..       ...       ...       ...                 ...
# 5   0.414236  0.365071  0.626368  direct translation
# 6   0.305874  0.271386  0.590569  direct translation
# 7   0.453185  0.369136  0.629967  direct translation
# 8   0.301552  0.254713  0.581735  direct translation
# 9   0.381603  0.307406  0.604008  direct translation
#
# [70 rows x 4 columns]

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#                   model    metric     value
# 0                   DCS   pearson  0.599170
# 1                   DCS   pearson  0.558736
# 2                   DCS   pearson  0.582151
# 3                   DCS   pearson  0.514541
# 4                   DCS   pearson  0.635018
# ..                  ...       ...       ...
# 205  direct translation  accuracy  0.626368
# 206  direct translation  accuracy  0.590569
# 207  direct translation  accuracy  0.629967
# 208  direct translation  accuracy  0.581735
# 209  direct translation  accuracy  0.604008
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.25)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_to_a375,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','GAN-based Autoencoders',
                   'TransCompR-combined and GAN-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
# statannot.add_stat_annotation(ax=ax, 
#                               data=res_to_a375,
#                               y="value",
#                               x="model",
#                               order=['direct translation','DCS',
#                                      'DCS modified v1','DCS modified v2',
#                                      'similarity-trained Autoencoders','GAN-based Autoencoders',
#                                      'TransCompR-combined and GAN-based Autoencoders'],
#                               hue_order = ['accuracy','pearson','spearman'],
#                               hue="metric",
#                               box_pairs=[
#                                   (("DCS", "pearson"), ("similarity-trained Autoencoders","pearson"))],
#                               test="Mann-Whitney",
#                               loc = 'inside',
#                               verbose=0
#                              )
plt.savefig('../figures/MI_results/allgenes_autoencoders_compare_allgenes_a375.png', bbox_inches='tight',dpi=600)

# %%
from scipy import stats

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders',
          'direct translation','GAN-based Autoencoders',
          'TransCompR-combined and GAN-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-30-089ea8c76e79>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-30-089ea8c76e79>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-31-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-31-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-32-748d6dd7cfa5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
# <ipython-input-32-748d6dd7cfa5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']]
a375_translate.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
a375_translate
# Out:
#                                                   metric  DCS  \
# DCS                                              pearson  1.0
# DCS modified v1                                  pearson  0.0
# DCS modified v2                                  pearson  0.0
# similarity-trained Autoencoders                  pearson  0.0
# direct translation                               pearson  0.0
# GAN-based Autoencoders                           pearson  0.0
# TransCompR-combined and GAN-based Autoencoders   pearson  0.0
# DCS                                             spearman  1.0
# DCS modified v1                                 spearman  0.0
# DCS modified v2                                 spearman  0.0
# similarity-trained Autoencoders                 spearman  0.0
# direct translation                              spearman  0.0
# GAN-based Autoencoders                          spearman  0.0
# TransCompR-combined and GAN-based Autoencoders  spearman  0.0
# DCS                                             accuracy  1.0
# DCS modified v1                                 accuracy  0.0
# DCS modified v2                                 accuracy  0.0
# similarity-trained Autoencoders                 accuracy  0.0
# direct translation                              accuracy  0.0
# GAN-based Autoencoders                          accuracy  0.0
# TransCompR-combined and GAN-based Autoencoders  accuracy  0.0
#
#                                                 DCS modified v1  \
# DCS                                                    0.850107
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    1.000000
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.969850
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 DCS modified v2  \
# DCS                                                    0.075662
# DCS modified v1                                        0.104110
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.088973
# DCS modified v1                                        0.104110
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.088973
# DCS modified v1                                        0.088973
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 similarity-trained Autoencoders  \
# DCS                                                                    0.384673
# DCS modified v1                                                        0.520523
# DCS modified v2                                                        0.241322
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.623176
# DCS modified v1                                                        0.677585
# DCS modified v2                                                        0.212294
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.623176
# DCS modified v1                                                        0.570750
# DCS modified v2                                                        0.344704
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
#
#                                                 direct translation  \
# DCS                                                       0.031209
# DCS modified v1                                           0.031209
# DCS modified v2                                           0.001315
# similarity-trained Autoencoders                           0.003611
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
# DCS                                                       0.025748
# DCS modified v1                                           0.025748
# DCS modified v2                                           0.001008
# similarity-trained Autoencoders                           0.003611
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
# DCS                                                       0.025748
# DCS modified v1                                           0.025748
# DCS modified v2                                           0.001706
# similarity-trained Autoencoders                           0.004586
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
#
#                                                 GAN-based Autoencoders  \
# DCS                                                           0.273036
# DCS modified v1                                               0.384673
# DCS modified v2                                               0.344704
# similarity-trained Autoencoders                               0.733730
# direct translation                                            0.005795
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.472676
# DCS modified v1                                               0.520523
# DCS modified v2                                               0.307489
# similarity-trained Autoencoders                               0.791337
# direct translation                                            0.002827
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.520523
# DCS modified v1                                               0.520523
# DCS modified v2                                               0.307489
# similarity-trained Autoencoders                               0.850107
# direct translation                                            0.003611
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
#
#                                                 TransCompR-combined and GAN-based Autoencoders
# DCS                                                                                   0.185877
# DCS modified v1                                                                       0.212294
# DCS modified v2                                                                       0.570750
# similarity-trained Autoencoders                                                       0.384673
# direct translation                                                                    0.001315
# GAN-based Autoencoders                                                                0.570750
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.307489
# DCS modified v1                                                                       0.307489
# DCS modified v2                                                                       0.427355
# similarity-trained Autoencoders                                                       0.427355
# direct translation                                                                    0.001706
# GAN-based Autoencoders                                                                0.623176
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.212294
# DCS modified v1                                                                       0.212294
# DCS modified v2                                                                       0.472676
# similarity-trained Autoencoders                                                       0.427355
# direct translation                                                                    0.002202
# GAN-based Autoencoders                                                                0.623176
# TransCompR-combined and GAN-based Autoencoders                                        1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_a375 = results.loc[:,['recon_pear_a375','recon_spear_a375','recon_acc_a375','model']]
res_recon_a375.columns = ['pearson','spearman','accuracy','model']
res_recon_a375
# Out:
#     pearson  spearman  accuracy  \
# 0  0.944607  0.931870  0.891681
# 1  0.942046  0.929751  0.889458
# 2  0.947642  0.935973  0.894833
# 3  0.941711  0.929063  0.889775
# 4  0.945411  0.933031  0.894141
# 5  0.946220  0.937022  0.896427
# 6  0.943144  0.932478  0.891758
# 7  0.941229  0.933005  0.893113
# 8  0.943884  0.935252  0.895268
# 9  0.940707  0.932645  0.893243
# 0  0.894737  0.871022  0.852468
# 1  0.894061  0.866142  0.848679
# 2  0.901794  0.876313  0.854598
# 3  0.887728  0.864473  0.848241
# 4  0.898279  0.871958  0.854948
# 5  0.903179  0.885072  0.862272
# 6  0.895989  0.876050  0.855333
# 7  0.893390  0.878501  0.858342
# 8  0.897282  0.880321  0.859161
# 9  0.892277  0.875791  0.856103
# 0  0.826383  0.756613  0.790215
# 1  0.818986  0.734010  0.778140
# 2  0.827975  0.761507  0.791721
# 3  0.813655  0.742145  0.783081
# 4  0.828014  0.752695  0.791035
# 5  0.831958  0.776322  0.801362
# 6  0.800847  0.731223  0.778329
# 7  0.818409  0.772086  0.799294
# 8  0.822378  0.775301  0.799670
# 9  0.803080  0.758384  0.792070
# 0  0.774872  0.686237  0.755247
# 1  0.777196  0.676526  0.750082
# 2  0.785535  0.702377  0.761791
# 3  0.768159  0.687787  0.756393
# 4  0.793090  0.704071  0.765778
# 5  0.776692  0.710172  0.767404
# 6  0.762495  0.697467  0.761097
# 7  0.723925  0.661135  0.744554
# 8  0.773076  0.712661  0.768941
# 9  0.764739  0.713006  0.769017
# 0  0.820469  0.746691  0.785728
# 1  0.814631  0.744231  0.783632
# 2  0.828589  0.760706  0.790942
# 3  0.808884  0.732363  0.778678
# 4  0.828356  0.755079  0.791811
# 5  0.832160  0.780179  0.804544
# 6  0.799361  0.744852  0.784965
# 7  0.816330  0.770359  0.798246
# 8  0.814963  0.761875  0.792260
# 9  0.803444  0.756039  0.791271
# 0  0.861666  0.831706  0.827744
# 1  0.867706  0.830984  0.827412
# 2  0.876625  0.840893  0.831185
# 3  0.863265  0.829932  0.827293
# 4  0.873245  0.843019  0.837052
# 5  0.875062  0.854330  0.841472
# 6  0.869891  0.843207  0.835253
# 7  0.856327  0.836144  0.832483
# 8  0.866323  0.845611  0.836843
# 9  0.852096  0.826328  0.823739
#
#                                             model
# 0                                             DCS
# 1                                             DCS
# 2                                             DCS
# 3                                             DCS
# 4                                             DCS
# 5                                             DCS
# 6                                             DCS
# 7                                             DCS
# 8                                             DCS
# 9                                             DCS
# 0                                 DCS modified v1
# 1                                 DCS modified v1
# 2                                 DCS modified v1
# 3                                 DCS modified v1
# 4                                 DCS modified v1
# 5                                 DCS modified v1
# 6                                 DCS modified v1
# 7                                 DCS modified v1
# 8                                 DCS modified v1
# 9                                 DCS modified v1
# 0                 similarity-trained Autoencoders
# 1                 similarity-trained Autoencoders
# 2                 similarity-trained Autoencoders
# 3                 similarity-trained Autoencoders
# 4                 similarity-trained Autoencoders
# 5                 similarity-trained Autoencoders
# 6                 similarity-trained Autoencoders
# 7                 similarity-trained Autoencoders
# 8                 similarity-trained Autoencoders
# 9                 similarity-trained Autoencoders
# 0                                 DCS modified v2
# 1                                 DCS modified v2
# 2                                 DCS modified v2
# 3                                 DCS modified v2
# 4                                 DCS modified v2
# 5                                 DCS modified v2
# 6                                 DCS modified v2
# 7                                 DCS modified v2
# 8                                 DCS modified v2
# 9                                 DCS modified v2
# 0                          GAN-based Autoencoders
# 1                          GAN-based Autoencoders
# 2                          GAN-based Autoencoders
# 3                          GAN-based Autoencoders
# 4                          GAN-based Autoencoders
# 5                          GAN-based Autoencoders
# 6                          GAN-based Autoencoders
# 7                          GAN-based Autoencoders
# 8                          GAN-based Autoencoders
# 9                          GAN-based Autoencoders
# 0  TransCompR-combined and GAN-based Autoencoders
# 1  TransCompR-combined and GAN-based Autoencoders
# 2  TransCompR-combined and GAN-based Autoencoders
# 3  TransCompR-combined and GAN-based Autoencoders
# 4  TransCompR-combined and GAN-based Autoencoders
# 5  TransCompR-combined and GAN-based Autoencoders
# 6  TransCompR-combined and GAN-based Autoencoders
# 7  TransCompR-combined and GAN-based Autoencoders
# 8  TransCompR-combined and GAN-based Autoencoders
# 9  TransCompR-combined and GAN-based Autoencoders

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#                                               model    metric     value
# 0                                               DCS   pearson  0.944607
# 1                                               DCS   pearson  0.942046
# 2                                               DCS   pearson  0.947642
# 3                                               DCS   pearson  0.941711
# 4                                               DCS   pearson  0.945411
# ..                                              ...       ...       ...
# 175  TransCompR-combined and GAN-based Autoencoders  accuracy  0.841472
# 176  TransCompR-combined and GAN-based Autoencoders  accuracy  0.835253
# 177  TransCompR-combined and GAN-based Autoencoders  accuracy  0.832483
# 178  TransCompR-combined and GAN-based Autoencoders  accuracy  0.836843
# 179  TransCompR-combined and GAN-based Autoencoders  accuracy  0.823739
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_recon_a375,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','GAN-based Autoencoders',
                   'TransCompR-combined and GAN-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_a375.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-37-0978ea0316cd>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-37-0978ea0316cd>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-38-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-38-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-39-7bf8ce6c3d50>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
# <ipython-input-39-7bf8ce6c3d50>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']]
a375_reconstruction.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                                                   metric  DCS  \
# DCS                                              pearson  1.0
# DCS modified v1                                  pearson  0.0
# DCS modified v2                                  pearson  0.0
# similarity-trained Autoencoders                  pearson  0.0
# GAN-based Autoencoders                           pearson  0.0
# TransCompR-combined and GAN-based Autoencoders   pearson  0.0
# DCS                                             spearman  1.0
# DCS modified v1                                 spearman  0.0
# DCS modified v2                                 spearman  0.0
# similarity-trained Autoencoders                 spearman  0.0
# GAN-based Autoencoders                          spearman  0.0
# TransCompR-combined and GAN-based Autoencoders  spearman  0.0
# DCS                                             accuracy  1.0
# DCS modified v1                                 accuracy  0.0
# DCS modified v2                                 accuracy  0.0
# similarity-trained Autoencoders                 accuracy  0.0
# GAN-based Autoencoders                          accuracy  0.0
# TransCompR-combined and GAN-based Autoencoders  accuracy  0.0
#
#                                                 DCS modified v1  \
# DCS                                                    0.850107
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 DCS modified v2  \
# DCS                                                    0.075662
# DCS modified v1                                        0.104110
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        0.000183
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        0.000183
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 similarity-trained Autoencoders  \
# DCS                                                                    0.384673
# DCS modified v1                                                        0.520523
# DCS modified v2                                                        0.241322
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.000183
# DCS modified v1                                                        0.000183
# DCS modified v2                                                        0.000183
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.000183
# DCS modified v1                                                        0.000183
# DCS modified v2                                                        0.000183
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
#
#                                                 GAN-based Autoencoders  \
# DCS                                                           0.273036
# DCS modified v1                                               0.384673
# DCS modified v2                                               0.344704
# similarity-trained Autoencoders                               0.733730
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.000183
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               0.909722
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.000183
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000183
# similarity-trained Autoencoders                               1.000000
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
#
#                                                 TransCompR-combined and GAN-based Autoencoders
# DCS                                                                                   0.185877
# DCS modified v1                                                                       0.212294
# DCS modified v2                                                                       0.570750
# similarity-trained Autoencoders                                                       0.384673
# GAN-based Autoencoders                                                                0.570750
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.000183
# DCS modified v1                                                                       0.000183
# DCS modified v2                                                                       0.000183
# similarity-trained Autoencoders                                                       0.000183
# GAN-based Autoencoders                                                                0.000183
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.000183
# DCS modified v1                                                                       0.000183
# DCS modified v2                                                                       0.000183
# similarity-trained Autoencoders                                                       0.000183
# GAN-based Autoencoders                                                                0.000183
# TransCompR-combined and GAN-based Autoencoders                                        1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline],axis=0)
res_to_ht29
# Out:
#      pearson  spearman  accuracy               model
# 0   0.613718  0.526330  0.685056                 DCS
# 1   0.566115  0.464582  0.663853                 DCS
# 2   0.609149  0.492402  0.667321                 DCS
# 3   0.530387  0.418556  0.646344                 DCS
# 4   0.649465  0.522971  0.686253                 DCS
# ..       ...       ...       ...                 ...
# 5   0.414236  0.365071  0.626368  direct translation
# 6   0.305874  0.271386  0.590569  direct translation
# 7   0.453185  0.369136  0.629967  direct translation
# 8   0.301552  0.254713  0.581735  direct translation
# 9   0.381603  0.307406  0.604008  direct translation
#
# [70 rows x 4 columns]

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#                   model    metric     value
# 0                   DCS   pearson  0.613718
# 1                   DCS   pearson  0.566115
# 2                   DCS   pearson  0.609149
# 3                   DCS   pearson  0.530387
# 4                   DCS   pearson  0.649465
# ..                  ...       ...       ...
# 205  direct translation  accuracy  0.626368
# 206  direct translation  accuracy  0.590569
# 207  direct translation  accuracy  0.629967
# 208  direct translation  accuracy  0.581735
# 209  direct translation  accuracy  0.604008
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_to_ht29,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','GAN-based Autoencoders',
                   'TransCompR-combined and GAN-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_autoencoders_comparison_allgenes_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-44-97a09e4ee7f4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-44-97a09e4ee7f4>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-45-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-45-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-46-c5c1bf237c12>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
# <ipython-input-46-c5c1bf237c12>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']]
ht29_translate.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
ht29_translate
# Out:
#                                                   metric  DCS  \
# DCS                                              pearson  1.0
# DCS modified v1                                  pearson  0.0
# DCS modified v2                                  pearson  0.0
# similarity-trained Autoencoders                  pearson  0.0
# direct translation                               pearson  0.0
# GAN-based Autoencoders                           pearson  0.0
# TransCompR-combined and GAN-based Autoencoders   pearson  0.0
# DCS                                             spearman  1.0
# DCS modified v1                                 spearman  0.0
# DCS modified v2                                 spearman  0.0
# similarity-trained Autoencoders                 spearman  0.0
# direct translation                              spearman  0.0
# GAN-based Autoencoders                          spearman  0.0
# TransCompR-combined and GAN-based Autoencoders  spearman  0.0
# DCS                                             accuracy  1.0
# DCS modified v1                                 accuracy  0.0
# DCS modified v2                                 accuracy  0.0
# similarity-trained Autoencoders                 accuracy  0.0
# direct translation                              accuracy  0.0
# GAN-based Autoencoders                          accuracy  0.0
# TransCompR-combined and GAN-based Autoencoders  accuracy  0.0
#
#                                                 DCS modified v1  \
# DCS                                                    0.909722
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.969850
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.909722
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 DCS modified v2  \
# DCS                                                    0.021134
# DCS modified v1                                        0.037635
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.053903
# DCS modified v1                                        0.037635
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.053903
# DCS modified v1                                        0.037635
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# direct translation                                     0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 similarity-trained Autoencoders  \
# DCS                                                                    0.185877
# DCS modified v1                                                        0.185877
# DCS modified v2                                                        0.427355
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.212294
# DCS modified v1                                                        0.212294
# DCS modified v2                                                        0.273036
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.307489
# DCS modified v1                                                        0.273036
# DCS modified v2                                                        0.307489
# similarity-trained Autoencoders                                        1.000000
# direct translation                                                     0.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
#
#                                                 direct translation  \
# DCS                                                       0.021134
# DCS modified v1                                           0.021134
# DCS modified v2                                           0.000183
# similarity-trained Autoencoders                           0.000330
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
# DCS                                                       0.011330
# DCS modified v1                                           0.011330
# DCS modified v2                                           0.000183
# similarity-trained Autoencoders                           0.000583
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
# DCS                                                       0.017257
# DCS modified v1                                           0.017257
# DCS modified v2                                           0.000183
# similarity-trained Autoencoders                           0.001008
# direct translation                                        1.000000
# GAN-based Autoencoders                                    0.000000
# TransCompR-combined and GAN-based Autoencoders            0.000000
#
#                                                 GAN-based Autoencoders  \
# DCS                                                           0.075662
# DCS modified v1                                               0.088973
# DCS modified v2                                               0.570750
# similarity-trained Autoencoders                               0.733730
# direct translation                                            0.000330
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.161972
# DCS modified v1                                               0.161972
# DCS modified v2                                               0.384673
# similarity-trained Autoencoders                               0.677585
# direct translation                                            0.000330
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.212294
# DCS modified v1                                               0.212294
# DCS modified v2                                               0.427355
# similarity-trained Autoencoders                               0.677585
# direct translation                                            0.000583
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
#
#                                                 TransCompR-combined and GAN-based Autoencoders
# DCS                                                                                   0.045155
# DCS modified v1                                                                       0.088973
# DCS modified v2                                                                       0.623176
# similarity-trained Autoencoders                                                       0.472676
# direct translation                                                                    0.000330
# GAN-based Autoencoders                                                                0.733730
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.064022
# DCS modified v1                                                                       0.053903
# DCS modified v2                                                                       0.733730
# similarity-trained Autoencoders                                                       0.472676
# direct translation                                                                    0.000330
# GAN-based Autoencoders                                                                0.677585
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.064022
# DCS modified v1                                                                       0.064022
# DCS modified v2                                                                       0.791337
# similarity-trained Autoencoders                                                       0.427355
# direct translation                                                                    0.000440
# GAN-based Autoencoders                                                                0.623176
# TransCompR-combined and GAN-based Autoencoders                                        1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','accuracy','model']
res_recon_ht29
# Out:
#     pearson  spearman  accuracy  \
# 0  0.947445  0.937704  0.896936
# 1  0.945406  0.934308  0.894100
# 2  0.942116  0.933452  0.893411
# 3  0.944477  0.933683  0.894614
# 4  0.950940  0.942423  0.903572
# 5  0.952127  0.942698  0.903724
# 6  0.947209  0.939710  0.900714
# 7  0.951822  0.944159  0.905886
# 8  0.946720  0.939709  0.901069
# 9  0.944046  0.935589  0.895927
# 0  0.905294  0.882624  0.858544
# 1  0.899689  0.877359  0.855455
# 2  0.890714  0.871069  0.852250
# 3  0.894254  0.871414  0.852953
# 4  0.909243  0.892813  0.868540
# 5  0.912985  0.893661  0.869312
# 6  0.901663  0.885650  0.863277
# 7  0.913307  0.898859  0.873773
# 8  0.904954  0.889883  0.866144
# 9  0.896798  0.877517  0.857071
# 0  0.830313  0.775642  0.796885
# 1  0.824589  0.761464  0.792661
# 2  0.812255  0.762062  0.792232
# 3  0.826020  0.771951  0.797735
# 4  0.846574  0.804735  0.817642
# 5  0.853151  0.811846  0.821536
# 6  0.833748  0.793034  0.811242
# 7  0.849627  0.814801  0.824357
# 8  0.838561  0.800195  0.815394
# 9  0.816862  0.760642  0.792421
# 0  0.792076  0.723574  0.772086
# 1  0.783562  0.711663  0.765846
# 2  0.776529  0.707050  0.764035
# 3  0.774928  0.699053  0.762112
# 4  0.823872  0.773560  0.799868
# 5  0.799070  0.748566  0.788570
# 6  0.798056  0.746831  0.787282
# 7  0.796374  0.752913  0.793152
# 8  0.786902  0.741768  0.783793
# 9  0.781035  0.723354  0.773273
# 0  0.835169  0.780231  0.801800
# 1  0.828786  0.767704  0.795398
# 2  0.807937  0.755687  0.789337
# 3  0.822836  0.767055  0.796170
# 4  0.845713  0.809343  0.819980
# 5  0.847676  0.806944  0.819358
# 6  0.827314  0.789109  0.809588
# 7  0.851542  0.815302  0.825445
# 8  0.835067  0.799301  0.814475
# 9  0.819369  0.768452  0.797549
# 0  0.879440  0.847197  0.836858
# 1  0.864738  0.831556  0.826465
# 2  0.856943  0.826870  0.823209
# 3  0.868115  0.840600  0.834136
# 4  0.882092  0.861618  0.849000
# 5  0.877534  0.861290  0.847646
# 6  0.875646  0.855310  0.844256
# 7  0.881350  0.864614  0.850979
# 8  0.876735  0.857992  0.845584
# 9  0.869873  0.846019  0.838051
#
#                                             model
# 0                                             DCS
# 1                                             DCS
# 2                                             DCS
# 3                                             DCS
# 4                                             DCS
# 5                                             DCS
# 6                                             DCS
# 7                                             DCS
# 8                                             DCS
# 9                                             DCS
# 0                                 DCS modified v1
# 1                                 DCS modified v1
# 2                                 DCS modified v1
# 3                                 DCS modified v1
# 4                                 DCS modified v1
# 5                                 DCS modified v1
# 6                                 DCS modified v1
# 7                                 DCS modified v1
# 8                                 DCS modified v1
# 9                                 DCS modified v1
# 0                 similarity-trained Autoencoders
# 1                 similarity-trained Autoencoders
# 2                 similarity-trained Autoencoders
# 3                 similarity-trained Autoencoders
# 4                 similarity-trained Autoencoders
# 5                 similarity-trained Autoencoders
# 6                 similarity-trained Autoencoders
# 7                 similarity-trained Autoencoders
# 8                 similarity-trained Autoencoders
# 9                 similarity-trained Autoencoders
# 0                                 DCS modified v2
# 1                                 DCS modified v2
# 2                                 DCS modified v2
# 3                                 DCS modified v2
# 4                                 DCS modified v2
# 5                                 DCS modified v2
# 6                                 DCS modified v2
# 7                                 DCS modified v2
# 8                                 DCS modified v2
# 9                                 DCS modified v2
# 0                          GAN-based Autoencoders
# 1                          GAN-based Autoencoders
# 2                          GAN-based Autoencoders
# 3                          GAN-based Autoencoders
# 4                          GAN-based Autoencoders
# 5                          GAN-based Autoencoders
# 6                          GAN-based Autoencoders
# 7                          GAN-based Autoencoders
# 8                          GAN-based Autoencoders
# 9                          GAN-based Autoencoders
# 0  TransCompR-combined and GAN-based Autoencoders
# 1  TransCompR-combined and GAN-based Autoencoders
# 2  TransCompR-combined and GAN-based Autoencoders
# 3  TransCompR-combined and GAN-based Autoencoders
# 4  TransCompR-combined and GAN-based Autoencoders
# 5  TransCompR-combined and GAN-based Autoencoders
# 6  TransCompR-combined and GAN-based Autoencoders
# 7  TransCompR-combined and GAN-based Autoencoders
# 8  TransCompR-combined and GAN-based Autoencoders
# 9  TransCompR-combined and GAN-based Autoencoders

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#                                               model    metric     value
# 0                                               DCS   pearson  0.947445
# 1                                               DCS   pearson  0.945406
# 2                                               DCS   pearson  0.942116
# 3                                               DCS   pearson  0.944477
# 4                                               DCS   pearson  0.950940
# ..                                              ...       ...       ...
# 175  TransCompR-combined and GAN-based Autoencoders  accuracy  0.847646
# 176  TransCompR-combined and GAN-based Autoencoders  accuracy  0.844256
# 177  TransCompR-combined and GAN-based Autoencoders  accuracy  0.850979
# 178  TransCompR-combined and GAN-based Autoencoders  accuracy  0.845584
# 179  TransCompR-combined and GAN-based Autoencoders  accuracy  0.838051
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(9,12), dpi= 80)
ax = sns.barplot(x="value", y="model", data=res_recon_ht29,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','GAN-based Autoencoders',
                   'TransCompR-combined and GAN-based Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-52-1c7a3d8bd679>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-52-1c7a3d8bd679>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-53-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-53-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-54-12b8fd9ef33b>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
# <ipython-input-54-12b8fd9ef33b>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','GAN-based Autoencoders','TransCompR-combined and GAN-based Autoencoders']]
ht29_reconstruction.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                                                   metric  DCS  \
# DCS                                              pearson  1.0
# DCS modified v1                                  pearson  0.0
# DCS modified v2                                  pearson  0.0
# similarity-trained Autoencoders                  pearson  0.0
# GAN-based Autoencoders                           pearson  0.0
# TransCompR-combined and GAN-based Autoencoders   pearson  0.0
# DCS                                             spearman  1.0
# DCS modified v1                                 spearman  0.0
# DCS modified v2                                 spearman  0.0
# similarity-trained Autoencoders                 spearman  0.0
# GAN-based Autoencoders                          spearman  0.0
# TransCompR-combined and GAN-based Autoencoders  spearman  0.0
# DCS                                             accuracy  1.0
# DCS modified v1                                 accuracy  0.0
# DCS modified v2                                 accuracy  0.0
# similarity-trained Autoencoders                 accuracy  0.0
# GAN-based Autoencoders                          accuracy  0.0
# TransCompR-combined and GAN-based Autoencoders  accuracy  0.0
#
#                                                 DCS modified v1  \
# DCS                                                    0.000183
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        1.000000
# DCS modified v2                                        0.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 DCS modified v2  \
# DCS                                                    0.000183
# DCS modified v1                                        0.000183
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        0.000183
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
# DCS                                                    0.000183
# DCS modified v1                                        0.000183
# DCS modified v2                                        1.000000
# similarity-trained Autoencoders                        0.000000
# GAN-based Autoencoders                                 0.000000
# TransCompR-combined and GAN-based Autoencoders         0.000000
#
#                                                 similarity-trained Autoencoders  \
# DCS                                                                    0.000183
# DCS modified v1                                                        0.000183
# DCS modified v2                                                        0.000330
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.000183
# DCS modified v1                                                        0.000183
# DCS modified v2                                                        0.000583
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
# DCS                                                                    0.000183
# DCS modified v1                                                        0.000183
# DCS modified v2                                                        0.001706
# similarity-trained Autoencoders                                        1.000000
# GAN-based Autoencoders                                                 0.000000
# TransCompR-combined and GAN-based Autoencoders                         0.000000
#
#                                                 GAN-based Autoencoders  \
# DCS                                                           0.000183
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000440
# similarity-trained Autoencoders                               0.909722
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.000183
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000583
# similarity-trained Autoencoders                               0.969850
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
# DCS                                                           0.000183
# DCS modified v1                                               0.000183
# DCS modified v2                                               0.000769
# similarity-trained Autoencoders                               0.909722
# GAN-based Autoencoders                                        1.000000
# TransCompR-combined and GAN-based Autoencoders                0.000000
#
#                                                 TransCompR-combined and GAN-based Autoencoders
# DCS                                                                                   0.000183
# DCS modified v1                                                                       0.000183
# DCS modified v2                                                                       0.000183
# similarity-trained Autoencoders                                                       0.000183
# GAN-based Autoencoders                                                                0.000183
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.000183
# DCS modified v1                                                                       0.000183
# DCS modified v2                                                                       0.000183
# similarity-trained Autoencoders                                                       0.000183
# GAN-based Autoencoders                                                                0.000183
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
# DCS                                                                                   0.000183
# DCS modified v1                                                                       0.000183
# DCS modified v2                                                                       0.000183
# similarity-trained Autoencoders                                                       0.000246
# GAN-based Autoencoders                                                                0.000246
# TransCompR-combined and GAN-based Autoencoders                                        1.000000
