# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Compare DeepCellState variations

# %%
import seaborn as sns
sns.set()

# %%
res_dcs_noise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_with_noise_10k.csv',index_col=0)
res_dcs_noise['model'] = 'DCS'
res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_no_noise_10k.csv',index_col=0)
res_dcs_nonoise['model'] = 'DCS modified v1'
res_notvae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_notvae_results1000ep512bs.csv',index_col=0)
res_notvae_2encs['model'] = 'Two Autoencoders'
res_dcs_direct = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_direct_andl2similarity_10k.csv',index_col=0)
res_dcs_direct['model'] = 'DCS modified v2'
baseline = pd.read_csv('../results/baseline_evaluation_allgenes.csv',index_col=0)
baseline = baseline.drop_duplicates()

# add mi
res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
res_mi['model'] = 'MI Autoencoders'

# %%
# # add mi
# res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_pc3_ha1e.csv',index_col=0)
# res_mi['model'] = 'Translation Model'

# res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_2000ep512bs_pc3_ha1e_withclass.csv',index_col=0)
# res_mi_class['model'] = 'Translation Model with classifier'

# %%
# res_dcs_noise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_withnoise.csv',index_col=0)
# res_dcs_noise['model'] = 'DCS'
# res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_no_noise.csv',index_col=0)
# res_dcs_nonoise['model'] = 'DCS modified v1'
# res_notvae_2encs = pd.read_csv('../results/my_results/landmarks_10foldvalidation_vae_results1000ep512bs.csv',index_col=0)
# res_notvae_2encs['model'] = 'Two Autoencoders'
# res_dcs_direct = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_direct_and_l2similarity.csv',index_col=0)
# res_dcs_direct['model'] = 'DCS modified v2'
# baseline = pd.read_csv('../results/baseline_evaluation_landmarks.csv',index_col=0)
# baseline = baseline.drop_duplicates()

# # # add mi
# # res_mi = pd.read_csv('../results/MI_results/landmarks_10foldvalidation_pretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
# # res_mi['model'] = 'MI Autoencoders'

# %%
results = pd.concat([res_dcs_noise,res_dcs_nonoise,res_notvae_2encs,res_dcs_direct,res_mi],axis=0)
results
# Out:
#    model_pearsonHT29  model_pearsonA375  model_spearHT29  model_spearA375  \
# 0           0.613718           0.599170         0.526330         0.512294
# 1           0.566115           0.558736         0.464582         0.463245
# 2           0.609149           0.582151         0.492402         0.473071
# 3           0.530387           0.514541         0.418556         0.411831
# 4           0.649465           0.635018         0.522971         0.505391
# 5           0.517710           0.500510         0.456342         0.436321
# 6           0.379070           0.377209         0.345177         0.332456
# 7           0.565623           0.548966         0.465607         0.445844
# 8           0.390222           0.374094         0.324936         0.311553
# 9           0.470474           0.465445         0.379353         0.370936
# 0           0.618526           0.601937         0.533965         0.514301
# 1           0.565272           0.555866         0.463171         0.456192
# 2           0.616632           0.590337         0.495240         0.481992
# 3           0.531053           0.513541         0.421344         0.411026
# 4           0.661082           0.639639         0.532603         0.509573
# 5           0.522730           0.501386         0.454013         0.436072
# 6           0.378412           0.375514         0.341890         0.329808
# 7           0.563070           0.552748         0.461913         0.441782
# 8           0.396872           0.380036         0.328490         0.315809
# 9           0.475924           0.465739         0.379794         0.372564
# 0           0.666739           0.564090         0.562238         0.488221
# 1           0.591782           0.572697         0.478091         0.431274
# 2           0.703306           0.637546         0.599642         0.542747
# 3           0.595689           0.585109         0.465942         0.473938
# 4           0.621247           0.639732         0.519357         0.538977
# 5           0.554374           0.533395         0.456431         0.418876
# 6           0.505563           0.469591         0.401197         0.384238
# 7           0.630244           0.550840         0.542571         0.440696
# 8           0.501270           0.399251         0.382562         0.324429
# 9           0.554151           0.511755         0.449934         0.414483
# 0           0.694047           0.564707         0.600927         0.489972
# 1           0.601810           0.608006         0.483167         0.489876
# 2           0.702464           0.650462         0.591011         0.543741
# 3           0.611520           0.602023         0.487644         0.487823
# 4           0.700402           0.668152         0.579689         0.571824
# 5           0.618214           0.582899         0.508138         0.478771
# 6           0.541515           0.474985         0.458018         0.415385
# 7           0.651315           0.599302         0.568369         0.483529
# 8           0.545906           0.442222         0.435823         0.368281
# 9           0.571278           0.566806         0.464479         0.464336
# 0           0.667348           0.574139         0.577731         0.494421
# 1           0.577154           0.590913         0.459355         0.453064
# 2           0.706598           0.637148         0.601433         0.540541
# 3           0.593213           0.588596         0.456560         0.473792
# 4           0.654452           0.635853         0.557725         0.535623
# 5           0.575751           0.552753         0.485382         0.432631
# 6           0.528944           0.440748         0.433714         0.379072
# 7           0.632949           0.566633         0.544343         0.452295
# 8           0.505198           0.405110         0.386525         0.325354
# 9           0.573678           0.519431         0.461137         0.425053
#
#    model_accHT29  model_accA375  recon_pear_ht29  recon_pear_a375  \
# 0       0.685056       0.680166         0.947445         0.944607
# 1       0.663853       0.665333         0.945406         0.942046
# 2       0.667321       0.661947         0.942116         0.947642
# 3       0.646344       0.644403         0.944477         0.941711
# 4       0.686253       0.680406         0.950940         0.945411
# 5       0.659744       0.653069         0.952127         0.946220
# 6       0.616173       0.611459         0.947209         0.943144
# 7       0.665412       0.657116         0.951822         0.941229
# 8       0.606323       0.601103         0.946720         0.943884
# 9       0.630049       0.627560         0.944046         0.940707
# 0       0.687864       0.679744         0.905294         0.894737
# 1       0.664461       0.661640         0.899689         0.894061
# 2       0.668776       0.665608         0.890714         0.901794
# 3       0.646993       0.643278         0.894254         0.887728
# 4       0.690038       0.682260         0.909243         0.898279
# 5       0.658797       0.652305         0.912985         0.903179
# 6       0.613987       0.610309         0.901663         0.895989
# 7       0.664334       0.656710         0.913307         0.893390
# 8       0.608237       0.602734         0.904954         0.897282
# 9       0.629836       0.627878         0.896798         0.892277
# 0       0.699960       0.672665         0.830313         0.826383
# 1       0.665911       0.652558         0.824589         0.818986
# 2       0.715648       0.692009         0.812255         0.827975
# 3       0.664803       0.670647         0.826020         0.813655
# 4       0.684905       0.692943         0.846574         0.828014
# 5       0.658123       0.645286         0.853151         0.831958
# 6       0.635842       0.629828         0.833748         0.800847
# 7       0.693754       0.653587         0.849627         0.818409
# 8       0.628646       0.604494         0.838561         0.822378
# 9       0.656046       0.647380         0.816862         0.803080
# 0       0.714731       0.672886         0.792076         0.774872
# 1       0.669611       0.675419         0.783562         0.777196
# 2       0.709213       0.691394         0.776529         0.785535
# 3       0.672209       0.675568         0.774928         0.768159
# 4       0.708608       0.708943         0.823872         0.793090
# 5       0.677833       0.669765         0.799070         0.776692
# 6       0.659471       0.641724         0.798056         0.762495
# 7       0.706301       0.668620         0.796374         0.723925
# 8       0.648426       0.622705         0.786902         0.773076
# 9       0.659345       0.665881         0.781035         0.764739
# 0       0.704729       0.673265         0.835169         0.820469
# 1       0.658361       0.661112         0.828786         0.814631
# 2       0.716949       0.686692         0.807937         0.828589
# 3       0.660867       0.671086         0.822836         0.808884
# 4       0.701383       0.690730         0.845713         0.828356
# 5       0.672650       0.651852         0.847676         0.832160
# 6       0.651624       0.629179         0.827314         0.799361
# 7       0.694205       0.656526         0.851542         0.816330
# 8       0.628820       0.606410         0.835067         0.814963
# 9       0.657622       0.651626         0.819369         0.803444
#
#    recon_spear_ht29  recon_spear_a375  recon_acc_ht29  recon_acc_a375  \
# 0          0.937704          0.931870        0.896936        0.891681
# 1          0.934308          0.929751        0.894100        0.889458
# 2          0.933452          0.935973        0.893411        0.894833
# 3          0.933683          0.929063        0.894614        0.889775
# 4          0.942423          0.933031        0.903572        0.894141
# 5          0.942698          0.937022        0.903724        0.896427
# 6          0.939710          0.932478        0.900714        0.891758
# 7          0.944159          0.933005        0.905886        0.893113
# 8          0.939709          0.935252        0.901069        0.895268
# 9          0.935589          0.932645        0.895927        0.893243
# 0          0.882624          0.871022        0.858544        0.852468
# 1          0.877359          0.866142        0.855455        0.848679
# 2          0.871069          0.876313        0.852250        0.854598
# 3          0.871414          0.864473        0.852953        0.848241
# 4          0.892813          0.871958        0.868540        0.854948
# 5          0.893661          0.885072        0.869312        0.862272
# 6          0.885650          0.876050        0.863277        0.855333
# 7          0.898859          0.878501        0.873773        0.858342
# 8          0.889883          0.880321        0.866144        0.859161
# 9          0.877517          0.875791        0.857071        0.856103
# 0          0.775642          0.756613        0.796885        0.790215
# 1          0.761464          0.734010        0.792661        0.778140
# 2          0.762062          0.761507        0.792232        0.791721
# 3          0.771951          0.742145        0.797735        0.783081
# 4          0.804735          0.752695        0.817642        0.791035
# 5          0.811846          0.776322        0.821536        0.801362
# 6          0.793034          0.731223        0.811242        0.778329
# 7          0.814801          0.772086        0.824357        0.799294
# 8          0.800195          0.775301        0.815394        0.799670
# 9          0.760642          0.758384        0.792421        0.792070
# 0          0.723574          0.686237        0.772086        0.755247
# 1          0.711663          0.676526        0.765846        0.750082
# 2          0.707050          0.702377        0.764035        0.761791
# 3          0.699053          0.687787        0.762112        0.756393
# 4          0.773560          0.704071        0.799868        0.765778
# 5          0.748566          0.710172        0.788570        0.767404
# 6          0.746831          0.697467        0.787282        0.761097
# 7          0.752913          0.661135        0.793152        0.744554
# 8          0.741768          0.712661        0.783793        0.768941
# 9          0.723354          0.713006        0.773273        0.769017
# 0          0.780231          0.746691        0.801800        0.785728
# 1          0.767704          0.744231        0.795398        0.783632
# 2          0.755687          0.760706        0.789337        0.790942
# 3          0.767055          0.732363        0.796170        0.778678
# 4          0.809343          0.755079        0.819980        0.791811
# 5          0.806944          0.780179        0.819358        0.804544
# 6          0.789109          0.744852        0.809588        0.784965
# 7          0.815302          0.770359        0.825445        0.798246
# 8          0.799301          0.761875        0.814475        0.792260
# 9          0.768452          0.756039        0.797549        0.791271
#
#    cross_corr_ht29  cross_corr_a375  Direct_pearson  Direct_spearman  \
# 0         0.920867         0.920973        0.491287         0.213417
# 1         0.915497         0.915471        0.449773         0.484918
# 2         0.911275         0.915116        0.467521         0.225109
# 3         0.913457         0.919640        0.420189         0.132573
# 4         0.923569         0.925903        0.534992         0.588160
# 5         0.915390         0.922801        0.414236         0.500197
# 6         0.918249         0.919547        0.305874         0.156733
# 7         0.916835         0.922630        0.453185         0.515452
# 8         0.913029         0.914657        0.301552         0.143882
# 9         0.918858         0.917644        0.381603         0.261180
# 0         0.844822         0.848965        0.491287         0.213417
# 1         0.833210         0.842814        0.449773         0.484918
# 2         0.821369         0.836068        0.467521         0.225109
# 3         0.819174         0.842463        0.420189         0.132573
# 4         0.843547         0.855155        0.534992         0.588160
# 5         0.833371         0.854004        0.414236         0.500197
# 6         0.838858         0.841392        0.305874         0.156733
# 7         0.833406         0.853190        0.453185         0.515452
# 8         0.824562         0.836484        0.301552         0.143882
# 9         0.840801         0.840325        0.381603         0.261180
# 0         0.561255         0.539134        0.491287         0.415190
# 1         0.525529         0.551173        0.449773         0.373708
# 2         0.536881         0.556446        0.467521         0.380200
# 3         0.461170         0.527485        0.420189         0.338177
# 4         0.571863         0.636663        0.534992         0.417309
# 5         0.500165         0.544733        0.414236         0.365071
# 6         0.461660         0.456088        0.305874         0.271386
# 7         0.518081         0.540003        0.453185         0.369136
# 8         0.494669         0.475472        0.301552         0.254713
# 9         0.525332         0.503635        0.381603         0.307406
# 0         0.642537         0.560727        0.491287         0.213417
# 1         0.603092         0.633511        0.449773         0.484918
# 2         0.599310         0.633685        0.467521         0.225109
# 3         0.522509         0.606819        0.420189         0.132573
# 4         0.654624         0.686866        0.534992         0.588160
# 5         0.603380         0.643138        0.414236         0.500197
# 6         0.559584         0.589233        0.305874         0.156733
# 7         0.577107         0.604186        0.453185         0.515452
# 8         0.560933         0.604294        0.301552         0.143882
# 9         0.625018         0.575655        0.381603         0.261180
# 0         0.583207         0.553094        0.491287         0.415190
# 1         0.527387         0.559233        0.449773         0.373708
# 2         0.535538         0.563246        0.467521         0.380200
# 3         0.464524         0.536350        0.420189         0.338177
# 4         0.608245         0.640172        0.534992         0.417309
# 5         0.527997         0.568708        0.414236         0.365071
# 6         0.494581         0.465254        0.305874         0.271386
# 7         0.529275         0.565050        0.453185         0.369136
# 8         0.485504         0.494689        0.301552         0.254713
# 9         0.543145         0.505058        0.381603         0.307406
#
#    DirectAcc_ht29  DirectAcc_a375             model
# 0        0.642906        0.642906               DCS
# 1        0.631011        0.631011               DCS
# 2        0.626187        0.626187               DCS
# 3        0.617286        0.617286               DCS
# 4        0.646800        0.646800               DCS
# 5        0.626274        0.626274               DCS
# 6        0.590469        0.590469               DCS
# 7        0.629866        0.629866               DCS
# 8        0.581630        0.581630               DCS
# 9        0.603909        0.603909               DCS
# 0        0.642906        0.642906   DCS modified v1
# 1        0.631011        0.631011   DCS modified v1
# 2        0.626187        0.626187   DCS modified v1
# 3        0.617286        0.617286   DCS modified v1
# 4        0.646800        0.646800   DCS modified v1
# 5        0.626274        0.626274   DCS modified v1
# 6        0.590469        0.590469   DCS modified v1
# 7        0.629866        0.629866   DCS modified v1
# 8        0.581630        0.581630   DCS modified v1
# 9        0.603909        0.603909   DCS modified v1
# 0        0.642983        0.642983  Two Autoencoders
# 1        0.631105        0.631105  Two Autoencoders
# 2        0.626279        0.626279  Two Autoencoders
# 3        0.617376        0.617376  Two Autoencoders
# 4        0.646877        0.646877  Two Autoencoders
# 5        0.626368        0.626368  Two Autoencoders
# 6        0.590569        0.590569  Two Autoencoders
# 7        0.629967        0.629967  Two Autoencoders
# 8        0.581735        0.581735  Two Autoencoders
# 9        0.604008        0.604008  Two Autoencoders
# 0        0.642906        0.642906   DCS modified v2
# 1        0.631011        0.631011   DCS modified v2
# 2        0.626187        0.626187   DCS modified v2
# 3        0.617286        0.617286   DCS modified v2
# 4        0.646800        0.646800   DCS modified v2
# 5        0.626274        0.626274   DCS modified v2
# 6        0.590469        0.590469   DCS modified v2
# 7        0.629866        0.629866   DCS modified v2
# 8        0.581630        0.581630   DCS modified v2
# 9        0.603909        0.603909   DCS modified v2
# 0        0.642983        0.642983   MI Autoencoders
# 1        0.631105        0.631105   MI Autoencoders
# 2        0.626279        0.626279   MI Autoencoders
# 3        0.617376        0.617376   MI Autoencoders
# 4        0.646877        0.646877   MI Autoencoders
# 5        0.626368        0.626368   MI Autoencoders
# 6        0.590569        0.590569   MI Autoencoders
# 7        0.629967        0.629967   MI Autoencoders
# 8        0.581735        0.581735   MI Autoencoders
# 9        0.604008        0.604008   MI Autoencoders

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline],axis=0)
res_to_a375
# Out:
#     pearson  spearman  accuracy               model
# 0  0.599170  0.512294  0.680166                 DCS
# 1  0.558736  0.463245  0.665333                 DCS
# 2  0.582151  0.473071  0.661947                 DCS
# 3  0.514541  0.411831  0.644403                 DCS
# 4  0.635018  0.505391  0.680406                 DCS
# 5  0.500510  0.436321  0.653069                 DCS
# 6  0.377209  0.332456  0.611459                 DCS
# 7  0.548966  0.445844  0.657116                 DCS
# 8  0.374094  0.311553  0.601103                 DCS
# 9  0.465445  0.370936  0.627560                 DCS
# 0  0.601937  0.514301  0.679744     DCS modified v1
# 1  0.555866  0.456192  0.661640     DCS modified v1
# 2  0.590337  0.481992  0.665608     DCS modified v1
# 3  0.513541  0.411026  0.643278     DCS modified v1
# 4  0.639639  0.509573  0.682260     DCS modified v1
# 5  0.501386  0.436072  0.652305     DCS modified v1
# 6  0.375514  0.329808  0.610309     DCS modified v1
# 7  0.552748  0.441782  0.656710     DCS modified v1
# 8  0.380036  0.315809  0.602734     DCS modified v1
# 9  0.465739  0.372564  0.627878     DCS modified v1
# 0  0.564090  0.488221  0.672665    Two Autoencoders
# 1  0.572697  0.431274  0.652558    Two Autoencoders
# 2  0.637546  0.542747  0.692009    Two Autoencoders
# 3  0.585109  0.473938  0.670647    Two Autoencoders
# 4  0.639732  0.538977  0.692943    Two Autoencoders
# 5  0.533395  0.418876  0.645286    Two Autoencoders
# 6  0.469591  0.384238  0.629828    Two Autoencoders
# 7  0.550840  0.440696  0.653587    Two Autoencoders
# 8  0.399251  0.324429  0.604494    Two Autoencoders
# 9  0.511755  0.414483  0.647380    Two Autoencoders
# 0  0.564707  0.489972  0.672886     DCS modified v2
# 1  0.608006  0.489876  0.675419     DCS modified v2
# 2  0.650462  0.543741  0.691394     DCS modified v2
# 3  0.602023  0.487823  0.675568     DCS modified v2
# 4  0.668152  0.571824  0.708943     DCS modified v2
# 5  0.582899  0.478771  0.669765     DCS modified v2
# 6  0.474985  0.415385  0.641724     DCS modified v2
# 7  0.599302  0.483529  0.668620     DCS modified v2
# 8  0.442222  0.368281  0.622705     DCS modified v2
# 9  0.566806  0.464336  0.665881     DCS modified v2
# 0  0.574139  0.494421  0.673265     MI Autoencoders
# 1  0.590913  0.453064  0.661112     MI Autoencoders
# 2  0.637148  0.540541  0.686692     MI Autoencoders
# 3  0.588596  0.473792  0.671086     MI Autoencoders
# 4  0.635853  0.535623  0.690730     MI Autoencoders
# 5  0.552753  0.432631  0.651852     MI Autoencoders
# 6  0.440748  0.379072  0.629179     MI Autoencoders
# 7  0.566633  0.452295  0.656526     MI Autoencoders
# 8  0.405110  0.325354  0.606410     MI Autoencoders
# 9  0.519431  0.425053  0.651626     MI Autoencoders
# 0  0.491287  0.415190  0.642983  direct translation
# 1  0.449773  0.373708  0.631105  direct translation
# 2  0.467521  0.380200  0.626279  direct translation
# 3  0.420189  0.338177  0.617376  direct translation
# 4  0.534992  0.417309  0.646877  direct translation
# 5  0.414236  0.365071  0.626368  direct translation
# 6  0.305874  0.271386  0.590569  direct translation
# 7  0.453185  0.369136  0.629967  direct translation
# 8  0.301552  0.254713  0.581735  direct translation
# 9  0.381603  0.307406  0.604008  direct translation

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#                   model    metric     value
# 0                   DCS   pearson  0.599170
# 1                   DCS   pearson  0.558736
# 2                   DCS   pearson  0.582151
# 3                   DCS   pearson  0.514541
# 4                   DCS   pearson  0.635018
# ..                  ...       ...       ...
# 175  direct translation  accuracy  0.626368
# 176  direct translation  accuracy  0.590569
# 177  direct translation  accuracy  0.629967
# 178  direct translation  accuracy  0.581735
# 179  direct translation  accuracy  0.604008
#
# [180 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.25)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="model", y="value", data=res_to_a375,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'Two Autoencoders','MI Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2)
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'models',
              ylabel='Performance metric value')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_autoencoders_compare_allgenes_a375.png', bbox_inches='tight',dpi=600)

# %%
from scipy import stats

# %%
models = ['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','direct translation','MI Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-31-571df82ebf91>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-31-571df82ebf91>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-32-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-32-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-33-748d6dd7cfa5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='accuracy'].value.values
# <ipython-input-33-748d6dd7cfa5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','DCS','DCS modified v1','DCS modified v2','Two Autoencoders','direct translation','MI Autoencoders']]
a375_translate.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
a375_translate
# Out:
#                       metric  DCS  DCS modified v1  DCS modified v2  \
# DCS                  pearson  1.0         0.850107         0.075662
# DCS modified v1      pearson  0.0         1.000000         0.104110
# DCS modified v2      pearson  0.0         0.000000         1.000000
# Two Autoencoders     pearson  0.0         0.000000         0.000000
# direct translation   pearson  0.0         0.000000         0.000000
# MI Autoencoders      pearson  0.0         0.000000         0.000000
# DCS                 spearman  1.0         1.000000         0.088973
# DCS modified v1     spearman  0.0         1.000000         0.104110
# DCS modified v2     spearman  0.0         0.000000         1.000000
# Two Autoencoders    spearman  0.0         0.000000         0.000000
# direct translation  spearman  0.0         0.000000         0.000000
# MI Autoencoders     spearman  0.0         0.000000         0.000000
# DCS                 accuracy  1.0         0.969850         0.088973
# DCS modified v1     accuracy  0.0         1.000000         0.088973
# DCS modified v2     accuracy  0.0         0.000000         1.000000
# Two Autoencoders    accuracy  0.0         0.000000         0.000000
# direct translation  accuracy  0.0         0.000000         0.000000
# MI Autoencoders     accuracy  0.0         0.000000         0.000000
#
#                     Two Autoencoders  direct translation  MI Autoencoders
# DCS                         0.384673            0.031209         0.273036
# DCS modified v1             0.520523            0.031209         0.384673
# DCS modified v2             0.241322            0.001315         0.344704
# Two Autoencoders            1.000000            0.003611         0.733730
# direct translation          0.000000            1.000000         0.005795
# MI Autoencoders             0.000000            0.000000         1.000000
# DCS                         0.623176            0.025748         0.472676
# DCS modified v1             0.677585            0.025748         0.520523
# DCS modified v2             0.212294            0.001008         0.307489
# Two Autoencoders            1.000000            0.003611         0.791337
# direct translation          0.000000            1.000000         0.002827
# MI Autoencoders             0.000000            0.000000         1.000000
# DCS                         0.623176            0.025748         0.520523
# DCS modified v1             0.570750            0.025748         0.520523
# DCS modified v2             0.344704            0.001706         0.307489
# Two Autoencoders            1.000000            0.004586         0.850107
# direct translation          0.000000            1.000000         0.003611
# MI Autoencoders             0.000000            0.000000         1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_a375 = results.loc[:,['recon_pear_a375','recon_spear_a375','recon_acc_a375','model']]
res_recon_a375.columns = ['pearson','spearman','accuracy','model']
res_recon_a375
# Out:
#     pearson  spearman  accuracy                              model
# 0  0.856880  0.837847  0.831766                  Translation Model
# 1  0.865250  0.832907  0.828442                  Translation Model
# 2  0.853304  0.830066  0.826299                  Translation Model
# 3  0.870107  0.859601  0.849913                  Translation Model
# 4  0.890893  0.867544  0.852362                  Translation Model
# 5  0.882259  0.862463  0.846948                  Translation Model
# 6  0.876594  0.860304  0.845963                  Translation Model
# 7  0.868792  0.854905  0.843307                  Translation Model
# 8  0.873025  0.852640  0.839900                  Translation Model
# 9  0.855601  0.839996  0.832788                  Translation Model
# 0  0.864403  0.845448  0.837065  Translation Model with classifier
# 1  0.867685  0.833098  0.828802  Translation Model with classifier
# 2  0.852782  0.829418  0.825857  Translation Model with classifier
# 3  0.872533  0.860482  0.850613  Translation Model with classifier
# 4  0.894209  0.870437  0.853787  Translation Model with classifier
# 5  0.881493  0.860359  0.844975  Translation Model with classifier
# 6  0.881764  0.864754  0.848587  Translation Model with classifier
# 7  0.873970  0.861666  0.848478  Translation Model with classifier
# 8  0.874017  0.856570  0.843698  Translation Model with classifier
# 9  0.851280  0.834647  0.829146  Translation Model with classifier

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#                                 model    metric     value
# 0                   Translation Model   pearson  0.856880
# 1                   Translation Model   pearson  0.865250
# 2                   Translation Model   pearson  0.853304
# 3                   Translation Model   pearson  0.870107
# 4                   Translation Model   pearson  0.890893
# 5                   Translation Model   pearson  0.882259
# 6                   Translation Model   pearson  0.876594
# 7                   Translation Model   pearson  0.868792
# 8                   Translation Model   pearson  0.873025
# 9                   Translation Model   pearson  0.855601
# 10  Translation Model with classifier   pearson  0.864403
# 11  Translation Model with classifier   pearson  0.867685
# 12  Translation Model with classifier   pearson  0.852782
# 13  Translation Model with classifier   pearson  0.872533
# 14  Translation Model with classifier   pearson  0.894209
# 15  Translation Model with classifier   pearson  0.881493
# 16  Translation Model with classifier   pearson  0.881764
# 17  Translation Model with classifier   pearson  0.873970
# 18  Translation Model with classifier   pearson  0.874017
# 19  Translation Model with classifier   pearson  0.851280
# 20                  Translation Model  spearman  0.837847
# 21                  Translation Model  spearman  0.832907
# 22                  Translation Model  spearman  0.830066
# 23                  Translation Model  spearman  0.859601
# 24                  Translation Model  spearman  0.867544
# 25                  Translation Model  spearman  0.862463
# 26                  Translation Model  spearman  0.860304
# 27                  Translation Model  spearman  0.854905
# 28                  Translation Model  spearman  0.852640
# 29                  Translation Model  spearman  0.839996
# 30  Translation Model with classifier  spearman  0.845448
# 31  Translation Model with classifier  spearman  0.833098
# 32  Translation Model with classifier  spearman  0.829418
# 33  Translation Model with classifier  spearman  0.860482
# 34  Translation Model with classifier  spearman  0.870437
# 35  Translation Model with classifier  spearman  0.860359
# 36  Translation Model with classifier  spearman  0.864754
# 37  Translation Model with classifier  spearman  0.861666
# 38  Translation Model with classifier  spearman  0.856570
# 39  Translation Model with classifier  spearman  0.834647
# 40                  Translation Model  accuracy  0.831766
# 41                  Translation Model  accuracy  0.828442
# 42                  Translation Model  accuracy  0.826299
# 43                  Translation Model  accuracy  0.849913
# 44                  Translation Model  accuracy  0.852362
# 45                  Translation Model  accuracy  0.846948
# 46                  Translation Model  accuracy  0.845963
# 47                  Translation Model  accuracy  0.843307
# 48                  Translation Model  accuracy  0.839900
# 49                  Translation Model  accuracy  0.832788
# 50  Translation Model with classifier  accuracy  0.837065
# 51  Translation Model with classifier  accuracy  0.828802
# 52  Translation Model with classifier  accuracy  0.825857
# 53  Translation Model with classifier  accuracy  0.850613
# 54  Translation Model with classifier  accuracy  0.853787
# 55  Translation Model with classifier  accuracy  0.844975
# 56  Translation Model with classifier  accuracy  0.848587
# 57  Translation Model with classifier  accuracy  0.848478
# 58  Translation Model with classifier  accuracy  0.843698
# 59  Translation Model with classifier  accuracy  0.829146

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="model", y="value", data=res_recon_a375,
            order=['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2)
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'models',
              ylabel='Performance metric value')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_a375.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-40-b10bf9764b29>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-40-b10bf9764b29>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-41-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-41-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-42-7bf8ce6c3d50>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='accuracy'].value.values
# <ipython-input-42-7bf8ce6c3d50>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders']]
a375_reconstruction.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                     metric  DCS  DCS modified v1  DCS modified v2  \
# DCS                pearson  1.0         0.850107         0.075662
# DCS modified v1    pearson  0.0         1.000000         0.104110
# DCS modified v2    pearson  0.0         0.000000         1.000000
# Two Autoencoders   pearson  0.0         0.000000         0.000000
# MI Autoencoders    pearson  0.0         0.000000         0.000000
# DCS               spearman  1.0         0.000183         0.000183
# DCS modified v1   spearman  0.0         1.000000         0.000183
# DCS modified v2   spearman  0.0         0.000000         1.000000
# Two Autoencoders  spearman  0.0         0.000000         0.000000
# MI Autoencoders   spearman  0.0         0.000000         0.000000
# DCS               accuracy  1.0         0.000183         0.000183
# DCS modified v1   accuracy  0.0         1.000000         0.000183
# DCS modified v2   accuracy  0.0         0.000000         1.000000
# Two Autoencoders  accuracy  0.0         0.000000         0.000000
# MI Autoencoders   accuracy  0.0         0.000000         0.000000
#
#                   Two Autoencoders  MI Autoencoders
# DCS                       0.384673         0.273036
# DCS modified v1           0.520523         0.384673
# DCS modified v2           0.241322         0.344704
# Two Autoencoders          1.000000         0.733730
# MI Autoencoders           0.000000         1.000000
# DCS                       0.000183         0.000183
# DCS modified v1           0.000183         0.000183
# DCS modified v2           0.000183         0.000183
# Two Autoencoders          1.000000         0.909722
# MI Autoencoders           0.000000         1.000000
# DCS                       0.000183         0.000183
# DCS modified v1           0.000183         0.000183
# DCS modified v2           0.000183         0.000183
# Two Autoencoders          1.000000         1.000000
# MI Autoencoders           0.000000         1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline],axis=0)
res_to_ht29
# Out:
#     pearson  spearman  accuracy                              model
# 0  0.471187  0.396801  0.641964                  Translation Model
# 1  0.490285  0.401972  0.642060                  Translation Model
# 2  0.576092  0.440536  0.656076                  Translation Model
# 3  0.477355  0.377410  0.634312                  Translation Model
# 4  0.636427  0.445383  0.665907                  Translation Model
# 5  0.488502  0.423471  0.653456                  Translation Model
# 6  0.401329  0.319445  0.609633                  Translation Model
# 7  0.369988  0.313148  0.607091                  Translation Model
# 8  0.456484  0.393878  0.636475                  Translation Model
# 9  0.447873  0.354685  0.617934                  Translation Model
# 0  0.469095  0.383426  0.635619  Translation Model with classifier
# 1  0.501197  0.416166  0.647002  Translation Model with classifier
# 2  0.581257  0.431337  0.652266  Translation Model with classifier
# 3  0.457016  0.361552  0.628435  Translation Model with classifier
# 4  0.637985  0.446054  0.667174  Translation Model with classifier
# 5  0.488866  0.421407  0.652708  Translation Model with classifier
# 6  0.394716  0.305953  0.604844  Translation Model with classifier
# 7  0.359524  0.303204  0.603296  Translation Model with classifier
# 8  0.436073  0.375289  0.628453  Translation Model with classifier
# 9  0.447776  0.354183  0.619430  Translation Model with classifier
# 0  0.294744  0.276065  0.593538                 direct translation
# 1  0.350380  0.315285  0.609876                 direct translation
# 2  0.337029  0.282466  0.594442                 direct translation
# 3  0.348499  0.312722  0.607611                 direct translation
# 4  0.383258  0.313748  0.611784                 direct translation
# 5  0.320330  0.259267  0.585922                 direct translation
# 6  0.269058  0.224497  0.574529                 direct translation
# 7  0.309138  0.260401  0.589317                 direct translation
# 8  0.298267  0.252779  0.583590                 direct translation
# 9  0.268524  0.230909  0.572029                 direct translation

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#                  model    metric     value
# 0    Translation Model   pearson  0.471187
# 1    Translation Model   pearson  0.490285
# 2    Translation Model   pearson  0.576092
# 3    Translation Model   pearson  0.477355
# 4    Translation Model   pearson  0.636427
# ..                 ...       ...       ...
# 85  direct translation  accuracy  0.585922
# 86  direct translation  accuracy  0.574529
# 87  direct translation  accuracy  0.589317
# 88  direct translation  accuracy  0.583590
# 89  direct translation  accuracy  0.572029
#
# [90 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="model", y="value", data=res_to_ht29,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'Two Autoencoders','MI Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2)
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'models',
              ylabel='Performance metric value')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_autoencoders_comparison_allgenes_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','direct translation','MI Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-47-76ee1cb415bb>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-47-76ee1cb415bb>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-48-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-48-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-49-c5c1bf237c12>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='accuracy'].value.values
# <ipython-input-49-c5c1bf237c12>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','DCS','DCS modified v1','DCS modified v2','Two Autoencoders','direct translation','MI Autoencoders']]
ht29_translate.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
ht29_translate
# Out:
#                       metric  DCS  DCS modified v1  DCS modified v2  \
# DCS                  pearson  1.0         0.909722         0.021134
# DCS modified v1      pearson  0.0         1.000000         0.037635
# DCS modified v2      pearson  0.0         0.000000         1.000000
# Two Autoencoders     pearson  0.0         0.000000         0.000000
# direct translation   pearson  0.0         0.000000         0.000000
# MI Autoencoders      pearson  0.0         0.000000         0.000000
# DCS                 spearman  1.0         0.969850         0.053903
# DCS modified v1     spearman  0.0         1.000000         0.037635
# DCS modified v2     spearman  0.0         0.000000         1.000000
# Two Autoencoders    spearman  0.0         0.000000         0.000000
# direct translation  spearman  0.0         0.000000         0.000000
# MI Autoencoders     spearman  0.0         0.000000         0.000000
# DCS                 accuracy  1.0         0.909722         0.053903
# DCS modified v1     accuracy  0.0         1.000000         0.037635
# DCS modified v2     accuracy  0.0         0.000000         1.000000
# Two Autoencoders    accuracy  0.0         0.000000         0.000000
# direct translation  accuracy  0.0         0.000000         0.000000
# MI Autoencoders     accuracy  0.0         0.000000         0.000000
#
#                     Two Autoencoders  direct translation  MI Autoencoders
# DCS                         0.185877            0.021134         0.075662
# DCS modified v1             0.185877            0.021134         0.088973
# DCS modified v2             0.427355            0.000183         0.570750
# Two Autoencoders            1.000000            0.000330         0.733730
# direct translation          0.000000            1.000000         0.000330
# MI Autoencoders             0.000000            0.000000         1.000000
# DCS                         0.212294            0.011330         0.161972
# DCS modified v1             0.212294            0.011330         0.161972
# DCS modified v2             0.273036            0.000183         0.384673
# Two Autoencoders            1.000000            0.000583         0.677585
# direct translation          0.000000            1.000000         0.000330
# MI Autoencoders             0.000000            0.000000         1.000000
# DCS                         0.307489            0.017257         0.212294
# DCS modified v1             0.273036            0.017257         0.212294
# DCS modified v2             0.307489            0.000183         0.427355
# Two Autoencoders            1.000000            0.001008         0.677585
# direct translation          0.000000            1.000000         0.000583
# MI Autoencoders             0.000000            0.000000         1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','accuracy','model']
res_recon_ht29
# Out:
#     pearson  spearman  accuracy                              model
# 0  0.842857  0.819590  0.824454                  Translation Model
# 1  0.847330  0.819666  0.824282                  Translation Model
# 2  0.846084  0.807335  0.814458                  Translation Model
# 3  0.844813  0.809687  0.816988                  Translation Model
# 4  0.886485  0.847685  0.840422                  Translation Model
# 5  0.853912  0.840956  0.834747                  Translation Model
# 6  0.859170  0.837358  0.833451                  Translation Model
# 7  0.849914  0.826574  0.826656                  Translation Model
# 8  0.859430  0.837115  0.831535                  Translation Model
# 9  0.847712  0.830071  0.828108                  Translation Model
# 0  0.844355  0.821576  0.825790  Translation Model with classifier
# 1  0.845537  0.817890  0.823283  Translation Model with classifier
# 2  0.847310  0.809415  0.816823  Translation Model with classifier
# 3  0.846701  0.810783  0.817577  Translation Model with classifier
# 4  0.886406  0.847768  0.840920  Translation Model with classifier
# 5  0.859223  0.844045  0.836906  Translation Model with classifier
# 6  0.854738  0.832576  0.830950  Translation Model with classifier
# 7  0.853018  0.828886  0.827806  Translation Model with classifier
# 8  0.855879  0.837278  0.831960  Translation Model with classifier
# 9  0.838290  0.821707  0.822193  Translation Model with classifier

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#                                 model    metric     value
# 0                   Translation Model   pearson  0.842857
# 1                   Translation Model   pearson  0.847330
# 2                   Translation Model   pearson  0.846084
# 3                   Translation Model   pearson  0.844813
# 4                   Translation Model   pearson  0.886485
# 5                   Translation Model   pearson  0.853912
# 6                   Translation Model   pearson  0.859170
# 7                   Translation Model   pearson  0.849914
# 8                   Translation Model   pearson  0.859430
# 9                   Translation Model   pearson  0.847712
# 10  Translation Model with classifier   pearson  0.844355
# 11  Translation Model with classifier   pearson  0.845537
# 12  Translation Model with classifier   pearson  0.847310
# 13  Translation Model with classifier   pearson  0.846701
# 14  Translation Model with classifier   pearson  0.886406
# 15  Translation Model with classifier   pearson  0.859223
# 16  Translation Model with classifier   pearson  0.854738
# 17  Translation Model with classifier   pearson  0.853018
# 18  Translation Model with classifier   pearson  0.855879
# 19  Translation Model with classifier   pearson  0.838290
# 20                  Translation Model  spearman  0.819590
# 21                  Translation Model  spearman  0.819666
# 22                  Translation Model  spearman  0.807335
# 23                  Translation Model  spearman  0.809687
# 24                  Translation Model  spearman  0.847685
# 25                  Translation Model  spearman  0.840956
# 26                  Translation Model  spearman  0.837358
# 27                  Translation Model  spearman  0.826574
# 28                  Translation Model  spearman  0.837115
# 29                  Translation Model  spearman  0.830071
# 30  Translation Model with classifier  spearman  0.821576
# 31  Translation Model with classifier  spearman  0.817890
# 32  Translation Model with classifier  spearman  0.809415
# 33  Translation Model with classifier  spearman  0.810783
# 34  Translation Model with classifier  spearman  0.847768
# 35  Translation Model with classifier  spearman  0.844045
# 36  Translation Model with classifier  spearman  0.832576
# 37  Translation Model with classifier  spearman  0.828886
# 38  Translation Model with classifier  spearman  0.837278
# 39  Translation Model with classifier  spearman  0.821707
# 40                  Translation Model  accuracy  0.824454
# 41                  Translation Model  accuracy  0.824282
# 42                  Translation Model  accuracy  0.814458
# 43                  Translation Model  accuracy  0.816988
# 44                  Translation Model  accuracy  0.840422
# 45                  Translation Model  accuracy  0.834747
# 46                  Translation Model  accuracy  0.833451
# 47                  Translation Model  accuracy  0.826656
# 48                  Translation Model  accuracy  0.831535
# 49                  Translation Model  accuracy  0.828108
# 50  Translation Model with classifier  accuracy  0.825790
# 51  Translation Model with classifier  accuracy  0.823283
# 52  Translation Model with classifier  accuracy  0.816823
# 53  Translation Model with classifier  accuracy  0.817577
# 54  Translation Model with classifier  accuracy  0.840920
# 55  Translation Model with classifier  accuracy  0.836906
# 56  Translation Model with classifier  accuracy  0.830950
# 57  Translation Model with classifier  accuracy  0.827806
# 58  Translation Model with classifier  accuracy  0.831960
# 59  Translation Model with classifier  accuracy  0.822193

# %%
sns.set_theme(style="whitegrid",font_scale = 1.2)
plt.figure(figsize=(12,7), dpi= 80)
sns.barplot(x="model", y="value", data=res_recon_ht29,
            order=['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders'],
            hue_order = ['accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2)
plt.legend(loc='lower left')
plt.gca().set(title='Performance of autoencoder model variations in 10-fold cross-validation', 
              xlabel = 'models',
              ylabel='Performance metric value')
#plt.xticks(rotation=45)
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_ht29.png', bbox_inches='tight',dpi=600)

# %%
models = ['DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-56-a61ceec243fd>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-56-a61ceec243fd>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-57-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-57-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'accuracy'
# Out:
# <ipython-input-58-12b8fd9ef33b>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='accuracy'].value.values
# <ipython-input-58-12b8fd9ef33b>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','Two Autoencoders','MI Autoencoders']]
ht29_reconstruction.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                     metric  DCS  DCS modified v1  DCS modified v2  \
# DCS                pearson  1.0         0.000183         0.000183
# DCS modified v1    pearson  0.0         1.000000         0.000183
# DCS modified v2    pearson  0.0         0.000000         1.000000
# Two Autoencoders   pearson  0.0         0.000000         0.000000
# MI Autoencoders    pearson  0.0         0.000000         0.000000
# DCS               spearman  1.0         0.000183         0.000183
# DCS modified v1   spearman  0.0         1.000000         0.000183
# DCS modified v2   spearman  0.0         0.000000         1.000000
# Two Autoencoders  spearman  0.0         0.000000         0.000000
# MI Autoencoders   spearman  0.0         0.000000         0.000000
# DCS               accuracy  1.0         0.000183         0.000183
# DCS modified v1   accuracy  0.0         1.000000         0.000183
# DCS modified v2   accuracy  0.0         0.000000         1.000000
# Two Autoencoders  accuracy  0.0         0.000000         0.000000
# MI Autoencoders   accuracy  0.0         0.000000         0.000000
#
#                   Two Autoencoders  MI Autoencoders
# DCS                       0.000183         0.000183
# DCS modified v1           0.000183         0.000183
# DCS modified v2           0.000330         0.000440
# Two Autoencoders          1.000000         0.909722
# MI Autoencoders           0.000000         1.000000
# DCS                       0.000183         0.000183
# DCS modified v1           0.000183         0.000183
# DCS modified v2           0.000583         0.000583
# Two Autoencoders          1.000000         0.969850
# MI Autoencoders           0.000000         1.000000
# DCS                       0.000183         0.000183
# DCS modified v1           0.000183         0.000183
# DCS modified v2           0.001706         0.000769
# Two Autoencoders          1.000000         0.909722
# MI Autoencoders           0.000000         1.000000
