# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import mannwhitneyu, normaltest
from statannotations.Annotator import Annotator
import statannot

# %% [markdown]
# # Compare DeepCellState variations

# %%
import seaborn as sns
sns.set()

# %%
res_dcs_noise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_with_noise_10k.csv',index_col=0)
res_dcs_noise['model'] = 'DCS'
res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_no_noise_10k.csv',index_col=0)
res_dcs_nonoise['model'] = 'DCS modified v1'
res_notvae_2encs = pd.read_csv('../results/my_results_10kgenes/allgenes_10foldvalidation_notvae_results1000ep512bs.csv',index_col=0)
res_notvae_2encs['model'] = 'similarity-trained Autoencoders'
res_dcs_direct = pd.read_csv('../results/deepcellstate_results_10kgenes/deepcellstate_allgenes_10foldvalidation_results1000ep_direct_andl2similarity_10k.csv',index_col=0)
res_dcs_direct['model'] = 'DCS modified v2'
baseline = pd.read_csv('../results/baseline_evaluation_allgenes.csv',index_col=0)
baseline = baseline.drop_duplicates()

# add mi
res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
res_mi['model'] = 'Autoencoders with classifier'

# %%
# # add TransCompRmixedANNS
# res_annTransCompR = pd.read_csv('../results/ANNmixedTransCompR_results_10k/allgenes_10foldvalidation_ANNmixedTransCompR_500ep512bs_a375_ht29.csv',index_col=0)
# res_annTransCompR['model'] = 'TransCompR-combined and Autoencoders with classifier'

# %%
res_cpa = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_withCPA_1000ep512bs_a375_ht29.csv',index_col=0)
res_cpa['model'] = 'CPA-based Autoencoders'

# %%
res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_ht29_a375_withclass.csv',index_col=0)
res_mi_class['model'] = 'Autoencoders with classifier'
res_transCompR = pd.read_csv('../results/TransCompR_results/allgenes_10foldvalidation_transcompr_decoders_1000ep512bs_a375_ht29.csv',index_col=0)
res_transCompR['model'] = 'TransCompR'
res_fit = pd.read_csv('../results/FITmodel_results/allgenes_10foldvalidation_FIT_a375_ht29.csv',index_col=0)
res_fit['model'] = 'FIT'

# %%
# # add mi
# res_mi = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_1000ep512bs_pc3_ha1e.csv',index_col=0)
# res_mi['model'] = 'Translation Model'

# res_mi_class = pd.read_csv('../results/MI_results/allgenes_10foldvalidation_notpretrained_MIuniform_and_l2sim_2encs_2000ep512bs_pc3_ha1e_withclass.csv',index_col=0)
# res_mi_class['model'] = 'Translation Model with classifier'

# %%
# res_dcs_noise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_withnoise.csv',index_col=0)
# res_dcs_noise['model'] = 'DCS'
# res_dcs_nonoise = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_no_noise.csv',index_col=0)
# res_dcs_nonoise['model'] = 'DCS modified v1'
# res_notvae_2encs = pd.read_csv('../results/my_results/landmarks_10foldvalidation_vae_results1000ep512bs.csv',index_col=0)
# res_notvae_2encs['model'] = 'Two Autoencoders'
# res_dcs_direct = pd.read_csv('../results/deepcellstate_results/deepcellstate_landmarks_10foldvalidation_results300ep128bs_direct_and_l2similarity.csv',index_col=0)
# res_dcs_direct['model'] = 'DCS modified v2'
# baseline = pd.read_csv('../results/baseline_evaluation_landmarks.csv',index_col=0)
# baseline = baseline.drop_duplicates()

# # # add mi
# # res_mi = pd.read_csv('../results/MI_results/landmarks_10foldvalidation_pretrained_MIuniform_and_l2sim_2encs_1000ep512bs.csv',index_col=0)
# # res_mi['model'] = 'MI Autoencoders'

# %%
results = pd.concat([res_dcs_noise,res_dcs_nonoise,res_notvae_2encs,
                     res_dcs_direct,res_cpa,res_mi_class,
                     res_transCompR],axis=0)
#res_annTransCompR
results
# Out:
#     model_pearsonHT29  model_pearsonA375  model_spearHT29  model_spearA375  \
# 0            0.613718           0.599170         0.526330         0.512294
# 1            0.566115           0.558736         0.464582         0.463245
# 2            0.609149           0.582151         0.492402         0.473071
# 3            0.530387           0.514541         0.418556         0.411831
# 4            0.649465           0.635018         0.522971         0.505391
# ..                ...                ...              ...              ...
# 5            0.572714           0.552361         0.482618         0.459567
# 6            0.517275           0.448766         0.429654         0.385287
# 7            0.613800           0.578690         0.528382         0.453449
# 8            0.504796           0.400220         0.399192         0.322164
# 9            0.547518           0.513790         0.447626         0.419357
#
#     model_accHT29  model_accA375  recon_pear_ht29  recon_pear_a375  \
# 0        0.685056       0.680166         0.947445         0.944607
# 1        0.663853       0.665333         0.945406         0.942046
# 2        0.667321       0.661947         0.942116         0.947642
# 3        0.646344       0.644403         0.944477         0.941711
# 4        0.686253       0.680406         0.950940         0.945411
# ..            ...            ...              ...              ...
# 5        0.669031       0.662602         0.869644         0.870845
# 6        0.647088       0.630542         0.861795         0.854774
# 7        0.688293       0.660842         0.877211         0.846940
# 8        0.634823       0.604707         0.853622         0.851408
# 9        0.655919       0.648059         0.846276         0.844722
#
#     recon_spear_ht29  recon_spear_a375  ...  recon_acc_a375  cross_corr_ht29  \
# 0           0.937704          0.931870  ...        0.891681         0.920867
# 1           0.934308          0.929751  ...        0.889458         0.915497
# 2           0.933452          0.935973  ...        0.894833         0.911275
# 3           0.933683          0.929063  ...        0.889775         0.913457
# 4           0.942423          0.933031  ...        0.894141         0.923569
# ..               ...               ...  ...             ...              ...
# 5           0.841884          0.833748  ...        0.830252              NaN
# 6           0.833605          0.820409  ...        0.821250              NaN
# 7           0.854646          0.813830  ...        0.817877              NaN
# 8           0.827085          0.814839  ...        0.818141              NaN
# 9           0.811522          0.813814  ...        0.817554              NaN
#
#     cross_corr_a375  Direct_pearson  Direct_spearman  DirectAcc_ht29  \
# 0          0.920973        0.491287         0.213417        0.642906
# 1          0.915471        0.449773         0.484918        0.631011
# 2          0.915116        0.467521         0.225109        0.626187
# 3          0.919640        0.420189         0.132573        0.617286
# 4          0.925903        0.534992         0.588160        0.646800
# ..              ...             ...              ...             ...
# 5               NaN             NaN              NaN             NaN
# 6               NaN             NaN              NaN             NaN
# 7               NaN             NaN              NaN             NaN
# 8               NaN             NaN              NaN             NaN
# 9               NaN             NaN              NaN             NaN
#
#     DirectAcc_a375       model F1_score  ClassAccuracy
# 0         0.642906         DCS      NaN            NaN
# 1         0.631011         DCS      NaN            NaN
# 2         0.626187         DCS      NaN            NaN
# 3         0.617286         DCS      NaN            NaN
# 4         0.646800         DCS      NaN            NaN
# ..             ...         ...      ...            ...
# 5              NaN  TransCompR      NaN            NaN
# 6              NaN  TransCompR      NaN            NaN
# 7              NaN  TransCompR      NaN            NaN
# 8              NaN  TransCompR      NaN            NaN
# 9              NaN  TransCompR      NaN            NaN
#
# [70 rows x 21 columns]

# %% [markdown]
# ## A375 trasnlation

# %%
res_to_a375 = results.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_to_a375.columns = ['pearson','spearman','sign accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_a375']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','sign accuracy','model']
res_fit_a375 = res_fit.loc[:,['model_pearsonA375','model_spearA375','model_accA375','model']]
res_fit_a375.columns = ['pearson','spearman','sign accuracy','model']
res_to_a375 = pd.concat([res_to_a375,res_baseline,res_fit_a375],axis=0)
res_to_a375
# Out:
#      pearson  spearman  sign accuracy model
# 0   0.599170  0.512294       0.680166   DCS
# 1   0.558736  0.463245       0.665333   DCS
# 2   0.582151  0.473071       0.661947   DCS
# 3   0.514541  0.411831       0.644403   DCS
# 4   0.635018  0.505391       0.680406   DCS
# ..       ...       ...            ...   ...
# 5   0.484918  0.640643       0.406802   FIT
# 6   0.397843  0.612002       0.333542   FIT
# 7   0.499022  0.631420       0.387057   FIT
# 8   0.383503  0.603520       0.312379   FIT
# 9   0.482378  0.636100       0.391265   FIT
#
# [90 rows x 4 columns]

# %%
res_to_a375 = pd.melt(res_to_a375,id_vars=['model'])
res_to_a375.columns = ['model','metric','value']
res_to_a375
# Out:
#     model         metric     value
# 0     DCS        pearson  0.599170
# 1     DCS        pearson  0.558736
# 2     DCS        pearson  0.582151
# 3     DCS        pearson  0.514541
# 4     DCS        pearson  0.635018
# ..    ...            ...       ...
# 265   FIT  sign accuracy  0.406802
# 266   FIT  sign accuracy  0.333542
# 267   FIT  sign accuracy  0.387057
# 268   FIT  sign accuracy  0.312379
# 269   FIT  sign accuracy  0.391265
#
# [270 rows x 3 columns]

# %%
plt.rcParams["figure.figsize"] = (8, 6)

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(8,7), dpi= 300)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_to_a375,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','Autoencoders with classifier',
                   'CPA-based Autoencoders','FIT','TransCompR'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.xlim(0.25,0.7)
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='models')
# statannot.add_stat_annotation(ax=ax, 
#                               data=res_to_a375,
#                               y="value",
#                               x="model",
#                               order=['direct translation','DCS',
#                                      'DCS modified v1','DCS modified v2',
#                                      'similarity-trained Autoencoders','GAN-based Autoencoders',
#                                      'TransCompR-combined and GAN-based Autoencoders'],
#                               hue_order = ['accuracy','pearson','spearman'],
#                               hue="metric",
#                               box_pairs=[
#                                   (("DCS", "pearson"), ("similarity-trained Autoencoders","pearson"))],
#                               test="Mann-Whitney",
#                               loc = 'inside',
#                               verbose=0
#                              )
plt.savefig('../figures/MI_results/allgenes_autoencoders_compare_allgenes_a375.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from scipy import stats

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders',
          'direct translation','Autoencoders with classifier',
          'CPA-based Autoencoders','FIT','TransCompR']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-15-f81326c34b3a>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='pearson'].value.values
# <ipython-input-15-f81326c34b3a>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-16-2bb75a293747>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='spearman'].value.values
# <ipython-input-16-2bb75a293747>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='sign accuracy'].value.values
        x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-17-a9ff6e3ced82>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_a375[res_to_a375['model']==m1][res_to_a375['metric']=='sign accuracy'].value.values
# <ipython-input-17-a9ff6e3ced82>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_a375[res_to_a375['model']==m2][res_to_a375['metric']=='sign accuracy'].value.values

# %%
a375_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_translate = a375_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation',
                                 'Autoencoders with classifier','CPA-based Autoencoders','FIT','TransCompR']]
a375_translate.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
a375_translate
# Out:
#                                         metric  DCS  DCS modified v1  \
# DCS                                    pearson  1.0         0.850107
# DCS modified v1                        pearson  0.0         1.000000
# DCS modified v2                        pearson  0.0         0.000000
# similarity-trained Autoencoders        pearson  0.0         0.000000
# direct translation                     pearson  0.0         0.000000
# Autoencoders with classifier           pearson  0.0         0.000000
# CPA-based Autoencoders                 pearson  0.0         0.000000
# FIT                                    pearson  0.0         0.000000
# TransCompR                             pearson  0.0         0.000000
# DCS                                   spearman  1.0         1.000000
# DCS modified v1                       spearman  0.0         1.000000
# DCS modified v2                       spearman  0.0         0.000000
# similarity-trained Autoencoders       spearman  0.0         0.000000
# direct translation                    spearman  0.0         0.000000
# Autoencoders with classifier          spearman  0.0         0.000000
# CPA-based Autoencoders                spearman  0.0         0.000000
# FIT                                   spearman  0.0         0.000000
# TransCompR                            spearman  0.0         0.000000
# DCS                              sign accuracy  1.0         0.969850
# DCS modified v1                  sign accuracy  0.0         1.000000
# DCS modified v2                  sign accuracy  0.0         0.000000
# similarity-trained Autoencoders  sign accuracy  0.0         0.000000
# direct translation               sign accuracy  0.0         0.000000
# Autoencoders with classifier     sign accuracy  0.0         0.000000
# CPA-based Autoencoders           sign accuracy  0.0         0.000000
# FIT                              sign accuracy  0.0         0.000000
# TransCompR                       sign accuracy  0.0         0.000000
#
#                                  DCS modified v2  \
# DCS                                     0.075662
# DCS modified v1                         0.104110
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# CPA-based Autoencoders                  0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
# DCS                                     0.088973
# DCS modified v1                         0.104110
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# CPA-based Autoencoders                  0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
# DCS                                     0.088973
# DCS modified v1                         0.088973
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# CPA-based Autoencoders                  0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
#
#                                  similarity-trained Autoencoders  \
# DCS                                                     0.384673
# DCS modified v1                                         0.520523
# DCS modified v2                                         0.241322
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# CPA-based Autoencoders                                  0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
# DCS                                                     0.623176
# DCS modified v1                                         0.677585
# DCS modified v2                                         0.212294
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# CPA-based Autoencoders                                  0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
# DCS                                                     0.623176
# DCS modified v1                                         0.570750
# DCS modified v2                                         0.344704
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# CPA-based Autoencoders                                  0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
#
#                                  direct translation  \
# DCS                                        0.031209
# DCS modified v1                            0.031209
# DCS modified v2                            0.001315
# similarity-trained Autoencoders            0.003611
# direct translation                         1.000000
# Autoencoders with classifier               0.000000
# CPA-based Autoencoders                     0.000000
# FIT                                        0.000000
# TransCompR                                 0.000000
# DCS                                        0.025748
# DCS modified v1                            0.025748
# DCS modified v2                            0.001008
# similarity-trained Autoencoders            0.003611
# direct translation                         1.000000
# Autoencoders with classifier               0.000000
# CPA-based Autoencoders                     0.000000
# FIT                                        0.000000
# TransCompR                                 0.000000
# DCS                                        0.025748
# DCS modified v1                            0.025748
# DCS modified v2                            0.001706
# similarity-trained Autoencoders            0.004586
# direct translation                         1.000000
# Autoencoders with classifier               0.000000
# CPA-based Autoencoders                     0.000000
# FIT                                        0.000000
# TransCompR                                 0.000000
#
#                                  Autoencoders with classifier  \
# DCS                                                  0.273036
# DCS modified v1                                      0.344704
# DCS modified v2                                      0.472676
# similarity-trained Autoencoders                      0.520523
# direct translation                                   0.002202
# Autoencoders with classifier                         1.000000
# CPA-based Autoencoders                               0.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
# DCS                                                  0.472676
# DCS modified v1                                      0.344704
# DCS modified v2                                      0.273036
# similarity-trained Autoencoders                      0.570750
# direct translation                                   0.002202
# Autoencoders with classifier                         1.000000
# CPA-based Autoencoders                               0.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
# DCS                                                  0.344704
# DCS modified v1                                      0.344704
# DCS modified v2                                      0.307489
# similarity-trained Autoencoders                      0.570750
# direct translation                                   0.002202
# Autoencoders with classifier                         1.000000
# CPA-based Autoencoders                               0.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
#
#                                  CPA-based Autoencoders       FIT  TransCompR
# DCS                                            0.677585  0.520523    0.384673
# DCS modified v1                                0.850107  0.520523    0.384673
# DCS modified v2                                0.104110  0.031209    0.307489
# similarity-trained Autoencoders                0.623176  0.104110    0.733730
# direct translation                             0.007285  0.031209    0.005795
# Autoencoders with classifier                   0.344704  0.053903    0.969850
# CPA-based Autoencoders                         1.000000  0.140465    0.384673
# FIT                                            0.000000  1.000000    0.075662
# TransCompR                                     0.000000  0.000000    1.000000
# DCS                                            0.969850  0.000183    0.344704
# DCS modified v1                                1.000000  0.000183    0.307489
# DCS modified v2                                0.104110  0.000183    0.427355
# similarity-trained Autoencoders                0.850107  0.000183    0.733730
# direct translation                             0.007285  0.000183    0.002202
# Autoencoders with classifier                   0.212294  0.000183    0.969850
# CPA-based Autoencoders                         1.000000  0.000183    0.344704
# FIT                                            0.000000  1.000000    0.000183
# TransCompR                                     0.000000  0.000000    1.000000
# DCS                                            0.969850  0.000183    0.273036
# DCS modified v1                                0.969850  0.000183    0.273036
# DCS modified v2                                0.121225  0.000183    0.472676
# similarity-trained Autoencoders                0.791337  0.000183    0.520523
# direct translation                             0.007285  0.000183    0.002827
# Autoencoders with classifier                   0.273036  0.000183    0.850107
# CPA-based Autoencoders                         1.000000  0.000183    0.344704
# FIT                                            0.000000  1.000000    0.000183
# TransCompR                                     0.000000  0.000000    1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_a375 = results.loc[:,['recon_pear_a375','recon_spear_a375','recon_acc_a375','model']]
res_recon_a375.columns = ['pearson','spearman','sign accuracy','model']
res_recon_a375
# Out:
#      pearson  spearman  sign accuracy       model
# 0   0.944607  0.931870       0.891681         DCS
# 1   0.942046  0.929751       0.889458         DCS
# 2   0.947642  0.935973       0.894833         DCS
# 3   0.941711  0.929063       0.889775         DCS
# 4   0.945411  0.933031       0.894141         DCS
# ..       ...       ...            ...         ...
# 5   0.870845  0.833748       0.830252  TransCompR
# 6   0.854774  0.820409       0.821250  TransCompR
# 7   0.846940  0.813830       0.817877  TransCompR
# 8   0.851408  0.814839       0.818141  TransCompR
# 9   0.844722  0.813814       0.817554  TransCompR
#
# [70 rows x 4 columns]

# %%
res_recon_a375 = pd.melt(res_recon_a375,id_vars=['model'])
res_recon_a375.columns = ['model','metric','value']
res_recon_a375
# Out:
#           model         metric     value
# 0           DCS        pearson  0.944607
# 1           DCS        pearson  0.942046
# 2           DCS        pearson  0.947642
# 3           DCS        pearson  0.941711
# 4           DCS        pearson  0.945411
# ..          ...            ...       ...
# 205  TransCompR  sign accuracy  0.830252
# 206  TransCompR  sign accuracy  0.821250
# 207  TransCompR  sign accuracy  0.817877
# 208  TransCompR  sign accuracy  0.818141
# 209  TransCompR  sign accuracy  0.817554
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_recon_a375,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','Autoencoders with classifier',
                   'TransCompR',
                   'CPA-based Autoencoders'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='models')
#plt.xticks(rotation=45)
plt.xlim(0.5,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_a375.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','Autoencoders with classifier',
          'TransCompR','CPA-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='pearson'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-22-4e9f52c21874>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='pearson'].value.values
# <ipython-input-22-4e9f52c21874>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-23-db2d8645d6f5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='spearman'].value.values
# <ipython-input-23-db2d8645d6f5>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='sign accuracy'].value.values
        x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-24-26171e6f1a72>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_a375[res_recon_a375['model']==m1][res_recon_a375['metric']=='sign accuracy'].value.values
# <ipython-input-24-26171e6f1a72>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_a375[res_recon_a375['model']==m2][res_recon_a375['metric']=='sign accuracy'].value.values

# %%
a375_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
a375_reconstruction = a375_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','Autoencoders with classifier','TransCompR','CPA-based Autoencoders']]
a375_reconstruction.to_csv('../results/MI_results/allgenes_a375_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
a375_reconstruction
# Out:
#                                         metric  DCS  DCS modified v1  \
# DCS                                    pearson  1.0         0.000183
# DCS modified v1                        pearson  0.0         1.000000
# DCS modified v2                        pearson  0.0         0.000000
# similarity-trained Autoencoders        pearson  0.0         0.000000
# Autoencoders with classifier           pearson  0.0         0.000000
# TransCompR                             pearson  0.0         0.000000
# CPA-based Autoencoders                 pearson  0.0         0.000000
# DCS                                   spearman  1.0         0.000183
# DCS modified v1                       spearman  0.0         1.000000
# DCS modified v2                       spearman  0.0         0.000000
# similarity-trained Autoencoders       spearman  0.0         0.000000
# Autoencoders with classifier          spearman  0.0         0.000000
# TransCompR                            spearman  0.0         0.000000
# CPA-based Autoencoders                spearman  0.0         0.000000
# DCS                              sign accuracy  1.0         0.000183
# DCS modified v1                  sign accuracy  0.0         1.000000
# DCS modified v2                  sign accuracy  0.0         0.000000
# similarity-trained Autoencoders  sign accuracy  0.0         0.000000
# Autoencoders with classifier     sign accuracy  0.0         0.000000
# TransCompR                       sign accuracy  0.0         0.000000
# CPA-based Autoencoders           sign accuracy  0.0         0.000000
#
#                                  DCS modified v2  \
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
#
#                                  similarity-trained Autoencoders  \
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.000183
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.000183
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.000183
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
#
#                                  Autoencoders with classifier  TransCompR  \
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000183    0.000183
# similarity-trained Autoencoders                      0.733730    0.000183
# Autoencoders with classifier                         1.000000    0.000183
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000183    0.000183
# similarity-trained Autoencoders                      0.677585    0.000183
# Autoencoders with classifier                         1.000000    0.000183
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000183    0.000183
# similarity-trained Autoencoders                      0.733730    0.000183
# Autoencoders with classifier                         1.000000    0.000183
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
#
#                                  CPA-based Autoencoders
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000183
# similarity-trained Autoencoders                0.909722
# Autoencoders with classifier                   0.677585
# TransCompR                                     0.000183
# CPA-based Autoencoders                         1.000000
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000183
# similarity-trained Autoencoders                0.520523
# Autoencoders with classifier                   0.733730
# TransCompR                                     0.000183
# CPA-based Autoencoders                         1.000000
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000183
# similarity-trained Autoencoders                0.677585
# Autoencoders with classifier                   0.677585
# TransCompR                                     0.000183
# CPA-based Autoencoders                         1.000000

# %% [markdown]
# ## HT29 trasnlation

# %%
res_to_ht29 = results.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_to_ht29.columns = ['pearson','spearman','sign accuracy','model']
res_baseline = baseline.loc[:,['Direct_pearson','Direct_spearman','DirectAcc_ht29']]
res_baseline['model'] = 'direct translation'
res_baseline.columns = ['pearson','spearman','sign accuracy','model']
res_fit_ht29 = res_fit.loc[:,['model_pearsonHT29','model_spearHT29','model_accHT29','model']]
res_fit_ht29.columns = ['pearson','spearman','sign accuracy','model']
res_to_ht29 = pd.concat([res_to_ht29,res_baseline,res_fit_ht29],axis=0)
res_to_ht29
# Out:
#      pearson  spearman  sign accuracy model
# 0   0.613718  0.526330       0.685056   DCS
# 1   0.566115  0.464582       0.663853   DCS
# 2   0.609149  0.492402       0.667321   DCS
# 3   0.530387  0.418556       0.646344   DCS
# 4   0.649465  0.522971       0.686253   DCS
# ..       ...       ...            ...   ...
# 5   0.507485  0.652826       0.439214   FIT
# 6   0.426178  0.620179       0.355160   FIT
# 7   0.541904  0.655602       0.446650   FIT
# 8   0.395360  0.600902       0.310104   FIT
# 9   0.486326  0.631249       0.393344   FIT
#
# [90 rows x 4 columns]

# %%
res_to_ht29 = pd.melt(res_to_ht29,id_vars=['model'])
res_to_ht29.columns = ['model','metric','value']
res_to_ht29
# Out:
#     model         metric     value
# 0     DCS        pearson  0.613718
# 1     DCS        pearson  0.566115
# 2     DCS        pearson  0.609149
# 3     DCS        pearson  0.530387
# 4     DCS        pearson  0.649465
# ..    ...            ...       ...
# 265   FIT  sign accuracy  0.439214
# 266   FIT  sign accuracy  0.355160
# 267   FIT  sign accuracy  0.446650
# 268   FIT  sign accuracy  0.310104
# 269   FIT  sign accuracy  0.393344
#
# [270 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_to_ht29,
            order=['direct translation','DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','Autoencoders with classifier',
                   'CPA-based Autoencoders','FIT','TransCompR'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='')
plt.yticks([])
plt.xlim(0.25,0.7)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_autoencoders_comparison_allgenes_ht29.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','Autoencoders with classifier',
          'FIT','TransCompR','CPA-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-29-331afb6bc7e5>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='pearson'].value.values
# <ipython-input-29-331afb6bc7e5>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-30-2b2bd44095e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='spearman'].value.values
# <ipython-input-30-2b2bd44095e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='sign accuracy'].value.values
        x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-31-cfb7e48ca1ad>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_to_ht29[res_to_ht29['model']==m1][res_to_ht29['metric']=='sign accuracy'].value.values
# <ipython-input-31-cfb7e48ca1ad>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_to_ht29[res_to_ht29['model']==m2][res_to_ht29['metric']=='sign accuracy'].value.values

# %%
ht29_translate = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_translate = ht29_translate[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','direct translation','FIT','TransCompR','Autoencoders with classifier','CPA-based Autoencoders']]
ht29_translate.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_translation_pvalues_table.csv')
ht29_translate
# Out:
#                                         metric  DCS  DCS modified v1  \
# DCS                                    pearson  1.0         0.909722
# DCS modified v1                        pearson  0.0         1.000000
# DCS modified v2                        pearson  0.0         0.000000
# similarity-trained Autoencoders        pearson  0.0         0.000000
# direct translation                     pearson  0.0         0.000000
# Autoencoders with classifier           pearson  0.0         0.000000
# FIT                                    pearson  0.0         0.000000
# TransCompR                             pearson  0.0         0.000000
# CPA-based Autoencoders                 pearson  0.0         0.000000
# DCS                                   spearman  1.0         0.969850
# DCS modified v1                       spearman  0.0         1.000000
# DCS modified v2                       spearman  0.0         0.000000
# similarity-trained Autoencoders       spearman  0.0         0.000000
# direct translation                    spearman  0.0         0.000000
# Autoencoders with classifier          spearman  0.0         0.000000
# FIT                                   spearman  0.0         0.000000
# TransCompR                            spearman  0.0         0.000000
# CPA-based Autoencoders                spearman  0.0         0.000000
# DCS                              sign accuracy  1.0         0.909722
# DCS modified v1                  sign accuracy  0.0         1.000000
# DCS modified v2                  sign accuracy  0.0         0.000000
# similarity-trained Autoencoders  sign accuracy  0.0         0.000000
# direct translation               sign accuracy  0.0         0.000000
# Autoencoders with classifier     sign accuracy  0.0         0.000000
# FIT                              sign accuracy  0.0         0.000000
# TransCompR                       sign accuracy  0.0         0.000000
# CPA-based Autoencoders           sign accuracy  0.0         0.000000
#
#                                  DCS modified v2  \
# DCS                                     0.021134
# DCS modified v1                         0.037635
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.053903
# DCS modified v1                         0.037635
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.053903
# DCS modified v1                         0.037635
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# direct translation                      0.000000
# Autoencoders with classifier            0.000000
# FIT                                     0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
#
#                                  similarity-trained Autoencoders  \
# DCS                                                     0.185877
# DCS modified v1                                         0.185877
# DCS modified v2                                         0.427355
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.212294
# DCS modified v1                                         0.212294
# DCS modified v2                                         0.273036
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.307489
# DCS modified v1                                         0.273036
# DCS modified v2                                         0.307489
# similarity-trained Autoencoders                         1.000000
# direct translation                                      0.000000
# Autoencoders with classifier                            0.000000
# FIT                                                     0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
#
#                                  direct translation       FIT  TransCompR  \
# DCS                                        0.021134  0.520523    0.140465
# DCS modified v1                            0.021134  0.427355    0.185877
# DCS modified v2                            0.000183  0.001706    0.307489
# similarity-trained Autoencoders            0.000330  0.017257    0.909722
# direct translation                         1.000000  0.014019    0.000330
# Autoencoders with classifier               0.000000  0.002827    0.623176
# FIT                                        0.000000  1.000000    0.009108
# TransCompR                                 0.000000  0.000000    1.000000
# CPA-based Autoencoders                     0.000000  0.000000    0.000000
# DCS                                        0.011330  0.000183    0.104110
# DCS modified v1                            0.011330  0.000183    0.140465
# DCS modified v2                            0.000183  0.000246    0.241322
# similarity-trained Autoencoders            0.000583  0.000183    0.909722
# direct translation                         1.000000  0.000183    0.000330
# Autoencoders with classifier               0.000000  0.000183    0.623176
# FIT                                        0.000000  1.000000    0.000183
# TransCompR                                 0.000000  0.000000    1.000000
# CPA-based Autoencoders                     0.000000  0.000000    0.000000
# DCS                                        0.017257  0.000183    0.121225
# DCS modified v1                            0.017257  0.000183    0.140465
# DCS modified v2                            0.000183  0.000183    0.241322
# similarity-trained Autoencoders            0.001008  0.000183    1.000000
# direct translation                         1.000000  0.000183    0.000330
# Autoencoders with classifier               0.000000  0.000183    0.520523
# FIT                                        0.000000  1.000000    0.000183
# TransCompR                                 0.000000  0.000000    1.000000
# CPA-based Autoencoders                     0.000000  0.000000    0.000000
#
#                                  Autoencoders with classifier  \
# DCS                                                  0.088973
# DCS modified v1                                      0.088973
# DCS modified v2                                      0.472676
# similarity-trained Autoencoders                      0.520523
# direct translation                                   0.000330
# Autoencoders with classifier                         1.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
# CPA-based Autoencoders                               0.000000
# DCS                                                  0.075662
# DCS modified v1                                      0.064022
# DCS modified v2                                      0.677585
# similarity-trained Autoencoders                      0.623176
# direct translation                                   0.000330
# Autoencoders with classifier                         1.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
# CPA-based Autoencoders                               0.000000
# DCS                                                  0.064022
# DCS modified v1                                      0.064022
# DCS modified v2                                      0.570750
# similarity-trained Autoencoders                      0.570750
# direct translation                                   0.000330
# Autoencoders with classifier                         1.000000
# FIT                                                  0.000000
# TransCompR                                           0.000000
# CPA-based Autoencoders                               0.000000
#
#                                  CPA-based Autoencoders
# DCS                                            0.185877
# DCS modified v1                                0.185877
# DCS modified v2                                0.307489
# similarity-trained Autoencoders                0.791337
# direct translation                             0.000440
# Autoencoders with classifier                   0.520523
# FIT                                            0.025748
# TransCompR                                     0.969850
# CPA-based Autoencoders                         1.000000
# DCS                                            0.273036
# DCS modified v1                                0.307489
# DCS modified v2                                0.307489
# similarity-trained Autoencoders                0.969850
# direct translation                             0.000769
# Autoencoders with classifier                   0.623176
# FIT                                            0.000183
# TransCompR                                     0.791337
# CPA-based Autoencoders                         1.000000
# DCS                                            0.185877
# DCS modified v1                                0.273036
# DCS modified v2                                0.273036
# similarity-trained Autoencoders                1.000000
# direct translation                             0.001008
# Autoencoders with classifier                   0.520523
# FIT                                            0.000183
# TransCompR                                     0.969850
# CPA-based Autoencoders                         1.000000

# %% [markdown]
# ### Same but for reconstruction

# %%
res_recon_ht29 = results.loc[:,['recon_pear_ht29','recon_spear_ht29','recon_acc_ht29','model']]
res_recon_ht29.columns = ['pearson','spearman','sign accuracy','model']
res_recon_ht29
# Out:
#      pearson  spearman  sign accuracy       model
# 0   0.947445  0.937704       0.896936         DCS
# 1   0.945406  0.934308       0.894100         DCS
# 2   0.942116  0.933452       0.893411         DCS
# 3   0.944477  0.933683       0.894614         DCS
# 4   0.950940  0.942423       0.903572         DCS
# ..       ...       ...            ...         ...
# 5   0.869644  0.841884       0.835783  TransCompR
# 6   0.861795  0.833605       0.830092  TransCompR
# 7   0.877211  0.854646       0.843838  TransCompR
# 8   0.853622  0.827085       0.826753  TransCompR
# 9   0.846276  0.811522       0.817515  TransCompR
#
# [70 rows x 4 columns]

# %%
res_recon_ht29 = pd.melt(res_recon_ht29,id_vars=['model'])
res_recon_ht29.columns = ['model','metric','value']
res_recon_ht29
# Out:
#           model         metric     value
# 0           DCS        pearson  0.947445
# 1           DCS        pearson  0.945406
# 2           DCS        pearson  0.942116
# 3           DCS        pearson  0.944477
# 4           DCS        pearson  0.950940
# ..          ...            ...       ...
# 205  TransCompR  sign accuracy  0.835783
# 206  TransCompR  sign accuracy  0.830092
# 207  TransCompR  sign accuracy  0.843838
# 208  TransCompR  sign accuracy  0.826753
# 209  TransCompR  sign accuracy  0.817515
#
# [210 rows x 3 columns]

# %%
sns.set_theme(style="whitegrid",font_scale=2)
# plt.figure(figsize=(9,12), dpi= 80)
plt.figure()
ax = sns.barplot(x="value", y="model", data=res_recon_ht29,
            order=['DCS',
                   'DCS modified v1','DCS modified v2',
                   'similarity-trained Autoencoders','Autoencoders with classifier',
                   'TransCompR','CPA-based Autoencoders'],
            hue_order = ['sign accuracy','pearson','spearman'],
            hue="metric",ci=95,capsize=0.2,orient='h')
plt.legend(loc='lower left',prop={'size': 21})
plt.gca().set(title='', 
              xlabel = 'Performance metric value',
              ylabel='')
plt.yticks([])
#plt.ylim(0,1.0)
plt.savefig('../figures/MI_results/allgenes_10fold_validation_reconstruction_autoencoders_comparison_allgenes_ht29.eps',
            papertype="a4",
            format='eps',
            bbox_inches='tight',dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
models = ['DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','Autoencoders with classifier',
          'TransCompR','CPA-based Autoencoders']
pvalues_pearson = np.zeros((len(models),len(models)))
pvalues_pearson = pd.DataFrame(pvalues_pearson)
pvalues_pearson.index = models
pvalues_pearson.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values
        pvalues_pearson.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_pearson['metric'] = 'pearson'
# Out:
# <ipython-input-37-68a6ceab595f>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='pearson'].value.values
# <ipython-input-37-68a6ceab595f>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='pearson'].value.values

# %%
pvalues_spearman = np.zeros((len(models),len(models)))
pvalues_spearman = pd.DataFrame(pvalues_spearman)
pvalues_spearman.index = models
pvalues_spearman.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values
        pvalues_spearman.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_spearman['metric'] = 'spearman'
# Out:
# <ipython-input-38-d8298965d0b4>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='spearman'].value.values
# <ipython-input-38-d8298965d0b4>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='spearman'].value.values

# %%
pvalues_accuracy = np.zeros((len(models),len(models)))
pvalues_accuracy = pd.DataFrame(pvalues_accuracy)
pvalues_accuracy.index = models
pvalues_accuracy.columns = models
for i in range(len(models)):
    for j in range(i,len(models)):
        m1 = models[i]
        m2 = models[j]
        x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='sign accuracy'].value.values
        x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='sign accuracy'].value.values
        pvalues_accuracy.loc[m1,m2] = stats.mannwhitneyu(x1,x2)[1]
pvalues_accuracy['metric'] = 'sign accuracy'
# Out:
# <ipython-input-39-9d6d1f9e8d53>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x1 = res_recon_ht29[res_recon_ht29['model']==m1][res_recon_ht29['metric']=='sign accuracy'].value.values
# <ipython-input-39-9d6d1f9e8d53>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x2 = res_recon_ht29[res_recon_ht29['model']==m2][res_recon_ht29['metric']=='sign accuracy'].value.values

# %%
ht29_reconstruction = pd.concat([pvalues_pearson,pvalues_spearman,pvalues_accuracy],axis=0)
ht29_reconstruction = ht29_reconstruction[['metric','DCS','DCS modified v1','DCS modified v2','similarity-trained Autoencoders','Autoencoders with classifier','TransCompR','CPA-based Autoencoders']]
ht29_reconstruction.to_csv('../results/MI_results/allgenes_ht29_autoencoders_comparison_allgenes_reconstruction_pvalues_table.csv')
ht29_reconstruction
# Out:
#                                         metric  DCS  DCS modified v1  \
# DCS                                    pearson  1.0         0.000183
# DCS modified v1                        pearson  0.0         1.000000
# DCS modified v2                        pearson  0.0         0.000000
# similarity-trained Autoencoders        pearson  0.0         0.000000
# Autoencoders with classifier           pearson  0.0         0.000000
# TransCompR                             pearson  0.0         0.000000
# CPA-based Autoencoders                 pearson  0.0         0.000000
# DCS                                   spearman  1.0         0.000183
# DCS modified v1                       spearman  0.0         1.000000
# DCS modified v2                       spearman  0.0         0.000000
# similarity-trained Autoencoders       spearman  0.0         0.000000
# Autoencoders with classifier          spearman  0.0         0.000000
# TransCompR                            spearman  0.0         0.000000
# CPA-based Autoencoders                spearman  0.0         0.000000
# DCS                              sign accuracy  1.0         0.000183
# DCS modified v1                  sign accuracy  0.0         1.000000
# DCS modified v2                  sign accuracy  0.0         0.000000
# similarity-trained Autoencoders  sign accuracy  0.0         0.000000
# Autoencoders with classifier     sign accuracy  0.0         0.000000
# TransCompR                       sign accuracy  0.0         0.000000
# CPA-based Autoencoders           sign accuracy  0.0         0.000000
#
#                                  DCS modified v2  \
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
# DCS                                     0.000183
# DCS modified v1                         0.000183
# DCS modified v2                         1.000000
# similarity-trained Autoencoders         0.000000
# Autoencoders with classifier            0.000000
# TransCompR                              0.000000
# CPA-based Autoencoders                  0.000000
#
#                                  similarity-trained Autoencoders  \
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.000330
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.000583
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
# DCS                                                     0.000183
# DCS modified v1                                         0.000183
# DCS modified v2                                         0.001706
# similarity-trained Autoencoders                         1.000000
# Autoencoders with classifier                            0.000000
# TransCompR                                              0.000000
# CPA-based Autoencoders                                  0.000000
#
#                                  Autoencoders with classifier  TransCompR  \
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000440    0.000183
# similarity-trained Autoencoders                      0.677585    0.007285
# Autoencoders with classifier                         1.000000    0.001315
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000583    0.000183
# similarity-trained Autoencoders                      0.791337    0.014019
# Autoencoders with classifier                         1.000000    0.007285
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
# DCS                                                  0.000183    0.000183
# DCS modified v1                                      0.000183    0.000183
# DCS modified v2                                      0.000769    0.000183
# similarity-trained Autoencoders                      0.909722    0.031209
# Autoencoders with classifier                         1.000000    0.014019
# TransCompR                                           0.000000    1.000000
# CPA-based Autoencoders                               0.000000    0.000000
#
#                                  CPA-based Autoencoders
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000583
# similarity-trained Autoencoders                0.909722
# Autoencoders with classifier                   0.850107
# TransCompR                                     0.005795
# CPA-based Autoencoders                         1.000000
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000769
# similarity-trained Autoencoders                0.850107
# Autoencoders with classifier                   0.791337
# TransCompR                                     0.004586
# CPA-based Autoencoders                         1.000000
# DCS                                            0.000183
# DCS modified v1                                0.000183
# DCS modified v2                                0.000769
# similarity-trained Autoencoders                0.733730
# Autoencoders with classifier                   0.733730
# TransCompR                                     0.021134
# CPA-based Autoencoders                         1.000000
